# %% [markdown]
# # [Датафреймы](https://drive.google.com/drive/folders/13K24GVmATfSxGF0K0LcWFHBiLxJRuRyN?usp=sharing)

# %% [markdown]
# *   [`Headliner_df.pkl` Датафрейм информации о звонках `Headliner`](https://drive.google.com/file/d/1-86JPhdac5Y-YIggqYWVh9rFCDoe8Uej/view?usp=sharing)
# *   [`Primavera_df.pkl` Датафрейм информации о звонках `Primavera`](https://drive.google.com/file/d/16vejQ6aIN1VprZ8RuaG0Dx4SSj3eebbP/view?usp=sharing)
# *   [`Paveletskaya_city_df.pkl` Датафрейм информации о звонках `Paveletskaya_city`](https://drive.google.com/file/d/1-0RLElus9y3f3xJ7PovfTDFoLh_2HnPK/view?usp=sharing)
# *   [`Paveletskaya_df.pkl` Датафрейм информации о звонках `Paveletskaya`](https://drive.google.com/file/d/1-3V7Dyjq-N3m0dc-7FztObG4PeRrMfHl/view?usp=sharing)
# *   [`total_df.pkl` Общий датафрейм информации о звонках](https://drive.google.com/file/d/18LdqvkasD_NMNbB025jQDyWmuTWfXrin/view?usp=sharing)
# *   [`total_not_match_df.pkl` Общий датафрейм информации о звонках без файлов записей звонков](https://drive.google.com/file/d/1-0C7m74ofUqLCH4C-eX3ARZMWRLOQeMJ/view?usp=sharing)
# *   [`total_match_df.pkl` Общий датафрейм информации о звонках с файлами записей звонков](https://drive.google.com/file/d/1-JerYBfZ95fZX698-N25-gC1HNC0jwTy/view?usp=sharing)
# *   [`files_for_transcription_df.pkl` Файлы записей звонков для транскрибации](https://drive.google.com/file/d/1zYs0ioydR3cNvn2GItm3t4-_DOHELmcz/view?usp=sharing)
# *   [`Headliner_transcriptions_duplicates_df.pkl` Дубликаты файлов транскрибации записей звонков `Headliner`](https://drive.google.com/file/d/1AipPmqtkKenGn3FeT6j9bRpmhLE4Nb52/view?usp=sharing)
# *   [`Headliner_transcriptions_df.pkl` Файлы транскрибации записей звонков `Headliner`](https://drive.google.com/file/d/1-6nvHviEZcJhQN_5ayJHWi915VZSaH85/view?usp=sharing)
# *   [`Primavera_transcriptions_df.pkl` Файлы транскрибации записей звонков `Primavera`](https://drive.google.com/file/d/1-95iMVyyHCY3TLw7MjTuvhKged0F7Fvk/view?usp=sharing)
# *   [`Paveletskaya_city_transcriptions_df.pkl` Файлы транскрибации записей звонков `Paveletskaya_city`](https://drive.google.com/file/d/1-AEMld0GLwY8F9eb8Zl-i4JR0iMriDG3/view?usp=sharing)
# *   [`Headliner_transcriptions_text_df.pkl` Датафрейм с текстами транскрибации записей звонков `Headliner`](https://drive.google.com/file/d/1-BW6FuH533sHste2-G3lsz5UwgCHq-tA/view?usp=sharing)
# *   [`Primavera_transcriptions_text_df.pkl` Датафрейм с текстами транскрибации записей звонков `Primavera`](https://drive.google.com/file/d/1-GtHNxJsJXLeJ3caAmEeLSnC8hKI9IHS/view?usp=sharing)
# *   [`Paveletskaya_city_transcriptions_text_df.pkl` Датафрейм с текстами транскрибации записей звонков `Paveletskaya_city`](https://drive.google.com/file/d/1-JJd74nlGwpV5AOkTFjCagZ9GACk1-Jr/view?usp=sharing)
# *   [`transcriptions_df.pkl` Общий датафрейм из файлов транскрибации звонков](https://drive.google.com/file/d/1-4XFnmUfM5XSlobGbxjYNvqIC5mIETKa/view?usp=sharing)
# *   [`empty_transcriptions_text_df.pkl` Датафрейм с пустыми текстами транскрибации звонков](https://drive.google.com/file/d/1k9BBo6NHO3P6wC39FHPS4L1HU6hUc1CC/view?usp=sharing)
# *   [`total_transcriptions_text_df.pkl` Общий датафрейм информации о звонках с добавленными текстами транскрибации](https://drive.google.com/file/d/1-9aVRx43rM7eXesI8Q8Rp-ClfjKMLK4e/view?usp=sharing)
# *   [`total_text_df.pkl` Общий датафрейм информации о звонках с непустыми текстами транскрибации Whisper](https://drive.google.com/file/d/1-8GP-b9YLJEOHPtP_BVstto5YjyHPrLj/view?usp=sharing)
# *   [`target_teg_df.pkl` Датафрейм тегов целевых звонков из датафрейма `total_text_df`](https://drive.google.com/file/d/1--VcAmWPUmTOK6zeIViVdQ51s-iw1Ia9/view?usp=sharing)
# *   [`targets_df.pkl` Датафрейм с непустыми текстами транскрибации целевых звонков](https://drive.google.com/file/d/1PK7OhmOYHMo2UUN83WhZlFYRzwX9lOo_/view?usp=sharing)
# *   [`not_target_teg_df.pkl` Датафрейм тегов нецелевых звонков из датафрейма `total_text_df`](https://drive.google.com/file/d/1-5BHr9ik1LY9sQ1JpdioKOuH8QJ6bw3o/view?usp=sharing)
# *   [`not_targets_df.pkl` Датафрейм с непустыми текстами транскрибации нецелевых звонков](https://drive.google.com/file/d/1-1Vu4OuE9DFmLlxDKdkbN-mzXhkYS1ku/view?usp=sharing)
# *   [`calls_duration_statistics_df.pkl` Описательные статистики длительности звонков](https://drive.google.com/file/d/1xxBpajBj30eK3kV9mlBVYs7o_1Hr5yLJ/view?usp=sharing)
# *   [`text_length_statistics_df.pkl` Описательные статистики длин текстов транскрибации звонков](https://drive.google.com/file/d/1-6JF86eqrNnLjHhh1lDTOkRr9Nt92Zsw/view?usp=sharing)
# *   [`targets_sorted_df.pkl` Сортированный датафрейм с текстами транскрибации целевых звонков](https://drive.google.com/file/d/1-N0fRAj7jOXSLlMXz4wX9820mi_cfF5I/view?usp=sharing)
# *   [`not_targets_sorted_df.pkl` Сортированный датафрейм с текстами транскрибации нецелевых звонков](https://drive.google.com/file/d/1-P6cFpEC62SuqljPRqrrxrzGkTHr435j/view?usp=sharing)

# %% [markdown]
# # [Таблицы](https://drive.google.com/drive/folders/1Wr3rQQkQtTuTFMRSdAbz1rMPHxdHCeLZ?usp=sharing)

# %% [markdown]
# *   [Записи звонков без информации в csv-файлах.xlsx](https://docs.google.com/spreadsheets/d/1-5hKNi2yH7Vy94H_LatiNmscocsK7U5m/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)
# *   [Информация о звонках в csv-файлах без файлов записи звонков.xlsx](https://docs.google.com/spreadsheets/d/1-DpzEGSH02laE7cKinwxNzPj2zhXgN6J/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)
# *   [Информация о звонках в csv-файлах с файлами записи звонков.xlsx](https://docs.google.com/spreadsheets/d/1-QR-Xng6RHZGsJCRVQQP3jCosBAQAIIF/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)
# *   [Файлы для транскрибации.xlsx](https://docs.google.com/spreadsheets/d/1--RU4rTU--Zyb--3brX7sPPb30Z--YGl/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)
# *   [Дубликаты файлов транскрибации звонков Headliner.xlsx](https://docs.google.com/spreadsheets/d/1-6TFKVSaEAkXlIKS5TGpHi9_Thv3pK3p/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)
# *   [Файлы с пустыми текстами транскрибации звонков.xlsx](https://docs.google.com/spreadsheets/d/1-1Y5i4nVLA5O1rjwDfX1LkZbMnZywaIO/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)
# *   [Теги.xlsx](https://docs.google.com/spreadsheets/d/1-56Uq5KmszbHheKOxVL7BPUmmYz2bKhb/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)
# *   [Описательные статистики длительности звонков.xlsx](https://docs.google.com/spreadsheets/d/1-7cFIA7yY2XPgZyEocl7R_svxOgUfPP7/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)
# *   [Описательные статистики длин текстов транскрибации звонков.xlsx](https://docs.google.com/spreadsheets/d/1-7-VwVzXQtL4v1BDwigNVak_usTlEFgU/edit?usp=sharing&ouid=103791142604649006389&rtpof=true&sd=true)

# %% [markdown]
# # [Модели](https://drive.google.com/drive/folders/1Dby4Pv_QNoAMt_3gkFYZ2i4sJ1pIC-2K?usp=sharing)

# %% [markdown]
# *   [`2023.10.15_text_model.keras` Модель на тектовом датасете без добавления новых записей, полученная с помощью `autokeras`, точность `99%` на проверочной выборке](https://drive.google.com/file/d/1EaA53dXa4ZU2DZLB2su4bf8TOPTdM_CK/view?usp=sharing)

# %% [markdown]
# # Техническое задание

# %% [markdown]
# **Проект:** Классификация аудиозвонков на целевые и нецелевые.

# %% [markdown]
# **Цель проекта:** Разработать нейронную сеть, способную классифицировать аудиозвонки на целевые и нецелевые на основе предоставленной базы данных и csv-таблицы с описаниями и метками классов.

# %% [markdown]
# **Введение:**
#
# Входной набор данных представляет из себя два набора файлов:
#
# > a)	[Первый набор файлов](https://drive.google.com/drive/folders/1cQWMpQkscZJbbOTxiJNy0o3nuaeIiB1P?usp=sharing) - это выгрузки в формате `CSV` с информацией по звонкам, а так же с проставленным статусом `“целевой/нецелевой”` в отдельном столбце (обратите внимание, что по проекту `“Павелецкая сити”` две выгрузки - эти наборы данных отличаются и относятся к разным наборам клиентов внутри одного и того же проекта).
#
# > b)	[Второй набор файлов](https://drive.google.com/drive/folders/1K3jGCH60uzFcsI3aj89VIXOOFEXvZxD6?usp=sharing) - аудиозаписи звонков. Они хранятся в корневом каталоге в одноимённых папках. К примеру, в папке `“Записи звонков_павелецкая сити”` лежат записи звонков по проекту `“Павелецкая Сити”`.

# %% [markdown]
# **Требования:**
#
# 1.   Нейронная сеть должна быть спроектирована и обучена для точной классификации аудиозвонков на два класса: целевые и нецелевые (с точностью `90+%`).
# 2.   Необходимо обеспечить интеграцию модели через `API`.
# 3.   Модель должна быть оптимизирована для обработки большого объёма данных.
# 4.   Код должен быть написан с соблюдением стандартов кодирования, и должна быть составлена подробная техническая документация.
# 5.   Код должен включать в себя систему журналирования для фиксации ошибок.
# 6.   Код должен принимать на вход регулярное выражение, по которому будет осуществляться проверка столбца `“теги”` в выгрузках `CSV` для определения статуса звонка `“целевой/нецелевой”`:
#
# >> a)	по проектам `“Примавера”` и `“Павелецкая сити”` наличие в столбце с тегами подстроки `“Целевой_М108“` будет равняться тому, что данный звонок целевой (пример регулярного выражения: `.*Целевой_М108.*`);
#
# >> b)	по проекту `“Хедлайнер”` - наличие в столбце с тегами подстроки `“первичный целевой“` будет равняться тому, что данный звонок целевой.
#
# 7.   После реализации необходимо иметь возможность получения поддержки по предоставленному решению в течение `2 месяцев`.

# %% [markdown]
# Список рекомендуемых параметров для звуковой записи (данный список носит информационный характер и не является обязательным):
#
# *   Эмоция (базовые 11: радость; печаль; гнев; отвращение; удивление; страдание (горе); волнение (интерес); презрение; смущение; стыд; вина).
# *   Пол.
# *   Возраст.
# *   Семантический анализ диалога (по конкретным ключевым словам и/или по тематикам диалогов).
# *   Характеристики, присутствующие в `CSV`/`XLSX` таблицах.

# %% [markdown]
# # Критерии классификации

# %% [markdown]
# Критерии `уникально-целевого` обращения:
# 1. Длительность звонка должна быть не менее `75 секунд`;
# 2. Телефонный номер абонента должен быть `уникальным`, т. е. его не должно быть в `CRM` заказчика. Либо, по нему не должно быть активности за последние `90 дней`. Исключение составляют `топовые площадки`, работающие по своим критериям (`ЦИАН`, `Яндекс.Недвижимость`, `Авито`, и т. д.);
# 3. Клиент должен знать минимальную информацию об объекте (понимать, куда он звонит): название `ЖК`, расположение, ценовую политику;
# 4. Номер абонента должен быть доступен в течение `15 дней` после совершённого звонка (при этом со стороны заказчика должно быть обеспечено `2 попытки` исходящего звонка в течение указанного срока);
# 5. Клиент должен быть `«адекватным»`. Не общаться на повышенных тонах, не употреблять ненормативную лексику и т. д.;
# 6. Клиент не должен быть повторным. Например, клиент `уже` купил квартиру и через `90 дней` решил купить машиноместо;
# 7. Заявка. В заявке должен быть указан номер телефона, а абонент при контакте с менеджером должен соответствовать всем критериям `уникально-целевого` обращения, перечисленным выше;
# 8. Озвученный общий бюджет покупки не должен быть `ниже 90%` от стоимости квартиры или коммерческого помещения, соответствующих площади/комнатности на момент обращения;
# 9. В случае, если клиент является уникальным, интересуется покупкой недвижимости, не является представителем партнёров или исполнителей и изъявил желание посетить офис продаж. При этом не обязательна фиксация уровня знания клиента об объекте в диалоге. При этом источник не должен относиться к каналам `«лидогенерация»` или `«тематические площадки»`;
# 10. Основной целью звонка клиента не должна являться покупка/аренда исключительно нежилого помещения, если это не являлось целью проводимой рекламной кампании.
#
# Критерии НЕ `уникально-целевого` (вторичного) обращения:
# 1. Клиент позвонил повторно менее чем через `3 месяца` (`90 дней`) с момента последнего обращения;
# 2. Клиент, либо члены его семьи, уже купил (купили) `квартиру`/`машиноместо`/`кладовое помещение`, и хочет (хотят) совершить ещё одну покупку. В данном случае клиент относится к показателю `LTV` (показатель прибыли, которую компания получает от одного клиента за всё время работы с ним).

# %% [markdown]
# # 6 неделя

# %%
# !rm -r sample_data

# %%
# !pip -q install autokeras
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 kB 17.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.1/590.1 kB 25.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 53.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 126.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 70.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 90.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 43.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 80.1 MB/s eta 0:00:00

# %%
import autokeras as ak
# Out:
# Using TensorFlow backend

# %%
# Подключаем google-диск
from google.colab import drive
drive.mount('/content/drive')
my_drv_path = '/content/drive/MyDrive/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Библиотеки и переменные

# %%
import os            # для работы с операционной системой
import pickle as pkl # для сохранения и загрузки переменных
import pandas as pd  # для работы с таблицами
import numpy  as np  # для работы с массивами
import re            # для работы с регулярными выражениями

# Параметры отображения датафреймов
pd.options.display.max_rows     = 99
pd.options.display.max_columns  = 99
pd.options.display.max_colwidth = 999

df_path                = my_drv_path + 'media108.ru/Датафреймы/'                                          # путь к папке для датафреймов
table_path             = my_drv_path + 'media108.ru/Таблицы/'                                             # путь к папке для таблиц
model_path             = my_drv_path + 'media108.ru/Модели/'                                              # путь к папке для моделей нейронных сетей
all_dataset_path       = my_drv_path + 'media108.ru/Датасет/'                                             # путь к папке всего датасета в целом
new_dataset_path       = my_drv_path + 'media108.ru/Датасет/Новые записи звонков/'                        # путь к новым записям звонков
new_dataset_rar_path   = my_drv_path + 'media108.ru/Новые записи звонков (rar)/'                          # путь к rar-файлам новых записей звонков
new_transcription_path = my_drv_path + 'media108.ru/Датасет/Whisper-транскрибация новых записей звонков/' # путь к папке транскрибации новых записей звонков
new_dataset_info_path  = new_dataset_path + 'Информация о звонках/'                                       # путь к информации о новых звонках

# %% [markdown]
# ## Функции

# %%
# Функция для создания датафрейма из списка записей звонков
def calls_list_to_df(calls_list):

  datetime_list    = [] # список для 'Дата и время'
  from_number_list = [] # список для 'Номер абонента'
  to_number_list   = [] # список для 'Номер сотрудника'
  session_list     = [] # список для 'Идентификатор сессии звонка'

  # Проходим по списку записей звонков
  for call in calls_list:

    call_item_list = call.split('_')
    time_item_list = call_item_list[1].split('.')
    time_item_list = time_item_list[0].split('-')

    # Заполняем списки для столбцов
    datetime_list.append(call_item_list[0] + ' ' + time_item_list[0] + ':' + time_item_list[1] + ':' + time_item_list[2])
    from_number_list.append(call_item_list[3])
    to_number_list.append(call_item_list[5])
    session_list.append(call_item_list[7])

  # Собираем созданные списки в словарь
  calls_dict = dict.fromkeys(['Дата и время', 'Номер абонента', 'Номер сотрудника', 'Идентификатор сессии звонка', 'Файл записи звонка'], [])
  calls_dict['Дата и время']                = datetime_list
  calls_dict['Номер абонента']              = from_number_list
  calls_dict['Номер сотрудника']            = to_number_list
  calls_dict['Идентификатор сессии звонка'] = session_list
  calls_dict['Файл записи звонка']          = calls_list

  # Возвращаем датафрейм
  return pd.DataFrame(calls_dict)


# Функция для создания датафрейма из списка файлов транскрибации звонков
def transcriptions_list_to_df(transcriptions_list):

  datetime_list    = [] # список для 'Дата и время'
  from_number_list = [] # список для 'Номер абонента'
  to_number_list   = [] # список для 'Номер сотрудника'
  session_list     = [] # список для 'Идентификатор сессии звонка'

  # Проходим по списку записей звонков
  for transcription in transcriptions_list:

    transcription_item_list = transcription.split('_')
    time_item_list = transcription_item_list[1].split('.')
    time_item_list = time_item_list[0].split('-')

    # Заполняем списки для столбцов
    datetime_list.append(transcription_item_list[0] + ' ' + time_item_list[0] + ':' + time_item_list[1] + ':' + time_item_list[2])
    from_number_list.append(transcription_item_list[3])
    to_number_list.append(transcription_item_list[5])
    session_list.append(transcription_item_list[7])

  # Собираем созданные списки в словарь
  transcriptions_dict = dict.fromkeys(['Дата и время', 'Номер абонента', 'Номер сотрудника', 'Идентификатор сессии звонка', 'Файл whisper-транскрибации записи звонка'], [])
  transcriptions_dict['Дата и время']                             = datetime_list
  transcriptions_dict['Номер абонента']                           = from_number_list
  transcriptions_dict['Номер сотрудника']                         = to_number_list
  transcriptions_dict['Идентификатор сессии звонка']              = session_list
  transcriptions_dict['Файл whisper-транскрибации записи звонка'] = transcriptions_list

  # Возвращаем датафрейм
  return pd.DataFrame(transcriptions_dict)


# Функция для показа формы датасета
def dataset_shapes(dataset):
  for split in ['train', 'val']:
    print(f'\n--- Выборка {split} ---')
    for i, (inp, arr) in enumerate(dataset.X[split].items(), 1):
      print(f'Вход {i}: {arr.shape}')
    for i, (inp, arr) in enumerate(dataset.Y[split].items(), 1):
      print(f'Выход {i}: {arr.shape}')


def most_common_words(dataset, words_count):
  index_word = dataset.preprocessing['1_Text'].index_word
  pairs = {k: index_word[k] for k in list(index_word)[:words_count]}
  return pairs


def dataset_prediction(dataset, model, num_samples=10, verbose=1):
  true_predictions = 0
  classes_names_train = ['Целевой', 'Нецелевой']
  classes_names = dataset.put_instructions[2]['2_Classification'].parameters.classes_names
  inp, out, pred = next(dataset.evaluate_on_model(model, batch_size=num_samples))
  print()
  for i, (sample, y_t, y_p) in enumerate(zip(inp['input_1'], out['output_1'], pred)):
    if classes_names[0] == classes_names_train[0]:
      text_to_output = f'Правда: {classes_names[y_t]}, Предсказание: {classes_names[round(y_p[0])]}'
      if y_t == round(y_p[0]): true_predictions += 1
    else:
      text_to_output = f'Правда: {classes_names[y_t]}, Предсказание: {classes_names[not round(y_p[0])]}'
      if y_t != round(y_p[0]): true_predictions += 1
    if verbose: print(text_to_output)
  if verbose: print()
  return f'{true_predictions/num_samples:.2%}'

# %% [markdown]
# ## Создание текстового датасета

# %%
# Загрузка датафреймов целевых и нецелевых звонков
with open(df_path + 'targets_df.pkl', 'rb') as f:
  targets_df = pkl.load(f)

with open(df_path + 'not_targets_df.pkl', 'rb') as f:
  not_targets_df = pkl.load(f)

# %%
print(targets_df.shape)
print(not_targets_df.shape)
# Out:
# (1312, 78)
# (3209, 78)

# %%
# Создаём каталоги для текстового датасета
os.makedirs('Звонки_текст', exist_ok=True)
os.makedirs('Звонки_текст/Целевой', exist_ok=True)
os.makedirs('Звонки_текст/Нецелевой', exist_ok=True)

# %%
# Записываем текстовые файлы
targets_df['Текст транскрибации звонка Whisper'].to_csv('Звонки_текст/Целевой/targets.txt', index=False, header=None)
not_targets_df['Текст транскрибации звонка Whisper'].to_csv('Звонки_текст/Нецелевой/not_targets.txt', index=False, header=None)

# %%
# Установка terra-ai-datasets-framework
# %%capture
# !pip install terra-ai-datasets-framework

# %%
from terra_ai_datasets.create import TextClassification

# %%
dataset = TextClassification(
    source_path=['Звонки_текст'],
    train_size=0.8,
    max_words_count=20000,
    mode='Length and step',
    preprocessing='None',
    length=100,
    step=10,
    one_hot_encoding=False,
    pymorphy=False
    )
# Out:
# 06:26:50 | Датасет подготовлен к началу формирования массивов
# INFO:terra_ai_datasets.creation.utils:Датасет подготовлен к началу формирования массивов

# %%
dataset.visualize()
# Out:
# Класс: Нецелевой
# 'Да буду ждать Спасибо Здравствуйте вы позвонили в компанию Эммер Групп Пожалуйста дождитесь ответа нашего специалиста Здравствуйте вы позвонили к компанию NRG Пожалуйста дождитесь ответа нашего специалиста Обращаем ваше внимание что в целях улучшения качества отслуживания клиентов все разговоры записываются Продолжая разговор Вы позвоните по объявлению МРДУ Пожалуйста дождитесь ответа нашего специалиста Обращаем ваше внимание Здравствуйте Вы позвонили в компанию Эмергрупп Пожалуйста дождитесь ответа нашего специалиста Обращаем Ваше внимание что в целях улучшения качества обслуживания клиентов все разговоры записываются Продолжая разговор Вы соглашаетесь на обработку Ваших персональных данных Компания Эмергрупп Меня зовут Татьяна Здравствуйте Здравствуйте А это реабилитационный центр Нет'
# Класс: Целевой
# 'же скидки есть и они все индивидуальны согласовываются как в офисе продаж в зависимости от того какая квартира вам понравится на каком этаже и какая будет форма оплаты Разрочка и посека безусловно оплатки процентные Что процентное безусловно это что Скидка размер скидки зависит от формы оплаты полная оплата наличными деньгами и посека рассылочка То есть как вы будете оплачивать это все влияет на стоимость квартиры на размер скидки Если… На каком проекте Какая скидка Все скидки я говорю все индивидуальны в офисе продаж Хорошо тогда И после выбора квартиры они очень разно отличаются друг от друга По ипотеке какие условия'

# %%
dataset.summary()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1_Text  \
# 0                                                                               Вам пришлю контакты а Вы мне в ответ данные Да договорились хорошо А когда Вы мне сможете перезвонить тогда по готовности ну по информации Как ответите в течение дня в течение дня хотя уже почти 6 сегодня либо ну может быть утром Угу ну хорошо ловинга потому что угу угу да договорились да спасибо Угу хорошо да хорошо Ну да отделка и там вот обои прям ждут ждут они Угу Вам нужно не о том что оплачено а о том что не передано по акту прямой передачи да Да хотя как может быть сделана квартира в доме который не передан
# 1  в одном километре от нас Для того чтобы ее видеть там надо по этажу уже повыше забираться То есть выше 15 го Я сначала так посмотрела на эти проценты это нужно за субметр посчитать Вот Соответственно да Вы можете приехать к нам в отдел продаж если мы вам подберем какой нибудь вариант делаем расчеты предварительные по липоситину То есть у вас будет уже соответственно полный скажем так набор предложений возможных и вы сможете выбрать для себя что будет для вас То есть субсидироваться и по стандартным условиям приобретать Ну да Получается если эти первоначальные износы ипотеки там уже чуть не
# 2                                                                        Али Вы подбираете для себя студию Да для студии Я почему то не знаю у вас есть рассрочка Да есть Я хотел уточнить может быть рассрочка или одна или двухкомнатная студия А Вы для себя подбираете Нет я подбираю для инвесторов Может что то сдать может что то потом перепродать В данный момент я беру договор с делаемой символ У меня там есть в данном момент Вот сейчас опять беру И почему то у вас было я давно в прошлом году И там хорошая хорошая Павлецкая Нравится район жив долго там Может быть как для себя может быть как для
# 3      Ну площадь Вам нужна какая Чтобы 2 машины Полноценная для спальни Или формата Евро 2 Что такое формат Евро 2 Где большая кухня гостиная с балконом и отдельная спальня Нет Какие планировки у нас от 43 квадратных метров идут Нет нет А бюджет в Вашем Нет нет Ваши 16 миллионов Нет Нет это негодяй Что Ладно понял спасибо Мы направим Вам предложение может быть если Вы передумаете Вам дополнительно призвание Спасибо Вам за обращение Спасибо сказала До свидания Доброе утро Глубный город на реке Промавейра Лидия слушаю вас Мне надо записаться к стоматологу Вы знаете Нет Паша мы квартиры продаем
# 4                                                               мы говорим про хедлайнеры у них достаточно сложная архитектурная концепция У нас есть дома высокие вот то о чем мы говорили то о чем я вам сказал это квартира в высоком доме У нас есть дома малоэтажные то есть это 4 5 этажей Касательно того как это все выглядит лучше смотреть вживую потому что дома сданы и я смогу вас в эти квартиры свалить и показать У вас есть какая то возможность приехать на выходные или будни Так ну давайте тогда сейчас придумаю После 25 го я наверное освобожусь и уже могу приехать сюда с 25 го мая потому что
#
#   2_Classification
# 0       Нецелевой
# 1       Нецелевой
# 2         Целевой
# 3       Нецелевой
# 4         Целевой
# Кол-во примеров в train выборке: 120507
# Кол-во примеров в val выборке: 30127
#
# Список классов и количество примеров:
#        Нецелевой  Целевой
# train       43128     77379
# val         10852     19275

# %%
dataset.create(use_generator=False)
# Out:
# 06:27:28 | Формирование массивов train - Text - 1_Text: 100%|██████████| 120507/120507 [00:09<00:00, 12833.23it/s]
# 06:27:44 | Формирование массивов train - Classification - 2_Classification: 100%|██████████| 120507/120507 [00:14<00:00, 8563.78it/s]
# 06:28:02 | Формирование массивов val - Text - 1_Text: 100%|██████████| 30127/30127 [00:03<00:00, 7652.77it/s]
# 06:28:07 | Формирование массивов val - Classification - 2_Classification: 100%|██████████| 30127/30127 [00:02<00:00, 12531.88it/s]

# %% [markdown]
# ## Подбор архитектуры нейронной сети

# %%
text_clf = ak.TextClassifier(
    max_trials=2,
    overwrite=True,
    seed=42,
    num_classes=2,
    multi_label=False,
    metrics=['accuracy'],
    objective='val_accuracy'
)

# %%
text_clf.fit(
    dataset.X['train']['input_1'],
    dataset.Y['train']['output_1'],
    epochs=10,
    batch_size=16,
    validation_data=(dataset.X['val']['input_1'],
                     dataset.Y['val']['output_1']))
# Out:
# Trial 2 Complete [00h 21m 16s]
# val_accuracy: 0.9836359620094299
#
# Best val_accuracy So Far: 0.9963487982749939
# Total elapsed time: 00h 35m 47s
# Epoch 1/10
# 7532/7532 [==============================] - 96s 12ms/step - loss: 0.2777 - accuracy: 0.8838 - val_loss: 0.1895 - val_accuracy: 0.9233
# Epoch 2/10
# 7532/7532 [==============================] - 68s 9ms/step - loss: 0.0741 - accuracy: 0.9733 - val_loss: 0.0620 - val_accuracy: 0.9763
# Epoch 3/10
# 7532/7532 [==============================] - 73s 10ms/step - loss: 0.0459 - accuracy: 0.9837 - val_loss: 0.0420 - val_accuracy: 0.9843
# Epoch 4/10
# 7532/7532 [==============================] - 72s 10ms/step - loss: 0.0364 - accuracy: 0.9871 - val_loss: 0.0158 - val_accuracy: 0.9952
# Epoch 5/10
# 7532/7532 [==============================] - 72s 10ms/step - loss: 0.0280 - accuracy: 0.9904 - val_loss: 0.0143 - val_accuracy: 0.9949
# Epoch 6/10
# 7532/7532 [==============================] - 71s 9ms/step - loss: 0.0238 - accuracy: 0.9919 - val_loss: 0.0165 - val_accuracy: 0.9942
# Epoch 7/10
# 7532/7532 [==============================] - 70s 9ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.0159 - val_accuracy: 0.9945
# Epoch 8/10
# 7532/7532 [==============================] - 71s 9ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0138 - val_accuracy: 0.9956
# Epoch 9/10
# 7532/7532 [==============================] - 70s 9ms/step - loss: 0.0170 - accuracy: 0.9945 - val_loss: 0.0244 - val_accuracy: 0.9925
# Epoch 10/10
# 7532/7532 [==============================] - 67s 9ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.0100 - val_accuracy: 0.9970

# %%
model = text_clf.export_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None,)]                 0
#
#  expand_last_dim (ExpandLas  (None, 1)                 0
#  tDim)
#
#  text_vectorization (TextVe  (None, 512)               0
#  ctorization)
#
#  embedding (Embedding)       (None, 512, 64)           320064
#
#  dropout (Dropout)           (None, 512, 64)           0
#
#  conv1d (Conv1D)             (None, 508, 256)          82176
#
#  global_max_pooling1d (Glob  (None, 256)               0
#  alMaxPooling1D)
#
#  dense (Dense)               (None, 256)               65792
#
#  re_lu (ReLU)                (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
#  classification_head_1 (Act  (None, 1)                 0
#  ivation)
#
# =================================================================
# Total params: 468289 (1.79 MB)
# Trainable params: 468289 (1.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.save('model.keras')

# %%
from tensorflow.keras.models import load_model
model = load_model('model.keras')
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 15 variables whereas the saved optimizer has 1 variables.

# %%
from tensorflow.keras import utils
utils.plot_model(model, show_shapes=True, dpi=50)

# %% [markdown]
# ## Тестирование модели нейронной сети

# %% [markdown]
# ### Загрузка модели нейронной сети

# %%
from tensorflow.keras.models import load_model
model = load_model(model_path + '2023.10.15_text_model.keras')
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 15 variables whereas the saved optimizer has 1 variables.

# %%
from tensorflow.keras import utils
utils.plot_model(model, show_shapes=True, dpi=50)

# %% [markdown]
# ### Тестирование модели нейронной сети на проверочной выборке

# %%
dataset_shapes(dataset)
# Out:
# --- Выборка train ---
# Вход 1: (120507,)
# Выход 1: (120507,)
#
# --- Выборка val ---
# Вход 1: (30127,)
# Выход 1: (30127,)

# %%
print(dataset_prediction(dataset, model))
# Out:
# 1/1 [==============================] - 0s 65ms/step
#
# Правда: Целевой, Предсказание: Целевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Целевой, Предсказание: Целевой
# Правда: Целевой, Предсказание: Целевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Целевой, Предсказание: Целевой
# Правда: Целевой, Предсказание: Целевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Целевой, Предсказание: Целевой
#
# 100.00%

# %%
print(dataset_prediction(dataset, model, 30127, 0))
# Out:
# 942/942 [==============================] - 87s 92ms/step
#
# 99.87%

# %% [markdown]
# ### Тестирование модели нейронной сети на новых звонках Headliner

# %% [markdown]
# #### Создание тестового датасета

# %%
# Загрузка датафрейма
with open(df_path + 'Headliner_new_df.pkl', 'rb') as f:
  Headliner_new_df = pkl.load(f)

# %%
Headliner_new_df.shape
# Out:
# (1542, 78)

# %%
# Создаём каталоги для тестового датасета
os.makedirs('Тест', exist_ok=True)
os.makedirs('Тест/Целевой', exist_ok=True)
os.makedirs('Тест/Нецелевой', exist_ok=True)

# %%
Headliner_new_df['Текст whisper-транскрибации записи звонка'][Headliner_new_df['Файл записи звонка'] != 'нет файла'].count()
# Out:
# 1226

# %%
Headliner_new_df['Текст whisper-транскрибации записи звонка'][Headliner_new_df['Файл записи звонка'] != 'нет файла'][Headliner_new_df['Класс'] == 'Целевой'].count()
# Out:
# 194

# %%
Headliner_new_df['Текст whisper-транскрибации записи звонка'][Headliner_new_df['Файл записи звонка'] != 'нет файла'][Headliner_new_df['Класс'] != 'Целевой'].count()
# Out:
# 1032

# %%
# Записываем текстовые файлы
Headliner_new_df['Текст whisper-транскрибации записи звонка'][Headliner_new_df['Файл записи звонка'] != 'нет файла'][Headliner_new_df['Класс'] == 'Целевой'].to_csv('Тест/Целевой/targets.txt', index=False, header=None)
Headliner_new_df['Текст whisper-транскрибации записи звонка'][Headliner_new_df['Файл записи звонка'] != 'нет файла'][Headliner_new_df['Класс'] != 'Целевой'].to_csv('Тест/Нецелевой/not_targets.txt', index=False, header=None)

# %%
# Установка terra-ai-datasets-framework
# %%capture
# !pip install terra-ai-datasets-framework

# %%
from terra_ai_datasets.create import TextClassification

# %%
test_dataset = TextClassification(
    source_path=['Тест'],
    train_size=0.1,
    max_words_count=20000,
    mode='Length and step',
    preprocessing='None',
    length=100,
    step=10,
    one_hot_encoding=False,
    pymorphy=False
    )
# Out:
# 15:14:24 | Датасет подготовлен к началу формирования массивов
# INFO:terra_ai_datasets.creation.utils:Датасет подготовлен к началу формирования массивов

# %%
test_dataset.visualize()
# Out:
# Класс: Нецелевой
# 'плане установки фасадов инженерии и так далее Ага но это все с этими с фасадами с панелями с фасадами да Да А там как там это там какие окна это как бы какая там конструкция архитектура Там окна они не панорамные они увеличены окна они там практически от стены до стены идут только но от стены а от пола они начинаются в детском районе сантиметров 60 65 вот находится Сколько там подъездов Подъездов Да или как там архитектуру называют Ну в этом доме получается там 4 подъезда идут вот эта квартира находится во втором подъезде получается И там подземный парк'
# Класс: Целевой
# 'там да Да но я так понимаю что корпус еще не построен же правильно В этом корпусе уже монолитные работы практически полностью завершены То есть там 51 этаж уже полностью построен Там сейчас идут работы по фасадам по инженерии внутри корпуса двери ставят и так далее Вот это Но лифты же не запущены мы же не пойдем с вами на 51 этаж посмотреть Ну вот А я вам я сейчас могу уточнить Смотрите какая ситуация у нас Вообще в принципе проход на стройку вот он пока вообще как бы ну для клиентов для нас самих он тоже запрещен Турецкие подрядчики'

# %%
test_dataset.summary()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1_Text  \
# 0  кодов ничего не надо да Нет у меня все в открытом доступе Да конечно Хорошо спасибо Вся информация с вами направляю спасибо Хорошо Здравствуйте вы позвонили в группу компании Картрос Благодарим вас за звонок Пожалуйста дождитесь ответа оператора Добрый день вы по компании Картрос Меня зовут Любовь Здравствуйте девушка Я вот хотела бы у вас проконфиденцироваться по поводу покупки квартиры Смотрите я вас задела в рабочей консультации с нашим менеджером Оставайтесь на линии Как могу вас представить Как вас зовут Ксения Минуту Ксения в данный момент линия дела занята С вами свяжется первый освободившийся менеджер Ожидайте Да хорошо спасибо Всего
# 1                                                                                                                 по этажам Повыше вот эта 22 миллиона она по этажу идет на 13 этаже а всего в доме 14 этажей То есть дом такой более скажем так компактный малоэтажный идет Вот а есть и квартиры еще побольше по площади 47 метров Это уже такие как евро двухкомнатные Там большая кухня гостиная идет в районе 20 метров и отдельная спальня Вот и квартира будет находиться на высоком уже этаже на 39 м Соответственно из окна будет открываться уже немного другой вид Там в том числе на Ревку на Филевский парк на Парк Победы Вот цена уже будет стоить ближе к 23
# 2                                                                                              это будет 1 2 процента это не будет какой то весомой прям разницы в цене то что я у вас вручиваю Я понял Я вас Да по тем квартирам да не проходит ипотека семейная А вы не хотите в тём причина студия маленькая не хочется Мне сейчас да старина 30 квадратных метров но такие деньги как то руками поднимаются Я знаю комплексы он напротив нас продаёт 17 5 квадратных метров студии Я понял Смотря для каких целей вы для жизни или инвестировать хотите Инвестировать Инвестировать ну мне кажется для инвестора это неплохой вариант Может быть по бюджету вы не готовы
# 3                                                                                                             которые будут вводиться в эксплуатацию во втором квартале 24 го года Ну вот это максимально второй квартал 24 го А так вообще в целом какие пожелания Может быть по этажу там больше высокий этаж видовой Нет наоборот высокий этаж но не первый и второй а третий Ну в общем не только Наносок надо будет С третьего по пятый С третьего по пятый А вы о нашем проекте хотя бы какой то информацией может быть уже обладаете В интернете может быть видели Нет ничего не обладаю Я вот именно что хочу чтобы посмотреть что у вас там вообще такое Смотрите я
# 4                                                                         то номер корпуса может быть Вот у меня только 39 блин Что то сам здесь не понятно Сейчас посмотрим секундочку сейчас тоже поищу секунду Секунду Так 23 этаж да есть такая квартира да 41 метра она практически по площади ее цена 2454 Вот это окончательная стоимость этой квартиры тоже продается да по переслупке от нашего инвестора от Фирзельца Так получается она у меня получается программа а ипотека Ипотека да она у нас в сети Тогда по ней невозможно будет дойти ипотека Потому что от инвестора нужен именно застройщик правильно я понимаю Да да да То есть если вот застройщик то
#
#   2_Classification
# 0       Нецелевой
# 1         Целевой
# 2       Нецелевой
# 3         Целевой
# 4         Целевой
# Кол-во примеров в train выборке: 2212
# Кол-во примеров в val выборке: 19910
#
# Список классов и количество примеров:
#        Нецелевой  Целевой
# train        1236       976
# val         11289      8621

# %%
test_dataset.create(use_generator=False)
# Out:
# 15:18:54 | Формирование массивов train - Text - 1_Text: 100%|██████████| 2212/2212 [00:00<00:00, 7525.01it/s]
# 15:18:54 | Формирование массивов train - Classification - 2_Classification: 100%|██████████| 2212/2212 [00:00<00:00, 7452.42it/s]
# 15:18:55 | Формирование массивов val - Text - 1_Text: 100%|██████████| 19910/19910 [00:02<00:00, 7675.50it/s]
# 15:18:58 | Формирование массивов val - Classification - 2_Classification: 100%|██████████| 19910/19910 [00:02<00:00, 7547.85it/s]

# %% [markdown]
# #### Тестирование

# %%
dataset_shapes(test_dataset)
# Out:
# --- Выборка train ---
# Вход 1: (2212,)
# Выход 1: (2212,)
#
# --- Выборка val ---
# Вход 1: (19910,)
# Выход 1: (19910,)

# %%
print(dataset_prediction(test_dataset, model))
# Out:
# 1/1 [==============================] - 0s 452ms/step
#
# Правда: Нецелевой, Предсказание: Целевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Целевой, Предсказание: Нецелевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Нецелевой, Предсказание: Нецелевой
# Правда: Целевой, Предсказание: Целевой
#
# 80.00%

# %%
print(dataset_prediction(test_dataset, model, 19910, 0))
# Out:
# 623/623 [==============================] - 61s 97ms/step
#
# 70.52%

# %% [markdown]
# ## [Новые записи звонков](https://drive.google.com/drive/folders/11aY9qpv301UnBuYvG8Iap1-Od28sQdMH?usp=sharing)

# %%
# Новые записи звонков
os.listdir(new_dataset_path)
# Out:
# ['Записи Headliner',
#  'Записи Primavera',
#  'Записи Павелецкая сити',
#  'Информация о звонках']

# %% [markdown]
# ### Распаковка архивов и первичный анализ

# %%
# Установка unrar
# !pip install unrar
# Out:
# Collecting unrar
#   Downloading unrar-0.4-py3-none-any.whl (25 kB)
# Installing collected packages: unrar
# Successfully installed unrar-0.4

# %%
# Архивы новых записей звонков
os.listdir(new_dataset_rar_path)
# Out:
# ['Записи Headliner.rar', 'Записи Primavera.rar', 'Записи Павелецкая сити.rar']

# %%
# Распаковка 'Записи Headliner.rar'
# !unrar x '/content/drive/MyDrive/media108.ru/Новые записи звонков (rar)/Записи Headliner.rar' '/content/drive/MyDrive/media108.ru/Новые записи звонков/' > /dev/null

# %%
# Распаковка 'Записи Primavera.rar'
# !unrar x '/content/drive/MyDrive/media108.ru/Новые записи звонков (rar)/Записи Primavera.rar' '/content/drive/MyDrive/media108.ru/Новые записи звонков/' > /dev/null

# %%
# Распаковка 'Записи Павелецкая сити.rar'
# !unrar x '/content/drive/MyDrive/media108.ru/Новые записи звонков (rar)/Записи Павелецкая сити.rar' '/content/drive/MyDrive/media108.ru/Новые записи звонков/' > /dev/null

# %%
# Новые записи звонков
os.listdir(new_dataset_path)
# Out:
# ['Записи Headliner',
#  'Записи Primavera',
#  'Записи Павелецкая сити',
#  'Информация о звонках']

# %%
# Записи Headliner
os.listdir(new_dataset_path + 'Записи Headliner')[:10]
# Out:
# ['2023-09-26_10-06-23.403699_from_79584153294_to_74959339902_session_3252459256_talk.mp3',
#  '2023-09-21_18-54-50.120569_from_79951538090_to_0188880_session_3235156678_talk.mp3',
#  '2023-09-27_16-10-52.316459_from_79853697070_to_0188880_session_3253840089_talk.mp3',
#  '2023-09-25_09-12-02.428401_from_79858141531_to_74959339902_session_3249639806_talk.mp3',
#  '2023-09-28_11-08-32.052586_from_79851881681_to_74959339902_session_3262172387_talk.mp3',
#  '2023-09-26_14-03-03.889896_from_79164117555_to_74959339902_session_3237804050_talk.mp3',
#  '2023-09-22_15-05-38.848815_from_79608617626_to_0188880_session_3243154724_talk.mp3',
#  '2023-09-22_15-47-29.153917_from_79169869883_to_74959339902_session_3231248615_talk.mp3',
#  '2023-09-25_15-33-38.734417_from_79025578055_to_74959339902_session_3251147526_talk.mp3',
#  '2023-09-27_16-24-56.511269_from_79166279057_to_74959339902_session_3253891649_talk.mp3']

# %%
# Записи Primavera
os.listdir(new_dataset_path + 'Записи Primavera')[:10]
# Out:
# ['2023-09-30_12-19-55.312627_from_79854305902_to_0253192_session_3263012391_talk.mp3',
#  '2023-10-04_19-40-25.037187_from_74950210291_to_0253206_session_3276780397_talk.mp3',
#  '2023-10-04_15-52-11.200324_from_79203810871_to_0253201_session_3276172302_talk.mp3',
#  '2023-10-02_20-00-47.312686_from_74950210291_to_0150113_session_3271743567_talk.mp3',
#  '2023-10-04_16-50-31.267655_from_79295237177_to_0111652_session_3269469074_talk.mp3',
#  '2023-09-30_15-31-41.654688_from_79939041290_to_0253192_session_3263409766_talk.mp3',
#  '2023-10-04_14-14-24.774719_from_74951201251_to_0253206_session_3268896004_talk.mp3',
#  '2023-10-04_10-51-34.713659_from_79154098258_to_0111631_session_3262644468_talk.mp3',
#  '2023-10-03_16-27-25.589891_from_79269050076_to_0253200_session_3251740160_talk.mp3',
#  '2023-10-04_13-48-28.199593_from_79250269006_to_0111651_session_3271685686_talk.mp3']

# %%
# Записи Павелецкая сити
os.listdir(new_dataset_path + 'Записи Павелецкая сити')[:10]
# Out:
# ['2023-09-18_11-48-26.391636_from_74932482450_to_00288_session_3219964480_talk.mp3',
#  '2023-09-18_12-54-18.603506_from_79160620083_to_00288_session_3220199190_talk.mp3',
#  '2023-09-20_09-56-40.872148_from_905424768475_to_00288_session_3237457931_talk.mp3',
#  '2023-09-19_13-53-47.892984_from_79037861965_to_00288_session_3222616640_talk.mp3',
#  '2023-09-18_12-31-27.901544_from_79099465930_to_00288_session_3230778649_talk.mp3',
#  '2023-09-17_17-31-02.604192_from_79165656567_to_00288_session_3225012783_talk.mp3',
#  '2023-09-18_17-14-07.670764_from_79264028168_to_00288_session_3231837499_talk.mp3',
#  '2023-09-17_15-30-32.547936_from_79033154042_to_00288_session_3218794065_talk.mp3',
#  '2023-09-18_10-27-52.597249_from_79035129646_to_00288_session_3232383306_talk.mp3',
#  '2023-09-16_17-35-42.402838_from_79607558395_to_00288_session_3230248941_talk.mp3']

# %%
# Новые записи звонков
print(f"      Headliner: {len(os.listdir(new_dataset_path + 'Записи Headliner')):4d} записей")
print(f"      Primavera: {len(os.listdir(new_dataset_path + 'Записи Primavera')):4d} записей")
print(f"Павелецкая сити: {len(os.listdir(new_dataset_path + 'Записи Павелецкая сити')):4d} записей")
# Out:
#       Headliner: 1226 записей
#       Primavera:  767 записей
# Павелецкая сити: 1413 записей

# %% [markdown]
# ### Headliner

# %% [markdown]
# #### Создание датафрейма

# %%
# Создаём датафрейм из списка записей звонков
Headliner_calls_df = calls_list_to_df(os.listdir(new_dataset_path + 'Записи Headliner'))
Headliner_calls_df.shape
# Out:
# (1226, 5)

# %%
Headliner_calls_df.head()
# Out:
#           Дата и время Номер абонента Номер сотрудника  \
# 0  2023-09-26 10:06:23    79584153294      74959339902
# 1  2023-09-21 18:54:50    79951538090          0188880
# 2  2023-09-27 16:10:52    79853697070          0188880
# 3  2023-09-25 09:12:02    79858141531      74959339902
# 4  2023-09-28 11:08:32    79851881681      74959339902
#
#   Идентификатор сессии звонка  \
# 0                  3252459256
# 1                  3235156678
# 2                  3253840089
# 3                  3249639806
# 4                  3262172387
#
#                                                                        Файл записи звонка
# 0  2023-09-26_10-06-23.403699_from_79584153294_to_74959339902_session_3252459256_talk.mp3
# 1      2023-09-21_18-54-50.120569_from_79951538090_to_0188880_session_3235156678_talk.mp3
# 2      2023-09-27_16-10-52.316459_from_79853697070_to_0188880_session_3253840089_talk.mp3
# 3  2023-09-25_09-12-02.428401_from_79858141531_to_74959339902_session_3249639806_talk.mp3
# 4  2023-09-28_11-08-32.052586_from_79851881681_to_74959339902_session_3262172387_talk.mp3

# %%
# Проверяем количество строк
print(len(os.listdir(new_dataset_path + 'Записи Headliner')))
print(Headliner_calls_df.shape[0])
# Out:
# 1226
# 1226

# %%
print(Headliner_calls_df.count())
# Out:
# Дата и время                   1226
# Номер абонента                 1226
# Номер сотрудника               1226
# Идентификатор сессии звонка    1226
# Файл записи звонка             1226
# dtype: int64

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Дата и время

# %%
Headliner_calls_df['Дата и время'].head()
# Out:
# 0    2023-09-26 10:06:23
# 1    2023-09-21 18:54:50
# 2    2023-09-27 16:10:52
# 3    2023-09-25 09:12:02
# 4    2023-09-28 11:08:32
# Name: Дата и время, dtype: object

# %%
# Приводим тип данных столбца 'Дата и время'
Headliner_calls_df['Дата и время'] = pd.to_datetime(Headliner_calls_df['Дата и время'])

# %%
Headliner_calls_df['Дата и время'].tail()
# Out:
# 1221   2023-09-25 20:22:45
# 1222   2023-09-27 15:04:39
# 1223   2023-09-26 15:17:11
# 1224   2023-09-26 11:33:50
# 1225   2023-09-23 11:18:02
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 1. Номер абонента

# %%
Headliner_calls_df['Номер абонента'].head()
# Out:
# 0    79584153294
# 1    79951538090
# 2    79853697070
# 3    79858141531
# 4    79851881681
# Name: Номер абонента, dtype: object

# %%
# Приводим тип данных столбца 'Номер абонента'
Headliner_calls_df = Headliner_calls_df.astype({'Номер абонента': int})

# %%
Headliner_calls_df['Номер абонента'].tail()
# Out:
# 1221    79039077310
# 1222    79964425592
# 1223    79199453103
# 1224    79264649878
# 1225    79224128180
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 2. Номер сотрудника

# %%
Headliner_calls_df['Номер сотрудника'].head()
# Out:
# 0    74959339902
# 1        0188880
# 2        0188880
# 3    74959339902
# 4    74959339902
# Name: Номер сотрудника, dtype: object

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Headliner_calls_df = Headliner_calls_df.astype({'Номер сотрудника': int})

# %%
Headliner_calls_df['Номер сотрудника'].tail()
# Out:
# 1221    74959339902
# 1222    74959339902
# 1223         188880
# 1224    74959339902
# 1225         188880
# Name: Номер сотрудника, dtype: int64

# %% [markdown]
# ##### 3. Идентификатор сессии звонка

# %%
Headliner_calls_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3252459256
# 1    3235156678
# 2    3253840089
# 3    3249639806
# 4    3262172387
# Name: Идентификатор сессии звонка, dtype: object

# %%
# Приводим тип данных столбца 'Идентификатор сессии звонка'
Headliner_calls_df = Headliner_calls_df.astype({'Идентификатор сессии звонка': int})

# %%
Headliner_calls_df['Идентификатор сессии звонка'].tail()
# Out:
# 1221    3244316548
# 1222    3240209630
# 1223    3246045878
# 1224    3245199518
# 1225    3251344342
# Name: Идентификатор сессии звонка, dtype: int64

# %%
# Смотрим количество уникальных значений столбца 'Идентификатор сессии звонка'
Headliner_calls_df['Идентификатор сессии звонка'].nunique()
# Out:
# 1226

# %% [markdown]
# ##### 4. Файл записи звонка

# %%
Headliner_calls_df['Файл записи звонка'].head()
# Out:
# 0    2023-09-26_10-06-23.403699_from_79584153294_to_74959339902_session_3252459256_talk.mp3
# 1        2023-09-21_18-54-50.120569_from_79951538090_to_0188880_session_3235156678_talk.mp3
# 2        2023-09-27_16-10-52.316459_from_79853697070_to_0188880_session_3253840089_talk.mp3
# 3    2023-09-25_09-12-02.428401_from_79858141531_to_74959339902_session_3249639806_talk.mp3
# 4    2023-09-28_11-08-32.052586_from_79851881681_to_74959339902_session_3262172387_talk.mp3
# Name: Файл записи звонка, dtype: object

# %%
# Добавляем к файлам относительные пути
Headliner_calls_df['Файл записи звонка'] = Headliner_calls_df['Файл записи звонка'].apply(lambda x: 'Новые записи звонков/Записи Headliner/' + x)

# %%
Headliner_calls_df['Файл записи звонка'].tail()
# Out:
# 1221    Новые записи звонков/Записи Headliner/2023-09-25_20-22-45.880054_from_79039077310_to_74959339902_session_3244316548_talk.mp3
# 1222    Новые записи звонков/Записи Headliner/2023-09-27_15-04-39.742280_from_79964425592_to_74959339902_session_3240209630_talk.mp3
# 1223        Новые записи звонков/Записи Headliner/2023-09-26_15-17-11.305534_from_79199453103_to_0188880_session_3246045878_talk.mp3
# 1224    Новые записи звонков/Записи Headliner/2023-09-26_11-33-50.933882_from_79264649878_to_74959339902_session_3245199518_talk.mp3
# 1225        Новые записи звонков/Записи Headliner/2023-09-23_11-18-02.353443_from_79224128180_to_0188880_session_3251344342_talk.mp3
# Name: Файл записи звонка, dtype: object

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Headliner_calls_df.dtypes
# Out:
# Дата и время                   datetime64[ns]
# Номер абонента                          int64
# Номер сотрудника                        int64
# Идентификатор сессии звонка             int64
# Файл записи звонка                     object
# dtype: object

# %%
print(Headliner_calls_df.count())
# Out:
# Дата и время                   1226
# Номер абонента                 1226
# Номер сотрудника               1226
# Идентификатор сессии звонка    1226
# Файл записи звонка             1226
# dtype: int64

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Headliner_calls_df в файл
with open(df_path + 'Headliner_new_calls_df.pkl', 'wb') as f:
  pkl.dump(Headliner_calls_df, f)

# %% [markdown]
# ### Primavera

# %% [markdown]
# #### Создание датафрейма

# %%
# Создаём датафрейм из списка записей звонков
Primavera_calls_df = calls_list_to_df(os.listdir(new_dataset_path + 'Записи Primavera'))
Primavera_calls_df.shape
# Out:
# (767, 5)

# %%
Primavera_calls_df.head()
# Out:
#           Дата и время Номер абонента Номер сотрудника  \
# 0  2023-09-30 12:19:55    79854305902          0253192
# 1  2023-10-04 19:40:25    74950210291          0253206
# 2  2023-10-04 15:52:11    79203810871          0253201
# 3  2023-10-02 20:00:47    74950210291          0150113
# 4  2023-10-04 16:50:31    79295237177          0111652
#
#   Идентификатор сессии звонка  \
# 0                  3263012391
# 1                  3276780397
# 2                  3276172302
# 3                  3271743567
# 4                  3269469074
#
#                                                                    Файл записи звонка
# 0  2023-09-30_12-19-55.312627_from_79854305902_to_0253192_session_3263012391_talk.mp3
# 1  2023-10-04_19-40-25.037187_from_74950210291_to_0253206_session_3276780397_talk.mp3
# 2  2023-10-04_15-52-11.200324_from_79203810871_to_0253201_session_3276172302_talk.mp3
# 3  2023-10-02_20-00-47.312686_from_74950210291_to_0150113_session_3271743567_talk.mp3
# 4  2023-10-04_16-50-31.267655_from_79295237177_to_0111652_session_3269469074_talk.mp3

# %%
# Проверяем количество строк
print(len(os.listdir(new_dataset_path + 'Записи Primavera')))
print(Primavera_calls_df.shape[0])
# Out:
# 767
# 767

# %%
print(Primavera_calls_df.count())
# Out:
# Дата и время                   767
# Номер абонента                 767
# Номер сотрудника               767
# Идентификатор сессии звонка    767
# Файл записи звонка             767
# dtype: int64

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Дата и время

# %%
Primavera_calls_df['Дата и время'].head()
# Out:
# 0    2023-09-30 12:19:55
# 1    2023-10-04 19:40:25
# 2    2023-10-04 15:52:11
# 3    2023-10-02 20:00:47
# 4    2023-10-04 16:50:31
# Name: Дата и время, dtype: object

# %%
# Приводим тип данных столбца 'Дата и время'
Primavera_calls_df['Дата и время'] = pd.to_datetime(Primavera_calls_df['Дата и время'])

# %%
Primavera_calls_df['Дата и время'].tail()
# Out:
# 762   2023-09-03 16:24:54
# 763   2023-09-02 17:12:27
# 764   2023-09-03 15:19:38
# 765   2023-09-02 17:49:06
# 766   2023-09-01 12:35:50
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 1. Номер абонента

# %%
Primavera_calls_df['Номер абонента'].head()
# Out:
# 0    79854305902
# 1    74950210291
# 2    79203810871
# 3    74950210291
# 4    79295237177
# Name: Номер абонента, dtype: object

# %%
# Приводим тип данных столбца 'Номер абонента'
Primavera_calls_df = Primavera_calls_df.astype({'Номер абонента': int})

# %%
Primavera_calls_df['Номер абонента'].tail()
# Out:
# 762    74991918588
# 763    79296548451
# 764    79167387714
# 765    74950210291
# 766    79776807507
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 2. Номер сотрудника

# %%
Primavera_calls_df['Номер сотрудника'].head()
# Out:
# 0    0253192
# 1    0253206
# 2    0253201
# 3    0150113
# 4    0111652
# Name: Номер сотрудника, dtype: object

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Primavera_calls_df = Primavera_calls_df.astype({'Номер сотрудника': int})

# %%
Primavera_calls_df['Номер сотрудника'].tail()
# Out:
# 762    150108
# 763    253208
# 764    111642
# 765    111639
# 766    253211
# Name: Номер сотрудника, dtype: int64

# %% [markdown]
# ##### 3. Идентификатор сессии звонка

# %%
Primavera_calls_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3263012391
# 1    3276780397
# 2    3276172302
# 3    3271743567
# 4    3269469074
# Name: Идентификатор сессии звонка, dtype: object

# %%
# Приводим тип данных столбца 'Идентификатор сессии звонка'
Primavera_calls_df = Primavera_calls_df.astype({'Идентификатор сессии звонка': int})

# %%
Primavera_calls_df['Идентификатор сессии звонка'].tail()
# Out:
# 762    3195081143
# 763    3197045974
# 764    3198170594
# 765    3204178922
# 766    3188505725
# Name: Идентификатор сессии звонка, dtype: int64

# %%
# Смотрим количество уникальных значений столбца 'Идентификатор сессии звонка'
Primavera_calls_df['Идентификатор сессии звонка'].nunique()
# Out:
# 767

# %% [markdown]
# ##### 4. Файл записи звонка

# %%
Primavera_calls_df['Файл записи звонка'].head()
# Out:
# 0    2023-09-30_12-19-55.312627_from_79854305902_to_0253192_session_3263012391_talk.mp3
# 1    2023-10-04_19-40-25.037187_from_74950210291_to_0253206_session_3276780397_talk.mp3
# 2    2023-10-04_15-52-11.200324_from_79203810871_to_0253201_session_3276172302_talk.mp3
# 3    2023-10-02_20-00-47.312686_from_74950210291_to_0150113_session_3271743567_talk.mp3
# 4    2023-10-04_16-50-31.267655_from_79295237177_to_0111652_session_3269469074_talk.mp3
# Name: Файл записи звонка, dtype: object

# %%
# Добавляем к файлам относительные пути
Primavera_calls_df['Файл записи звонка'] = Primavera_calls_df['Файл записи звонка'].apply(lambda x: 'Новые записи звонков/Записи Primavera/' + x)

# %%
Primavera_calls_df['Файл записи звонка'].tail()
# Out:
# 762    Новые записи звонков/Записи Primavera/2023-09-03_16-24-54.121808_from_74991918588_to_0150108_session_3195081143_talk.mp3
# 763    Новые записи звонков/Записи Primavera/2023-09-02_17-12-27.813266_from_79296548451_to_0253208_session_3197045974_talk.mp3
# 764    Новые записи звонков/Записи Primavera/2023-09-03_15-19-38.712929_from_79167387714_to_0111642_session_3198170594_talk.mp3
# 765    Новые записи звонков/Записи Primavera/2023-09-02_17-49-06.100800_from_74950210291_to_0111639_session_3204178922_talk.mp3
# 766    Новые записи звонков/Записи Primavera/2023-09-01_12-35-50.915379_from_79776807507_to_0253211_session_3188505725_talk.mp3
# Name: Файл записи звонка, dtype: object

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Primavera_calls_df.dtypes
# Out:
# Дата и время                   datetime64[ns]
# Номер абонента                          int64
# Номер сотрудника                        int64
# Идентификатор сессии звонка             int64
# Файл записи звонка                     object
# dtype: object

# %%
print(Primavera_calls_df.count())
# Out:
# Дата и время                   767
# Номер абонента                 767
# Номер сотрудника               767
# Идентификатор сессии звонка    767
# Файл записи звонка             767
# dtype: int64

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Primavera_calls_df в файл
with open(df_path + 'Primavera_new_calls_df.pkl', 'wb') as f:
  pkl.dump(Primavera_calls_df, f)

# %% [markdown]
# ### Paveletskaya_city

# %% [markdown]
# #### Создание датафрейма

# %%
# Создаём датафрейм из списка записей звонков
Paveletskaya_city_calls_df = calls_list_to_df(os.listdir(new_dataset_path + 'Записи Павелецкая сити'))
Paveletskaya_city_calls_df.shape
# Out:
# (1413, 5)

# %%
Paveletskaya_city_calls_df.head()
# Out:
#           Дата и время Номер абонента Номер сотрудника  \
# 0  2023-09-18 11:48:26    74932482450            00288
# 1  2023-09-18 12:54:18    79160620083            00288
# 2  2023-09-20 09:56:40   905424768475            00288
# 3  2023-09-19 13:53:47    79037861965            00288
# 4  2023-09-18 12:31:27    79099465930            00288
#
#   Идентификатор сессии звонка  \
# 0                  3219964480
# 1                  3220199190
# 2                  3237457931
# 3                  3222616640
# 4                  3230778649
#
#                                                                   Файл записи звонка
# 0   2023-09-18_11-48-26.391636_from_74932482450_to_00288_session_3219964480_talk.mp3
# 1   2023-09-18_12-54-18.603506_from_79160620083_to_00288_session_3220199190_talk.mp3
# 2  2023-09-20_09-56-40.872148_from_905424768475_to_00288_session_3237457931_talk.mp3
# 3   2023-09-19_13-53-47.892984_from_79037861965_to_00288_session_3222616640_talk.mp3
# 4   2023-09-18_12-31-27.901544_from_79099465930_to_00288_session_3230778649_talk.mp3

# %%
# Проверяем количество строк
print(len(os.listdir(new_dataset_path + 'Записи Павелецкая сити')))
print(Paveletskaya_city_calls_df.shape[0])
# Out:
# 1413
# 1413

# %%
print(Paveletskaya_city_calls_df.count())
# Out:
# Дата и время                   1413
# Номер абонента                 1413
# Номер сотрудника               1413
# Идентификатор сессии звонка    1413
# Файл записи звонка             1413
# dtype: int64

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Дата и время

# %%
Paveletskaya_city_calls_df['Дата и время'].head()
# Out:
# 0    2023-09-18 11:48:26
# 1    2023-09-18 12:54:18
# 2    2023-09-20 09:56:40
# 3    2023-09-19 13:53:47
# 4    2023-09-18 12:31:27
# Name: Дата и время, dtype: object

# %%
# Приводим тип данных столбца 'Дата и время'
Paveletskaya_city_calls_df['Дата и время'] = pd.to_datetime(Paveletskaya_city_calls_df['Дата и время'])

# %%
Paveletskaya_city_calls_df['Дата и время'].tail()
# Out:
# 1408   2023-09-18 14:28:39
# 1409   2023-09-18 11:08:55
# 1410   2023-09-21 10:36:24
# 1411   2023-09-21 11:59:49
# 1412   2023-09-18 12:14:11
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 1. Номер абонента

# %%
Paveletskaya_city_calls_df['Номер абонента'].head()
# Out:
# 0     74932482450
# 1     79160620083
# 2    905424768475
# 3     79037861965
# 4     79099465930
# Name: Номер абонента, dtype: object

# %%
Paveletskaya_city_calls_df['Номер абонента'][Paveletskaya_city_calls_df['Номер абонента'] == ''].count()
# Out:
# 1

# %%
# Меняем '' на '0' в столбце 'Номер абонента'
Paveletskaya_city_calls_df['Номер абонента'] = Paveletskaya_city_calls_df['Номер абонента'].apply(lambda x: '0' if x == '' else x)

# %%
# Приводим тип данных столбца 'Номер абонента'
Paveletskaya_city_calls_df = Paveletskaya_city_calls_df.astype({'Номер абонента': int})

# %%
Paveletskaya_city_calls_df['Номер абонента'].tail()
# Out:
# 1408    79646445150
# 1409    79037846520
# 1410    79160206095
# 1411    74954871149
# 1412    79067410826
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 2. Номер сотрудника

# %%
Paveletskaya_city_calls_df['Номер сотрудника'].head()
# Out:
# 0    00288
# 1    00288
# 2    00288
# 3    00288
# 4    00288
# Name: Номер сотрудника, dtype: object

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Paveletskaya_city_calls_df = Paveletskaya_city_calls_df.astype({'Номер сотрудника': int})

# %%
Paveletskaya_city_calls_df['Номер сотрудника'].tail()
# Out:
# 1408    288
# 1409    288
# 1410    288
# 1411    288
# 1412    288
# Name: Номер сотрудника, dtype: int64

# %% [markdown]
# ##### 3. Идентификатор сессии звонка

# %%
Paveletskaya_city_calls_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3219964480
# 1    3220199190
# 2    3237457931
# 3    3222616640
# 4    3230778649
# Name: Идентификатор сессии звонка, dtype: object

# %%
# Приводим тип данных столбца 'Идентификатор сессии звонка'
Paveletskaya_city_calls_df = Paveletskaya_city_calls_df.astype({'Идентификатор сессии звонка': int})

# %%
Paveletskaya_city_calls_df['Идентификатор сессии звонка'].tail()
# Out:
# 1408    3233375546
# 1409    3230415104
# 1410    3240292806
# 1411    3238346979
# 1412    3230568859
# Name: Идентификатор сессии звонка, dtype: int64

# %%
# Смотрим количество уникальных значений столбца 'Идентификатор сессии звонка'
Paveletskaya_city_calls_df['Идентификатор сессии звонка'].nunique()
# Out:
# 1413

# %% [markdown]
# ##### 4. Файл записи звонка

# %%
Paveletskaya_city_calls_df['Файл записи звонка'].head()
# Out:
# 0     2023-09-18_11-48-26.391636_from_74932482450_to_00288_session_3219964480_talk.mp3
# 1     2023-09-18_12-54-18.603506_from_79160620083_to_00288_session_3220199190_talk.mp3
# 2    2023-09-20_09-56-40.872148_from_905424768475_to_00288_session_3237457931_talk.mp3
# 3     2023-09-19_13-53-47.892984_from_79037861965_to_00288_session_3222616640_talk.mp3
# 4     2023-09-18_12-31-27.901544_from_79099465930_to_00288_session_3230778649_talk.mp3
# Name: Файл записи звонка, dtype: object

# %%
# Добавляем к файлам относительные пути
Paveletskaya_city_calls_df['Файл записи звонка'] = Paveletskaya_city_calls_df['Файл записи звонка'].apply(lambda x: 'Новые записи звонков/Записи Павелецкая сити/' + x)

# %%
Paveletskaya_city_calls_df['Файл записи звонка'].tail()
# Out:
# 1408    Новые записи звонков/Записи Павелецкая сити/2023-09-18_14-28-39.076451_from_79646445150_to_00288_session_3233375546_talk.mp3
# 1409    Новые записи звонков/Записи Павелецкая сити/2023-09-18_11-08-55.388293_from_79037846520_to_00288_session_3230415104_talk.mp3
# 1410    Новые записи звонков/Записи Павелецкая сити/2023-09-21_10-36-24.096708_from_79160206095_to_00288_session_3240292806_talk.mp3
# 1411    Новые записи звонков/Записи Павелецкая сити/2023-09-21_11-59-49.268642_from_74954871149_to_00288_session_3238346979_talk.mp3
# 1412    Новые записи звонков/Записи Павелецкая сити/2023-09-18_12-14-11.254019_from_79067410826_to_00288_session_3230568859_talk.mp3
# Name: Файл записи звонка, dtype: object

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Paveletskaya_city_calls_df.dtypes
# Out:
# Дата и время                   datetime64[ns]
# Номер абонента                          int64
# Номер сотрудника                        int64
# Идентификатор сессии звонка             int64
# Файл записи звонка                     object
# dtype: object

# %%
print(Paveletskaya_city_calls_df.count())
# Out:
# Дата и время                   1413
# Номер абонента                 1413
# Номер сотрудника               1413
# Идентификатор сессии звонка    1413
# Файл записи звонка             1413
# dtype: int64

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Paveletskaya_city_calls_df в файл
with open(df_path + 'Paveletskaya_city_new_calls_df.pkl', 'wb') as f:
  pkl.dump(Paveletskaya_city_calls_df, f)

# %% [markdown]
# ## [Whisper-транскрибация новых записей звонков](https://drive.google.com/drive/folders/1nkaIhMxJTazZ74SuNvUvr5lNAHfYKtPv?usp=drive_link)

# %%
os.listdir(new_transcription_path)
# Out:
# ['Расшифровки_Записи Headliner',
#  'Расшифровки_Записи Primavera',
#  'Расшифровки_Записи Павелецкая сити']

# %%
print(f"        Headliner: {len(os.listdir(new_transcription_path + 'Расшифровки_Записи Headliner')):4d} записей")
print(f"        Primavera: {len(os.listdir(new_transcription_path + 'Расшифровки_Записи Primavera')):4d} записей")
print(f"Paveletskaya_city: {len(os.listdir(new_transcription_path + 'Расшифровки_Записи Павелецкая сити')):4d} записей")
# Out:
#         Headliner: 1226 записей
#         Primavera:  767 записей
# Paveletskaya_city: 1413 записей

# %% [markdown]
# ### Headliner

# %% [markdown]
# #### Создание датафрейма

# %%
# Создаём датафрейм из списка файлов транскрибации звонков Headliner
Headliner_transcriptions_df = transcriptions_list_to_df(os.listdir(new_transcription_path + 'Расшифровки_Записи Headliner'))
Headliner_transcriptions_df.shape
# Out:
# (1226, 5)

# %%
Headliner_transcriptions_df.head()
# Out:
#           Дата и время Номер абонента Номер сотрудника  \
# 0  2023-09-01 11:18:46    79133420036          0188880
# 1  2023-09-01 12:07:24    79687467064      74959339929
# 2  2023-09-01 12:10:00    79687467064      74959339929
# 3  2023-09-01 12:20:37    79851620909      74959339929
# 4  2023-09-01 12:53:13    74959891229      74959339929
#
#   Идентификатор сессии звонка  \
# 0                  3188273510
# 1                  3188426705
# 2                  3201544602
# 3                  3188461175
# 4                  3191589263
#
#                                                  Файл whisper-транскрибации записи звонка
# 0      2023-09-01_11-18-46.243226_from_79133420036_to_0188880_session_3188273510_talk.txt
# 1  2023-09-01_12-07-24.419439_from_79687467064_to_74959339929_session_3188426705_talk.txt
# 2  2023-09-01_12-10-00.806885_from_79687467064_to_74959339929_session_3201544602_talk.txt
# 3  2023-09-01_12-20-37.789876_from_79851620909_to_74959339929_session_3188461175_talk.txt
# 4  2023-09-01_12-53-13.411858_from_74959891229_to_74959339929_session_3191589263_talk.txt

# %%
# Проверяем количество строк
print(len(os.listdir(new_transcription_path + 'Расшифровки_Записи Headliner')))
print(Headliner_transcriptions_df.shape[0])
# Out:
# 1226
# 1226

# %%
print(Headliner_transcriptions_df.count())
# Out:
# Дата и время                                1226
# Номер абонента                              1226
# Номер сотрудника                            1226
# Идентификатор сессии звонка                 1226
# Файл whisper-транскрибации записи звонка    1226
# dtype: int64

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Дата и время

# %%
Headliner_transcriptions_df['Дата и время'].head()
# Out:
# 0    2023-09-01 11:18:46
# 1    2023-09-01 12:07:24
# 2    2023-09-01 12:10:00
# 3    2023-09-01 12:20:37
# 4    2023-09-01 12:53:13
# Name: Дата и время, dtype: object

# %%
# Приводим тип данных столбца 'Дата и время'
Headliner_transcriptions_df['Дата и время'] = pd.to_datetime(Headliner_transcriptions_df['Дата и время'])

# %%
Headliner_transcriptions_df['Дата и время'].tail()
# Out:
# 1221   2023-08-31 16:55:42
# 1222   2023-08-31 17:01:20
# 1223   2023-08-31 17:08:06
# 1224   2023-09-01 09:30:00
# 1225   2023-09-01 10:09:28
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 1. Номер абонента

# %%
Headliner_transcriptions_df['Номер абонента'].head()
# Out:
# 0    79133420036
# 1    79687467064
# 2    79687467064
# 3    79851620909
# 4    74959891229
# Name: Номер абонента, dtype: object

# %%
# Приводим тип данных столбца 'Номер абонента'
Headliner_transcriptions_df = Headliner_transcriptions_df.astype({'Номер абонента': int})

# %%
Headliner_transcriptions_df['Номер абонента'].tail()
# Out:
# 1221    79851400618
# 1222    79851400618
# 1223    79647068969
# 1224    79503046153
# 1225    79687467064
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 2. Номер сотрудника

# %%
Headliner_transcriptions_df['Номер сотрудника'].head()
# Out:
# 0        0188880
# 1    74959339929
# 2    74959339929
# 3    74959339929
# 4    74959339929
# Name: Номер сотрудника, dtype: object

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Headliner_transcriptions_df = Headliner_transcriptions_df.astype({'Номер сотрудника': int})

# %%
Headliner_transcriptions_df['Номер сотрудника'].tail()
# Out:
# 1221         188880
# 1222    74959339929
# 1223    74957898990
# 1224         188880
# 1225    74959339929
# Name: Номер сотрудника, dtype: int64

# %% [markdown]
# ##### 3. Идентификатор сессии звонка

# %%
Headliner_transcriptions_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3188273510
# 1    3188426705
# 2    3201544602
# 3    3188461175
# 4    3191589263
# Name: Идентификатор сессии звонка, dtype: object

# %%
# Приводим тип данных столбца 'Идентификатор сессии звонка'
Headliner_transcriptions_df = Headliner_transcriptions_df.astype({'Идентификатор сессии звонка': int})

# %%
Headliner_transcriptions_df['Идентификатор сессии звонка'].tail()
# Out:
# 1221    3190201298
# 1222    3194695301
# 1223    3187322885
# 1224    3201040552
# 1225    3191076973
# Name: Идентификатор сессии звонка, dtype: int64

# %%
# Смотрим количество уникальных значений столбца 'Идентификатор сессии звонка'
Headliner_transcriptions_df['Идентификатор сессии звонка'].nunique()
# Out:
# 1226

# %% [markdown]
# ##### 4. Файл whisper-транскрибации записи звонка

# %%
Headliner_transcriptions_df['Файл whisper-транскрибации записи звонка'].head()
# Out:
# 0        2023-09-01_11-18-46.243226_from_79133420036_to_0188880_session_3188273510_talk.txt
# 1    2023-09-01_12-07-24.419439_from_79687467064_to_74959339929_session_3188426705_talk.txt
# 2    2023-09-01_12-10-00.806885_from_79687467064_to_74959339929_session_3201544602_talk.txt
# 3    2023-09-01_12-20-37.789876_from_79851620909_to_74959339929_session_3188461175_talk.txt
# 4    2023-09-01_12-53-13.411858_from_74959891229_to_74959339929_session_3191589263_talk.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %%
# Добавляем к файлам относительные пути
Headliner_transcriptions_df['Файл whisper-транскрибации записи звонка'] = Headliner_transcriptions_df['Файл whisper-транскрибации записи звонка'].apply(lambda x: 'Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/' + x)

# %%
Headliner_transcriptions_df['Файл whisper-транскрибации записи звонка'].tail()
# Out:
# 1221        Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-08-31_16-55-42.330776_from_79851400618_to_0188880_session_3190201298_talk.txt
# 1222    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-08-31_17-01-20.800209_from_79851400618_to_74959339929_session_3194695301_talk.txt
# 1223    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-08-31_17-08-06.533474_from_79647068969_to_74957898990_session_3187322885_talk.txt
# 1224        Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_09-30-00.917489_from_79503046153_to_0188880_session_3201040552_talk.txt
# 1225    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_10-09-28.491302_from_79687467064_to_74959339929_session_3191076973_talk.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %% [markdown]
# ##### 5. Текст whisper-транскрибации записи звонка

# %%
# Добавляем столбец 'Текст whisper-транскрибации записи звонка'
Headliner_transcriptions_df['Текст whisper-транскрибации записи звонка'] = 'нет текста транскрибации звонка'
Headliner_transcriptions_df.head()
# Out:
#          Дата и время  Номер абонента  Номер сотрудника  \
# 0 2023-09-01 11:18:46     79133420036            188880
# 1 2023-09-01 12:07:24     79687467064       74959339929
# 2 2023-09-01 12:10:00     79687467064       74959339929
# 3 2023-09-01 12:20:37     79851620909       74959339929
# 4 2023-09-01 12:53:13     74959891229       74959339929
#
#    Идентификатор сессии звонка  \
# 0                   3188273510
# 1                   3188426705
# 2                   3201544602
# 3                   3188461175
# 4                   3191589263
#
#                                                                                                                           Файл whisper-транскрибации записи звонка  \
# 0      Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_11-18-46.243226_from_79133420036_to_0188880_session_3188273510_talk.txt
# 1  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_12-07-24.419439_from_79687467064_to_74959339929_session_3188426705_talk.txt
# 2  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_12-10-00.806885_from_79687467064_to_74959339929_session_3201544602_talk.txt
# 3  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_12-20-37.789876_from_79851620909_to_74959339929_session_3188461175_talk.txt
# 4  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_12-53-13.411858_from_74959891229_to_74959339929_session_3191589263_talk.txt
#
#   Текст whisper-транскрибации записи звонка
# 0           нет текста транскрибации звонка
# 1           нет текста транскрибации звонка
# 2           нет текста транскрибации звонка
# 3           нет текста транскрибации звонка
# 4           нет текста транскрибации звонка

# %%
for row in range(Headliner_transcriptions_df.shape[0]):
  with open(all_dataset_path + Headliner_transcriptions_df.loc[row, ['Файл whisper-транскрибации записи звонка']].values[0], 'rb') as f:
    contents = f.read()
  Headliner_transcriptions_df.loc[row, ['Текст whisper-транскрибации записи звонка']] = contents.decode('utf-16').strip()

# %%
Headliner_transcriptions_df['Текст whisper-транскрибации записи звонка'].head()
# Out:
# 0    Здравствуйте, вы позвонили в группу компании «Картро». Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Группа компании «Картро» Статьяна, здравствуйте. Статьяна, здравствуйте. Меня зовут Анжела. Хотела вас уточнить по ЖК «Хоббелайнер». Интересует третья очередь или еще какая-то четвертая, а, вторая очередь. Третья очередь. Квартиры 30 и 40 квадратов. Хорошо, я вас поденю с менеджером. Минуту оставайтесь на линии. Спасибо. Жилой комплекс «Хоббелайнер». Меня зовут Виталия. Здравствуйте. Виталия, здравствуйте. Меня зовут Анжела. По поводу квартиры «Хоббелайнер». Вторая, третья очередь. Интересует квартиры 30 и 40 квадратов. Во второй очереди 30 квадратных метров по проекту не было. Площадь от 40 квадратных метров начиналась. Сейчас минимальный бюджет в построенной второй очереди начинается от 22 миллионов за 43 квадратных метра. Есть варианты с площадью 30 квадратных метров со сроком выдачи в ключе 2024 год. По бюджету начинается от 17,5 миллионов. Это со всеми макс...
# 1                                                                                                                                                                                                                                                                             Добрый день, слушаю вас. Как Вы зваетесь? Как Вы сказали, извините. Михаил. Михаил, мне нужно, знаете что, ООО «Элиткомплекс» по какому адресу находится? Шминцский проезд, 39, курс 2. Оттуда приехали, говорят, что нет такого. Охрана никого не пускает. Первый этаж, куда им идти? За минуту. 39, курс 2, первый этаж, помещение 18, кабинет 2-10. Это находится примерно рядом с вкусвиллом. Там дальше вкусвилл будет. Так, подождите, подождите, вот этот адрес, курс 2, первый этаж, помещение 18, кабинет 2-10. Кабинет 2-10, да? Да. Так, это и вот вкусвилл. Да, от вкусвилла, там буквально получается, если смотреть на вкусвилл, с правой стороны будет вход. С правой стороны вход от вкусвилл, да? Да, да, да. Угу, все, спасибо вам большое.
# 2    Алло, Михаил, это снова я. Скажите, пожалуйста, вот там никто, ну охрану туда не пускают. Может кто-то спуститься? Как этого устроить? Кто-нибудь может туда подойти, потому что их там не запускают? Я пока не могу подсказать. Блин, ну что делать? Они ехали. Если вы не в правильном помещении... Не, не, не, они в правильном. Нас все нашли, говорит, лозунг кусил, все нашли, в помещении стоят, там ждут, и кого ждут неизвестно. И там ехали, там еще... Там есть секретарь, который может принять документы. Вы это объясните охраннику, что ему нужно секретарь, чтобы он принял документы, и все. Может быть просто секретарь переехал в другое место. Вот. Нужен секретарь, который примет документы, и все. Вот и все. Блин, а отлично, мы будем искать того секретаря. Там точно должен быть кто-то, может быть, правда? Может быть просто секретарь, который принимает документы, он на обед отошел, поэтому охрана не пускает вас. Нужно это охране объяснить, они смогут подсказать. Потому что охранник думает, ...
# 3    ЗВОНОК ТЕЛЕФОНА ЗВОНОК ТЕЛЕФОНА Добрый день, группа «Картас». Михаил слушает вас. Здравствуйте. Михаил, нужно акт прямой передачи сделать. Включайте. Подскажите, какой проект, фамилия, собственник? Фамилия Белов, Щелково-Богородск. Да. Белов Андреанович. Я просто у вас здесь стою, охрана не пускает, говорит. Никуда не знает. А, я понял, Щелково-Богородск. Вам же объясняли, что необходимо заявление написать письменное. Да, а вот куда войти нужно? Только после рассмотрения данного заявления вам смогут сделать дубликат акта. Просто так это не делается. Нет, я вас понял. Я просто вот у вас в Москве стою, куда мне нужно идти? Кому вызвать, чтобы я написал заявление? Держите к тому адресу. Шмидтовский проезд, 39, корпус 2, этаж 1, помещение 18, кабинет 210. Ну, я вот здесь стою, охрана меня не пускает. Можно объяснить? Что такое отдел продаж? Отделы продаж, наверное, надо стоять или где? С одной стороны, у вас там технические документы делают. Куда нужно с этим актом бежать? Вам заявлен...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             *** Music ***
# Name: Текст whisper-транскрибации записи звонка, dtype: object

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Headliner_transcriptions_df.dtypes
# Out:
# Дата и время                                 datetime64[ns]
# Номер абонента                                        int64
# Номер сотрудника                                      int64
# Идентификатор сессии звонка                           int64
# Файл whisper-транскрибации записи звонка             object
# Текст whisper-транскрибации записи звонка            object
# dtype: object

# %%
print(Headliner_transcriptions_df.count())
# Out:
# Дата и время                                 1226
# Номер абонента                               1226
# Номер сотрудника                             1226
# Идентификатор сессии звонка                  1226
# Файл whisper-транскрибации записи звонка     1226
# Текст whisper-транскрибации записи звонка    1226
# dtype: int64

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Headliner_transcriptions_df в файл
with open(df_path + 'Headliner_new_transcriptions_df.pkl', 'wb') as f:
  pkl.dump(Headliner_transcriptions_df, f)

# %% [markdown]
# ### Primavera

# %% [markdown]
# #### Создание датафрейма

# %%
# Создаём датафрейм из списка файлов транскрибации звонков Primavera
Primavera_transcriptions_df = transcriptions_list_to_df(os.listdir(new_transcription_path + 'Расшифровки_Записи Primavera'))
Primavera_transcriptions_df.shape
# Out:
# (767, 5)

# %%
Primavera_transcriptions_df.head()
# Out:
#           Дата и время Номер абонента Номер сотрудника  \
# 0  2023-09-01 09:00:40    74950210291          0253211
# 1  2023-09-01 09:25:57    79264683596          0111639
# 2  2023-09-01 11:16:28    79161163889          0111652
# 3  2023-09-01 11:42:21    79377999852          0253201
# 4  2023-09-01 12:05:26    79199944228          0111652
#
#   Идентификатор сессии звонка  \
# 0                  3200997782
# 1                  3187995780
# 2                  3195799881
# 3                  3188347120
# 4                  3188422720
#
#                                                            Файл whisper-транскрибации записи звонка
# 0  2023-09-01_09-00-40.052431_from_74950210291_to_0253211_session_3200997782_talk_whisper_large.txt
# 1  2023-09-01_09-25-57.450908_from_79264683596_to_0111639_session_3187995780_talk_whisper_large.txt
# 2  2023-09-01_11-16-28.505654_from_79161163889_to_0111652_session_3195799881_talk_whisper_large.txt
# 3  2023-09-01_11-42-21.432552_from_79377999852_to_0253201_session_3188347120_talk_whisper_large.txt
# 4  2023-09-01_12-05-26.624031_from_79199944228_to_0111652_session_3188422720_talk_whisper_large.txt

# %%
# Проверяем количество строк
print(len(os.listdir(new_transcription_path + 'Расшифровки_Записи Primavera')))
print(Primavera_transcriptions_df.shape[0])
# Out:
# 767
# 767

# %%
print(Primavera_transcriptions_df.count())
# Out:
# Дата и время                                767
# Номер абонента                              767
# Номер сотрудника                            767
# Идентификатор сессии звонка                 767
# Файл whisper-транскрибации записи звонка    767
# dtype: int64

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Дата и время

# %%
Primavera_transcriptions_df['Дата и время'].head()
# Out:
# 0    2023-09-01 09:00:40
# 1    2023-09-01 09:25:57
# 2    2023-09-01 11:16:28
# 3    2023-09-01 11:42:21
# 4    2023-09-01 12:05:26
# Name: Дата и время, dtype: object

# %%
# Приводим тип данных столбца 'Дата и время'
Primavera_transcriptions_df['Дата и время'] = pd.to_datetime(Primavera_transcriptions_df['Дата и время'])

# %%
Primavera_transcriptions_df['Дата и время'].tail()
# Out:
# 762   2023-10-04 17:28:47
# 763   2023-10-04 17:34:08
# 764   2023-10-04 18:13:46
# 765   2023-10-04 19:40:25
# 766   2023-10-04 19:47:06
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 1. Номер абонента

# %%
Primavera_transcriptions_df['Номер абонента'].head()
# Out:
# 0    74950210291
# 1    79264683596
# 2    79161163889
# 3    79377999852
# 4    79199944228
# Name: Номер абонента, dtype: object

# %%
# Приводим тип данных столбца 'Номер абонента'
Primavera_transcriptions_df = Primavera_transcriptions_df.astype({'Номер абонента': int})

# %%
Primavera_transcriptions_df['Номер абонента'].tail()
# Out:
# 762    79263997574
# 763    74950851200
# 764    79263997574
# 765    74950210291
# 766    79624005760
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 2. Номер сотрудника

# %%
Primavera_transcriptions_df['Номер сотрудника'].head()
# Out:
# 0    0253211
# 1    0111639
# 2    0111652
# 3    0253201
# 4    0111652
# Name: Номер сотрудника, dtype: object

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Primavera_transcriptions_df = Primavera_transcriptions_df.astype({'Номер сотрудника': int})

# %%
Primavera_transcriptions_df['Номер сотрудника'].tail()
# Out:
# 762    111652
# 763    173695
# 764    111642
# 765    253206
# 766    111652
# Name: Номер сотрудника, dtype: int64

# %% [markdown]
# ##### 3. Идентификатор сессии звонка

# %%
Primavera_transcriptions_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3200997782
# 1    3187995780
# 2    3195799881
# 3    3188347120
# 4    3188422720
# Name: Идентификатор сессии звонка, dtype: object

# %%
# Приводим тип данных столбца 'Идентификатор сессии звонка'
Primavera_transcriptions_df = Primavera_transcriptions_df.astype({'Идентификатор сессии звонка': int})

# %%
Primavera_transcriptions_df['Идентификатор сессии звонка'].tail()
# Out:
# 762    3272470671
# 763    3276535412
# 764    3269705084
# 765    3276780397
# 766    3264304568
# Name: Идентификатор сессии звонка, dtype: int64

# %%
# Смотрим количество уникальных значений столбца 'Идентификатор сессии звонка'
Primavera_transcriptions_df['Идентификатор сессии звонка'].nunique()
# Out:
# 767

# %% [markdown]
# ##### 4. Файл whisper-транскрибации записи звонка

# %%
Primavera_transcriptions_df['Файл whisper-транскрибации записи звонка'].head()
# Out:
# 0    2023-09-01_09-00-40.052431_from_74950210291_to_0253211_session_3200997782_talk_whisper_large.txt
# 1    2023-09-01_09-25-57.450908_from_79264683596_to_0111639_session_3187995780_talk_whisper_large.txt
# 2    2023-09-01_11-16-28.505654_from_79161163889_to_0111652_session_3195799881_talk_whisper_large.txt
# 3    2023-09-01_11-42-21.432552_from_79377999852_to_0253201_session_3188347120_talk_whisper_large.txt
# 4    2023-09-01_12-05-26.624031_from_79199944228_to_0111652_session_3188422720_talk_whisper_large.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %%
# Добавляем к файлам относительные пути
Primavera_transcriptions_df['Файл whisper-транскрибации записи звонка'] = Primavera_transcriptions_df['Файл whisper-транскрибации записи звонка'].apply(lambda x: 'Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/' + x)

# %%
Primavera_transcriptions_df['Файл whisper-транскрибации записи звонка'].tail()
# Out:
# 762    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-10-04_17-28-47.993474_from_79263997574_to_0111652_session_3272470671_talk_whisper_large.txt
# 763    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-10-04_17-34-08.412006_from_74950851200_to_0173695_session_3276535412_talk_whisper_large.txt
# 764    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-10-04_18-13-46.905203_from_79263997574_to_0111642_session_3269705084_talk_whisper_large.txt
# 765    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-10-04_19-40-25.037187_from_74950210291_to_0253206_session_3276780397_talk_whisper_large.txt
# 766    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-10-04_19-47-06.171534_from_79624005760_to_0111652_session_3264304568_talk_whisper_large.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %% [markdown]
# ##### 5. Текст whisper-транскрибации записи звонка

# %%
# Добавляем столбец 'Текст whisper-транскрибации записи звонка'
Primavera_transcriptions_df['Текст whisper-транскрибации записи звонка'] = 'нет текста транскрибации звонка'
Primavera_transcriptions_df.head()
# Out:
#          Дата и время  Номер абонента  Номер сотрудника  \
# 0 2023-09-01 09:00:40     74950210291            253211
# 1 2023-09-01 09:25:57     79264683596            111639
# 2 2023-09-01 11:16:28     79161163889            111652
# 3 2023-09-01 11:42:21     79377999852            253201
# 4 2023-09-01 12:05:26     79199944228            111652
#
#    Идентификатор сессии звонка  \
# 0                   3200997782
# 1                   3187995780
# 2                   3195799881
# 3                   3188347120
# 4                   3188422720
#
#                                                                                                                                     Файл whisper-транскрибации записи звонка  \
# 0  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_09-00-40.052431_from_74950210291_to_0253211_session_3200997782_talk_whisper_large.txt
# 1  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_09-25-57.450908_from_79264683596_to_0111639_session_3187995780_talk_whisper_large.txt
# 2  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_11-16-28.505654_from_79161163889_to_0111652_session_3195799881_talk_whisper_large.txt
# 3  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_11-42-21.432552_from_79377999852_to_0253201_session_3188347120_talk_whisper_large.txt
# 4  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_12-05-26.624031_from_79199944228_to_0111652_session_3188422720_talk_whisper_large.txt
#
#   Текст whisper-транскрибации записи звонка
# 0           нет текста транскрибации звонка
# 1           нет текста транскрибации звонка
# 2           нет текста транскрибации звонка
# 3           нет текста транскрибации звонка
# 4           нет текста транскрибации звонка

# %%
for row in range(Primavera_transcriptions_df.shape[0]):
  with open(all_dataset_path + Primavera_transcriptions_df.loc[row, ['Файл whisper-транскрибации записи звонка']].values[0], 'rb') as f:
    contents = f.read()
  Primavera_transcriptions_df.loc[row, ['Текст whisper-транскрибации записи звонка']] = contents.decode('utf-16').strip()

# %%
Primavera_transcriptions_df['Текст whisper-транскрибации записи звонка'].head()
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Добрый день, оператор Яна, клубный город на реке Примавера. Как я могу к вам обращаться? Добрый день, Александр. Можете через 2 часа набрать? Да, покупка квартиры, да, интересует, Александр? Да, да, да. Все, хорошо, передам информацию. Ожидайте. Спасибо.
# 1    Клубный город на реке Примавера. Здравствуйте, Светлана. Да, здрасте. Есть квартиры? Да, да. Как обращаться к вам? Вячеслав. Вячеслав, вас менеджер проконсультирует минуту. Обращаем ваше внимание, что в целях контроля качества услуг разговор может быть записан. Обращаем ваше внимание. Примавера. Клубный город на реке. Меня Владимир зовут. Здравствуйте, Вячеслав. Всем могу быть полезен? Да, здрасте. Предъявление на вас, что квартиры до 20 миллионов, ну, как хотелось бы, до 15. Ну, либо однушка, либо двушка. Просите на двушку, наверное. Вячеслав, скажите, до 13 миллионов, вы сказали? Нет, до 17-ти. А, так. У нас просто двухкомнатные, где отдельная спальня и кухня. Они начинаются от 27 миллионов. Есть форматы Евро, двухкомнатные, где отдельная спальня и кухня-гостиная. Они начинаются от 19 миллионов 300 тысяч. Вам такие форматы подходят? Это самые дальние по сдаче, корпус. Да, совершенно верно. У нас сейчас в продаже две очереди, Россиния и Вивальди. Россия, ключи до декабря 2024 год...
# 2    Здравствуйте, это Татьяна. Здравствуйте, это Евгения. Город на реке, однокомнатный 25-й год, 19 370 000 рублей. Соединяем? Да. Ага. А для продаж соединяю с менеджером. Добрый день. Я хотела узнать, по ряду рассрочки какой у вас... Обращаем ваше внимание, что в целях контроля качества услуг разговор может быть записан. Прямовары, Клубная зона. Алло. Владимир зовут. Здравствуйте, Евгения. Чем могу быть полезен? Здравствуйте. Хотела поподробнее расспросить по отсрочке, рассрочке, то есть при покупке квартиры, такие условия. Евгения, а вас какой корпус интересует? Очередь. У нас есть две очереди. Первая на России называется, там ключи до декабря 24-го года пораньше завернуты. А вторая очередь называется в Вивальде, там срок получения ключей до декабря 25-го года, на год позднее. Вы готовы подождать? Ага. Подождать я готова, да. Ну какие у вас там условия? А что, разные условия для 24-го года? Да, конечно. А вы расскажите про то и про другое. В первую очередь у нас есть хорошая рассроч...
# 3                                           Кубный город на реке Примавера. Здравствуйте, Екатерина. Да, здравствуй, Екатерина. Скажите, пожалуйста, а где у вас офис находится? По поводу консультации приключена специалистка. Как вас представить можно? Михаил зовут. Соглени вас. Клубный город на реке Примавера. Меня зовут Екатерина. Михаил, здравствуйте. Чем могу быть вам? Правильно? Здравствуйте. А где у вас офис находится в Прадаже? Он находится по адресу Волоколамской шоссе, 71, корпус 1. Чуть в отдалении от объекта. Вы сейчас где-то недалеко? Да, мы где-то возле прям объекта. А, вам нужно пойти в другую сторону, либо там... В сторону Волоколамского шоссе. Да, абсолютно верно. Вы сейчас пешком или на автомобиле? Да, пешком. Я вам могу сбросить точку в Яндекс.Картах, в навигаторе, вы поймете где. И я вас буду застеливать. Есть номер живой, да? Можете сюда оставить. Сейчас, секунду, давайте я посмотрю определился ли. Так, 937, 799, да? Да, да. Все, сейчас отправлю вас. Все, спасибо, ждем.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Кловный город на реке Примавера. Здравствуйте, Анастасия. Девушка, здравствуйте. А у вас есть такой врач? Сейчас скажу. А ваш врач, это жилой комплекс. Ой, извините.
# Name: Текст whisper-транскрибации записи звонка, dtype: object

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Primavera_transcriptions_df.dtypes
# Out:
# Дата и время                                 datetime64[ns]
# Номер абонента                                        int64
# Номер сотрудника                                      int64
# Идентификатор сессии звонка                           int64
# Файл whisper-транскрибации записи звонка             object
# Текст whisper-транскрибации записи звонка            object
# dtype: object

# %%
print(Primavera_transcriptions_df.count())
# Out:
# Дата и время                                 767
# Номер абонента                               767
# Номер сотрудника                             767
# Идентификатор сессии звонка                  767
# Файл whisper-транскрибации записи звонка     767
# Текст whisper-транскрибации записи звонка    767
# dtype: int64

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Primavera_transcriptions_df в файл
with open(df_path + 'Primavera_new_transcriptions_df.pkl', 'wb') as f:
  pkl.dump(Primavera_transcriptions_df, f)

# %% [markdown]
# ### Paveletskaya_city

# %% [markdown]
# #### Создание датафрейма

# %%
# Создаём датафрейм из списка файлов транскрибации звонков Paveletskaya_city
Paveletskaya_city_transcriptions_df = transcriptions_list_to_df(os.listdir(new_transcription_path + 'Расшифровки_Записи Павелецкая сити'))
Paveletskaya_city_transcriptions_df.shape
# Out:
# (1413, 5)

# %%
Paveletskaya_city_transcriptions_df.head()
# Out:
#           Дата и время Номер абонента Номер сотрудника  \
# 0  2023-08-31 20:02:47    79169468891            00288
# 1  2023-09-01 08:51:34    79139426842            00288
# 2  2023-09-01 10:53:19    79257720080            00288
# 3  2023-09-01 11:24:52    37378077136            00288
# 4  2023-09-01 11:33:04    79858891114            00288
#
#   Идентификатор сессии звонка  \
# 0                  3195065861
# 1                  3195409751
# 2                  3188206290
# 3                  3188292205
# 4                  3195853356
#
#                                            Файл whisper-транскрибации записи звонка
# 0  2023-08-31_20-02-47.458103_from_79169468891_to_00288_session_3195065861_talk.txt
# 1  2023-09-01_08-51-34.418574_from_79139426842_to_00288_session_3195409751_talk.txt
# 2  2023-09-01_10-53-19.201214_from_79257720080_to_00288_session_3188206290_talk.txt
# 3  2023-09-01_11-24-52.929663_from_37378077136_to_00288_session_3188292205_talk.txt
# 4  2023-09-01_11-33-04.092834_from_79858891114_to_00288_session_3195853356_talk.txt

# %%
# Проверяем количество строк
print(len(os.listdir(new_transcription_path + 'Расшифровки_Записи Павелецкая сити')))
print(Paveletskaya_city_transcriptions_df.shape[0])
# Out:
# 1413
# 1413

# %%
print(Paveletskaya_city_transcriptions_df.count())
# Out:
# Дата и время                                1413
# Номер абонента                              1413
# Номер сотрудника                            1413
# Идентификатор сессии звонка                 1413
# Файл whisper-транскрибации записи звонка    1413
# dtype: int64

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Дата и время

# %%
Paveletskaya_city_transcriptions_df['Дата и время'].head()
# Out:
# 0    2023-08-31 20:02:47
# 1    2023-09-01 08:51:34
# 2    2023-09-01 10:53:19
# 3    2023-09-01 11:24:52
# 4    2023-09-01 11:33:04
# Name: Дата и время, dtype: object

# %%
# Приводим тип данных столбца 'Дата и время'
Paveletskaya_city_transcriptions_df['Дата и время'] = pd.to_datetime(Paveletskaya_city_transcriptions_df['Дата и время'])

# %%
Paveletskaya_city_transcriptions_df['Дата и время'].tail()
# Out:
# 1408   2023-08-31 16:07:51
# 1409   2023-08-31 16:20:15
# 1410   2023-08-31 17:01:46
# 1411   2023-08-31 17:12:58
# 1412   2023-08-31 18:33:45
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 1. Номер абонента

# %%
Paveletskaya_city_transcriptions_df['Номер абонента'].head()
# Out:
# 0    79169468891
# 1    79139426842
# 2    79257720080
# 3    37378077136
# 4    79858891114
# Name: Номер абонента, dtype: object

# %%
Paveletskaya_city_transcriptions_df['Номер абонента'][Paveletskaya_city_transcriptions_df['Номер абонента'] == ''].count()
# Out:
# 1

# %%
# Меняем '' на '0' в столбце 'Номер абонента'
Paveletskaya_city_transcriptions_df['Номер абонента'] = Paveletskaya_city_transcriptions_df['Номер абонента'].apply(lambda x: '0' if x == '' else x)

# %%
# Приводим тип данных столбца 'Номер абонента'
Paveletskaya_city_transcriptions_df = Paveletskaya_city_transcriptions_df.astype({'Номер абонента': int})

# %%
Paveletskaya_city_transcriptions_df['Номер абонента'].tail()
# Out:
# 1408    79271791618
# 1409    79331112978
# 1410    79153796174
# 1411    79061800540
# 1412    79271414018
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 2. Номер сотрудника

# %%
Paveletskaya_city_transcriptions_df['Номер сотрудника'].head()
# Out:
# 0    00288
# 1    00288
# 2    00288
# 3    00288
# 4    00288
# Name: Номер сотрудника, dtype: object

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Paveletskaya_city_transcriptions_df = Paveletskaya_city_transcriptions_df.astype({'Номер сотрудника': int})

# %%
Paveletskaya_city_transcriptions_df['Номер сотрудника'].tail()
# Out:
# 1408    288
# 1409    288
# 1410    288
# 1411    288
# 1412    288
# Name: Номер сотрудника, dtype: int64

# %% [markdown]
# ##### 3. Идентификатор сессии звонка

# %%
Paveletskaya_city_transcriptions_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3195065861
# 1    3195409751
# 2    3188206290
# 3    3188292205
# 4    3195853356
# Name: Идентификатор сессии звонка, dtype: object

# %%
# Приводим тип данных столбца 'Идентификатор сессии звонка'
Paveletskaya_city_transcriptions_df = Paveletskaya_city_transcriptions_df.astype({'Идентификатор сессии звонка': int})

# %%
Paveletskaya_city_transcriptions_df['Идентификатор сессии звонка'].tail()
# Out:
# 1408    3194514836
# 1409    3200112337
# 1410    3200245332
# 1411    3190248338
# 1412    3193454629
# Name: Идентификатор сессии звонка, dtype: int64

# %%
# Смотрим количество уникальных значений столбца 'Идентификатор сессии звонка'
Paveletskaya_city_transcriptions_df['Идентификатор сессии звонка'].nunique()
# Out:
# 1413

# %% [markdown]
# ##### 4. Файл whisper-транскрибации записи звонка

# %%
Paveletskaya_city_transcriptions_df['Файл whisper-транскрибации записи звонка'].head()
# Out:
# 0    2023-08-31_20-02-47.458103_from_79169468891_to_00288_session_3195065861_talk.txt
# 1    2023-09-01_08-51-34.418574_from_79139426842_to_00288_session_3195409751_talk.txt
# 2    2023-09-01_10-53-19.201214_from_79257720080_to_00288_session_3188206290_talk.txt
# 3    2023-09-01_11-24-52.929663_from_37378077136_to_00288_session_3188292205_talk.txt
# 4    2023-09-01_11-33-04.092834_from_79858891114_to_00288_session_3195853356_talk.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %%
# Добавляем к файлам относительные пути
Paveletskaya_city_transcriptions_df['Файл whisper-транскрибации записи звонка'] = Paveletskaya_city_transcriptions_df['Файл whisper-транскрибации записи звонка'].apply(lambda x: 'Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/' + x)

# %%
Paveletskaya_city_transcriptions_df['Файл whisper-транскрибации записи звонка'].tail()
# Out:
# 1408    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-08-31_16-07-51.657929_from_79271791618_to_00288_session_3194514836_talk.txt
# 1409    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-08-31_16-20-15.235129_from_79331112978_to_00288_session_3200112337_talk.txt
# 1410    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-08-31_17-01-46.633530_from_79153796174_to_00288_session_3200245332_talk.txt
# 1411    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-08-31_17-12-58.751450_from_79061800540_to_00288_session_3190248338_talk.txt
# 1412    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-08-31_18-33-45.980557_from_79271414018_to_00288_session_3193454629_talk.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %% [markdown]
# ##### 5. Текст whisper-транскрибации записи звонка

# %%
# Добавляем столбец 'Текст whisper-транскрибации записи звонка'
Paveletskaya_city_transcriptions_df['Текст whisper-транскрибации записи звонка'] = 'нет текста транскрибации звонка'
Paveletskaya_city_transcriptions_df.head()
# Out:
#          Дата и время  Номер абонента  Номер сотрудника  \
# 0 2023-08-31 20:02:47     79169468891               288
# 1 2023-09-01 08:51:34     79139426842               288
# 2 2023-09-01 10:53:19     79257720080               288
# 3 2023-09-01 11:24:52     37378077136               288
# 4 2023-09-01 11:33:04     79858891114               288
#
#    Идентификатор сессии звонка  \
# 0                   3195065861
# 1                   3195409751
# 2                   3188206290
# 3                   3188292205
# 4                   3195853356
#
#                                                                                                                           Файл whisper-транскрибации записи звонка  \
# 0  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-08-31_20-02-47.458103_from_79169468891_to_00288_session_3195065861_talk.txt
# 1  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-09-01_08-51-34.418574_from_79139426842_to_00288_session_3195409751_talk.txt
# 2  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-09-01_10-53-19.201214_from_79257720080_to_00288_session_3188206290_talk.txt
# 3  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-09-01_11-24-52.929663_from_37378077136_to_00288_session_3188292205_talk.txt
# 4  Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-09-01_11-33-04.092834_from_79858891114_to_00288_session_3195853356_talk.txt
#
#   Текст whisper-транскрибации записи звонка
# 0           нет текста транскрибации звонка
# 1           нет текста транскрибации звонка
# 2           нет текста транскрибации звонка
# 3           нет текста транскрибации звонка
# 4           нет текста транскрибации звонка

# %%
for row in range(Paveletskaya_city_transcriptions_df.shape[0]):
  with open(all_dataset_path + Paveletskaya_city_transcriptions_df.loc[row, ['Файл whisper-транскрибации записи звонка']].values[0], 'rb') as f:
    contents = f.read()
  Paveletskaya_city_transcriptions_df.loc[row, ['Текст whisper-транскрибации записи звонка']] = contents.decode('utf-16').strip()

# %%
Paveletskaya_city_transcriptions_df['Текст whisper-транскрибации записи звонка'].head()
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Здравствуйте, вы позвонили в компанию Эмергрупп. Пожалуйста дождитесь ответа нашего специалиста. Обращаем ваше внимание, что в целях улучшения качества обслуживания клиентов все разговоры записываются. Продолжая разговор, вы соглашаетесь на обработку ваших персональных данных. Вам звонок с Яндекс.Недвижимости. Для соединения с покупателем нажмите... Начинаем звонок покупателю.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Здравствуйте, вы позвонили в компанию Эммергрупп. Мы работаем ежедневно с 9 до 21 часа по московскому времени. Сейчас мы не можем ответить на ваш звонок. Пожалуйста, оставьте свои контактные данные, и мы вам перезвоним. Сообщите, пожалуйста, контактный номер телефона с указанием кода города и ваше имя. Начинайте говорить после звукового сигнала. 8-913-942-6842, Алина.
# 2    Здравствуйте! Вы позвонили в компанию Эмергрупп. Пожалуйста, дождитесь ответа нашего специалиста. Обращаем ваше внимание, что в целях улучшения качества обслуживания клиентов все разговоры записываются. Продолжая разговор, вы соглашаетесь на обработку ваших персональных данных. В компании Эмергрупп, меня зовут Ирина. Здравствуйте! Ирина, здравствуйте! Меня вот интересует ЖК по билетской сети. Покупка жировой недвижимости в данном комплексе? Переуступка. Можно ли у вас оформить переуступку по этому объекту? То есть, вы продаете, я правильно поняла вас? Да, да, да. Помните, с каким менеджером контактировали на объекте? Она уже не работает. Нет, именно агентство. Первое агентство, БЭСТ, Метриум. Не знаю. Не помните? Можно фамилию, имя, число, подговоры? Я посмотрю, с кем вы работали, с каким агентством. Ботя Рова, Людмила. Минуту. Людмила Борисовна? Да, да. У вас компания БЭСТ. БЭСТ, я вас сейчас соединю, минуту. По окончании разговора, пожалуйста, оцените качество отслуживания. Людм...
# 3                                                                Здравствуйте! Вы позвонили в компанию Эмэр Групп. Пожалуйста дождитесь ответа нашего специалиста. Обращаем ваше внимание, что в целях улучшения качества обслуживания клиентов все разговоры записываются. Продолжая разговор, вы соглашаетесь на обработку ваших персональных данных. Компания Наркология. Меня зовут Арина. Здравствуйте! Девушка, здравствуйте! Скажите, пожалуйста, я звоню вам с Молдавии. Это у вас наркологический центр, да? Нет, это строительная компания. Вы позвонили. А почему в этот номер пишется, как больница-наркологист? Я вам не смогу подсказать. Возможно, уже номер не принадлежит. А какой номер вы набирали? Подскажите, пожалуйста. Плюс семьсот сорок девять, пятьсот два, сто семьдесят семь, двадцать пять. Нет, что-то вообще соединение. Вы в Москву позвонили. В Москву? Я в Черпухов. Нет, нет, нет, нет, у нас вообще таких номеров нет. Какое-то соединение некорректное пошло. Ага, спасибо, до свидания. До свидания.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Здравствуйте! Вы позвонили в компанию ЭМР-Групп. Пожалуйста, дождитесь ответа нашего специалиста. Обращаем ваше внимание, что в целях улучшения качества обслуживания клиентов все разговоры записываются. Продолжая разговор, вы соглашаетесь на обработку ваших персональных данных.
# Name: Текст whisper-транскрибации записи звонка, dtype: object

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Paveletskaya_city_transcriptions_df.dtypes
# Out:
# Дата и время                                 datetime64[ns]
# Номер абонента                                        int64
# Номер сотрудника                                      int64
# Идентификатор сессии звонка                           int64
# Файл whisper-транскрибации записи звонка             object
# Текст whisper-транскрибации записи звонка            object
# dtype: object

# %%
print(Paveletskaya_city_transcriptions_df.count())
# Out:
# Дата и время                                 1413
# Номер абонента                               1413
# Номер сотрудника                             1413
# Идентификатор сессии звонка                  1413
# Файл whisper-транскрибации записи звонка     1413
# Текст whisper-транскрибации записи звонка    1413
# dtype: int64

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Paveletskaya_city_transcriptions_df в файл
with open(df_path + 'Paveletskaya_city_new_transcriptions_df.pkl', 'wb') as f:
  pkl.dump(Paveletskaya_city_transcriptions_df, f)

# %% [markdown]
# ## [Информация о новых звонках](https://drive.google.com/drive/folders/1O5nOxIkaEozzEnnUqW-NBKDiVowVFQYg?usp=sharing)

# %%
os.listdir(new_dataset_info_path)
# Out:
# ['Примавера.xlsx', 'Headliner.xlsx', 'Павелецкая сити.xlsx']

# %% [markdown]
# ### Headliner

# %% [markdown]
# #### Создание датафрейма

# %%
# Читаем файл 'Headliner.xlsx' в датафрейм
Headliner_df = pd.read_excel(new_dataset_info_path + 'Headliner.xlsx',
                             skiprows=4)
Headliner_df.shape
# Out:
# (1542, 72)

# %%
Headliner_df.head()
# Out:
#        Статус                       Тип         Дата и время  Номер абонента  \
# 0    Принятый               Звонок ВАТС  2023-10-05 10:26:28     79235257654
# 1    Принятый  Динамический коллтрекинг  2023-10-05 10:24:42     79235257654
# 2    Принятый  Динамический коллтрекинг  2023-10-05 10:23:07     79235257654
# 3  Потерянный  Динамический коллтрекинг  2023-10-05 10:22:18     79235257654
# 4    Принятый  Динамический коллтрекинг  2023-10-05 10:20:50     79067910613
#
#    Виртуальный номер                   Рекламная кампания Длительность звонка  \
# 0        74950854280  ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер            00:02:12
# 1        74953249432                Поисковое продвижение            00:01:24
# 2        74953249432                Поисковое продвижение            00:00:38
# 3        74953249432                Поисковое продвижение            00:00:06
# 4        74951629501                        Яндекс Директ            00:01:58
#
#   Длительность ожидания ответа             Причина завершения  \
# 0                     00:00:01  Сотрудник разорвал соединение
# 1                     00:00:09    Абонент разорвал соединение
# 2                     00:00:09    Абонент разорвал соединение
# 3                     00:00:06    Абонент разорвал соединение
# 4                     00:00:08  Сотрудник разорвал соединение
#
#                                           Сценарий  ...  Домен реферера  \
# 0  74959339929 ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер  ...             NaN
# 1                         .Последовательный обзвон  ...  www.google.com
# 2                         .Последовательный обзвон  ...  www.google.com
# 3                         .Последовательный обзвон  ...  www.google.com
# 4                         .Последовательный обзвон  ...       yandex.ru
#
#             Сайт Оценка сотрудника  Внутренний звонок  ФИО контакта  \
# 0  head-liner.ru               NaN                Нет           NaN
# 1  head-liner.ru               NaN                Нет           NaN
# 2  head-liner.ru               NaN                Нет           NaN
# 3  head-liner.ru               NaN                Нет           NaN
# 4  head-liner.ru               NaN                Нет           NaN
#
#   Имя тренера Группа, выбранная посетителем Регион номера абонента  \
# 0         NaN                           NaN       Кемеровская обл.
# 1         NaN                           NaN       Кемеровская обл.
# 2         NaN                           NaN       Кемеровская обл.
# 3         NaN                           NaN       Кемеровская обл.
# 4         NaN                           NaN              г. Москва
#
#   Страна номера абонента Контакт из CRM
# 0                     РФ            NaN
# 1                     РФ            NaN
# 2                     РФ            NaN
# 3                     РФ            NaN
# 4                     РФ            NaN
#
# [5 rows x 72 columns]

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Статус

# %%
Headliner_df['Статус'].head()
# Out:
# 0      Принятый
# 1      Принятый
# 2      Принятый
# 3    Потерянный
# 4      Принятый
# Name: Статус, dtype: object

# %%
print(Headliner_df['Статус'].count())
print(Headliner_df['Статус'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Статус'].tail()
# Out:
# 1537      Принятый
# 1538      Принятый
# 1539      Принятый
# 1540      Принятый
# 1541    Потерянный
# Name: Статус, dtype: object

# %%
Headliner_df['Статус'][Headliner_df['Статус'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 1. Тип

# %%
Headliner_df['Тип'].head()
# Out:
# 0                 Звонок ВАТС
# 1    Динамический коллтрекинг
# 2    Динамический коллтрекинг
# 3    Динамический коллтрекинг
# 4    Динамический коллтрекинг
# Name: Тип, dtype: object

# %%
print(Headliner_df['Тип'].count())
print(Headliner_df['Тип'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Тип'].tail()
# Out:
# 1537                Звонок ВАТС
# 1538                Звонок ВАТС
# 1539                Звонок ВАТС
# 1540                Звонок ВАТС
# 1541    Автоперезвон по заявкам
# Name: Тип, dtype: object

# %%
Headliner_df['Тип'][Headliner_df['Тип'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 2. Дата и время

# %%
Headliner_df['Дата и время'].head()
# Out:
# 0    2023-10-05 10:26:28
# 1    2023-10-05 10:24:42
# 2    2023-10-05 10:23:07
# 3    2023-10-05 10:22:18
# 4    2023-10-05 10:20:50
# Name: Дата и время, dtype: object

# %%
print(Headliner_df['Дата и время'].count())
print(Headliner_df['Дата и время'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Дата и время'
Headliner_df['Дата и время'] = pd.to_datetime(Headliner_df['Дата и время'])

# %%
Headliner_df['Дата и время'].tail()
# Out:
# 1537   2023-08-23 10:15:04
# 1538   2023-08-23 10:08:09
# 1539   2023-08-23 09:32:28
# 1540   2023-08-23 09:11:37
# 1541   2023-08-23 01:07:56
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 3. Номер абонента

# %%
Headliner_df['Номер абонента'].head()
# Out:
# 0    79235257654
# 1    79235257654
# 2    79235257654
# 3    79235257654
# 4    79067910613
# Name: Номер абонента, dtype: int64

# %%
print(Headliner_df['Номер абонента'].count())
print(Headliner_df['Номер абонента'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Номер абонента'
Headliner_df = Headliner_df.astype({'Номер абонента': int})

# %%
Headliner_df['Номер абонента'].tail()
# Out:
# 1537    79166964481
# 1538    79166964481
# 1539    79161079278
# 1540    79166964481
# 1541              0
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 4. Виртуальный номер

# %%
Headliner_df['Виртуальный номер'].head()
# Out:
# 0    74950854280
# 1    74953249432
# 2    74953249432
# 3    74953249432
# 4    74951629501
# Name: Виртуальный номер, dtype: int64

# %%
print(Headliner_df['Виртуальный номер'].count())
print(Headliner_df['Виртуальный номер'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Виртуальный номер'
Headliner_df = Headliner_df.astype({'Виртуальный номер': int})

# %%
Headliner_df['Виртуальный номер'].tail()
# Out:
# 1537    74950854280
# 1538    74950854280
# 1539    74951063507
# 1540    74950854280
# 1541    74951626927
# Name: Виртуальный номер, dtype: int64

# %% [markdown]
# ##### 5. Рекламная кампания

# %%
Headliner_df['Рекламная кампания'].head()
# Out:
# 0    ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер
# 1                  Поисковое продвижение
# 2                  Поисковое продвижение
# 3                  Поисковое продвижение
# 4                          Яндекс Директ
# Name: Рекламная кампания, dtype: object

# %%
print(Headliner_df['Рекламная кампания'].count())
print(Headliner_df['Рекламная кампания'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Рекламная кампания'].tail()
# Out:
# 1537    ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер
# 1538    ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер
# 1539            Базы // Яндекс Недвижимость
# 1540    ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер
# 1541      Посетители без рекламной кампании
# Name: Рекламная кампания, dtype: object

# %%
Headliner_df['Рекламная кампания'][Headliner_df['Рекламная кампания'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 6. Длительность звонка

# %%
Headliner_df['Длительность звонка'].head()
# Out:
# 0    00:02:12
# 1    00:01:24
# 2    00:00:38
# 3    00:00:06
# 4    00:01:58
# Name: Длительность звонка, dtype: object

# %%
print(Headliner_df['Длительность звонка'].count())
print(Headliner_df['Длительность звонка'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Длительность звонка'
Headliner_df['Длительность звонка'] = pd.to_datetime(Headliner_df['Длительность звонка']).dt.time

# %%
Headliner_df['Длительность звонка'].tail()
# Out:
# 1537    00:01:00
# 1538    00:00:45
# 1539    00:03:20
# 1540    00:00:14
# 1541    00:12:16
# Name: Длительность звонка, dtype: object

# %% [markdown]
# ##### 7. Длительность ожидания ответа

# %%
Headliner_df['Длительность ожидания ответа'].head()
# Out:
# 0    00:00:01
# 1    00:00:09
# 2    00:00:09
# 3    00:00:06
# 4    00:00:08
# Name: Длительность ожидания ответа, dtype: object

# %%
print(Headliner_df['Длительность ожидания ответа'].count())
print(Headliner_df['Длительность ожидания ответа'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Длительность ожидания ответа'
Headliner_df['Длительность ожидания ответа'] = pd.to_datetime(Headliner_df['Длительность ожидания ответа']).dt.time

# %%
Headliner_df['Длительность ожидания ответа'].tail()
# Out:
# 1537    00:00:09
# 1538    00:00:09
# 1539    00:00:01
# 1540    00:00:09
# 1541    00:12:16
# Name: Длительность ожидания ответа, dtype: object

# %% [markdown]
# ##### 8. Причина завершения

# %%
Headliner_df['Причина завершения'].head()
# Out:
# 0    Сотрудник разорвал соединение
# 1      Абонент разорвал соединение
# 2      Абонент разорвал соединение
# 3      Абонент разорвал соединение
# 4    Сотрудник разорвал соединение
# Name: Причина завершения, dtype: object

# %%
print(Headliner_df['Причина завершения'].count())
print(Headliner_df['Причина завершения'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Причина завершения'].tail()
# Out:
# 1537      Абонент разорвал соединение
# 1538      Абонент разорвал соединение
# 1539      Абонент разорвал соединение
# 1540    Сотрудник разорвал соединение
# 1541     Не дозвонились до сотрудника
# Name: Причина завершения, dtype: object

# %%
Headliner_df['Причина завершения'][Headliner_df['Причина завершения'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 9. Сценарий

# %%
Headliner_df['Сценарий'].head()
# Out:
# 0    74959339929 ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер
# 1                           .Последовательный обзвон
# 2                           .Последовательный обзвон
# 3                           .Последовательный обзвон
# 4                           .Последовательный обзвон
# Name: Сценарий, dtype: object

# %%
print(Headliner_df['Сценарий'].count())
print(Headliner_df['Сценарий'].shape[0])
# Out:
# 1542
# 1542

# %%
# Убираем '.' в столбце 'Сценарий'
Headliner_df['Сценарий'] = Headliner_df['Сценарий'].apply(lambda x: x.lstrip('.'))

# %%
Headliner_df['Сценарий'].tail()
# Out:
# 1537    74959339929 ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер
# 1538    74959339929 ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер
# 1539                                            Кортрос
# 1540    74959339929 ОТДЕЛ КЛИЕНТСКОГО СЕРВИСА Хедлайнер
# 1541                                       Автоперезвон
# Name: Сценарий, dtype: object

# %%
Headliner_df['Сценарий'][Headliner_df['Сценарий'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 10. Сотрудник

# %%
Headliner_df['Сотрудник'].head()
# Out:
# 0    Кортрос
# 1    Кортрос
# 2    Кортрос
# 3        NaN
# 4    Кортрос
# Name: Сотрудник, dtype: object

# %%
print(Headliner_df['Сотрудник'].count())
print(Headliner_df['Сотрудник'].shape[0])
# Out:
# 1251
# 1542

# %%
# Избавляемся от пустот в столбце 'Сотрудник'
Headliner_df['Сотрудник'] = Headliner_df['Сотрудник'].fillna('нет сотрудника')

# %%
print(Headliner_df['Сотрудник'].count())
print(Headliner_df['Сотрудник'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Сотрудник'].tail()
# Out:
# 1537               ОКС
# 1538               ОКС
# 1539           Кортрос
# 1540               ОКС
# 1541    нет сотрудника
# Name: Сотрудник, dtype: object

# %%
Headliner_df['Сотрудник'][Headliner_df['Сотрудник'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 11. Комментарий

# %%
Headliner_df['Комментарий'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Комментарий, dtype: float64

# %%
print(Headliner_df['Комментарий'].count())
print(Headliner_df['Комментарий'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'Комментарий'
Headliner_df['Комментарий'] = Headliner_df['Комментарий'].fillna('нет комментария')

# %%
print(Headliner_df['Комментарий'].count())
print(Headliner_df['Комментарий'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Комментарий'].tail()
# Out:
# 1537    нет комментария
# 1538    нет комментария
# 1539    нет комментария
# 1540    нет комментария
# 1541    нет комментария
# Name: Комментарий, dtype: object

# %%
Headliner_df['Комментарий'][Headliner_df['Комментарий'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 12. UTM-метка Source

# %%
Headliner_df['UTM-метка Source'].head()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4    yandex
# Name: UTM-метка Source, dtype: object

# %%
print(Headliner_df['UTM-метка Source'].count())
print(Headliner_df['UTM-метка Source'].shape[0])
# Out:
# 199
# 1542

# %%
# Избавляемся от пустот в столбце 'UTM-метка Source'
Headliner_df['UTM-метка Source'] = Headliner_df['UTM-метка Source'].fillna('нет')

# %%
print(Headliner_df['UTM-метка Source'].count())
print(Headliner_df['UTM-метка Source'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['UTM-метка Source'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: UTM-метка Source, dtype: object

# %%
Headliner_df['UTM-метка Source'][Headliner_df['UTM-метка Source'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 13. ID посетителя

# %%
Headliner_df['ID посетителя'].head()
# Out:
# 0    7.602506e+09
# 1    7.602506e+09
# 2    7.602506e+09
# 3    7.602506e+09
# 4    7.563128e+09
# Name: ID посетителя, dtype: float64

# %%
print(Headliner_df['ID посетителя'].count())
print(Headliner_df['ID посетителя'].shape[0])
# Out:
# 700
# 1542

# %%
# Избавляемся от пустот в столбце 'ID посетителя'
Headliner_df['ID посетителя'] = Headliner_df['ID посетителя'].fillna('0')

# %%
print(Headliner_df['ID посетителя'].count())
print(Headliner_df['ID посетителя'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'ID посетителя'
Headliner_df = Headliner_df.astype({'ID посетителя': int})

# %%
Headliner_df['ID посетителя'].tail()
# Out:
# 1537             0
# 1538             0
# 1539    7506091317
# 1540             0
# 1541    7507859367
# Name: ID посетителя, dtype: int64

# %% [markdown]
# ##### 14. Номер обращения

# %%
Headliner_df['Номер обращения'].head()
# Out:
# 0    6
# 1    5
# 2    4
# 3    3
# 4    4
# Name: Номер обращения, dtype: int64

# %%
print(Headliner_df['Номер обращения'].count())
print(Headliner_df['Номер обращения'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Номер обращения'].tail()
# Out:
# 1537     3
# 1538     2
# 1539    12
# 1540     1
# 1541     2
# Name: Номер обращения, dtype: int64

# %% [markdown]
# ##### 15. Поисковый запрос

# %%
Headliner_df['Поисковый запрос'].head()
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4    46117476237_46117476237
# Name: Поисковый запрос, dtype: object

# %%
print(Headliner_df['Поисковый запрос'].count())
print(Headliner_df['Поисковый запрос'].shape[0])
# Out:
# 295
# 1542

# %%
# Избавляемся от пустот в столбце 'Поисковый запрос'
Headliner_df['Поисковый запрос'] = Headliner_df['Поисковый запрос'].fillna('нет запроса')

# %%
print(Headliner_df['Поисковый запрос'].count())
print(Headliner_df['Поисковый запрос'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Поисковый запрос'].tail()
# Out:
# 1537    нет запроса
# 1538    нет запроса
# 1539    нет запроса
# 1540    нет запроса
# 1541    нет запроса
# Name: Поисковый запрос, dtype: object

# %%
Headliner_df['Поисковый запрос'][Headliner_df['Поисковый запрос'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 16. Теги

# %%
Headliner_df['Теги'].head()
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3    Нецелевой контакт
# 4                  NaN
# Name: Теги, dtype: object

# %%
print(Headliner_df['Теги'].count())
print(Headliner_df['Теги'].shape[0])
# Out:
# 1535
# 1542

# %%
# Избавляемся от пустот в столбце 'Теги'
Headliner_df['Теги'] = Headliner_df['Теги'].fillna('нет')

# %%
print(Headliner_df['Теги'].count())
print(Headliner_df['Теги'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Теги'].tail()
# Out:
# 1537      спорный - нет соединения
# 1538      спорный - нет соединения
# 1539    спорный - связь прервалась
# 1540      спорный - нет соединения
# 1541      спорный - нет соединения
# Name: Теги, dtype: object

# %%
Headliner_df['Теги'][Headliner_df['Теги'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 17. UTM-метка Campaign

# %%
Headliner_df['UTM-метка Campaign'].head()
# Out:
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4    brend_search_mmo_room|91303199
# Name: UTM-метка Campaign, dtype: object

# %%
print(Headliner_df['UTM-метка Campaign'].count())
print(Headliner_df['UTM-метка Campaign'].shape[0])
# Out:
# 190
# 1542

# %%
# Избавляемся от пустот в столбце 'UTM-метка Campaign'
Headliner_df['UTM-метка Campaign'] = Headliner_df['UTM-метка Campaign'].fillna('нет')

# %%
print(Headliner_df['UTM-метка Campaign'].count())
print(Headliner_df['UTM-метка Campaign'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['UTM-метка Campaign'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: UTM-метка Campaign, dtype: object

# %%
Headliner_df['UTM-метка Campaign'][Headliner_df['UTM-метка Campaign'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 18. Номер сотрудника

# %%
Headliner_df['Номер сотрудника'].head()
# Out:
# 0        0188880
# 1    74959339902
# 2    74959339902
# 3    74959339902
# 4    74959339902
# Name: Номер сотрудника, dtype: object

# %%
print(Headliner_df['Номер сотрудника'].count())
print(Headliner_df['Номер сотрудника'].shape[0])
# Out:
# 1532
# 1542

# %%
# Избавляемся от пустот в столбце 'Номер сотрудника'
Headliner_df['Номер сотрудника'] = Headliner_df['Номер сотрудника'].fillna('0')

# %%
print(Headliner_df['Номер сотрудника'].count())
print(Headliner_df['Номер сотрудника'].shape[0])
# Out:
# 1542
# 1542

# %%
# Обрезаем '<5' в столбце 'Номер сотрудника'
Headliner_df['Номер сотрудника'] = Headliner_df['Номер сотрудника'].apply(lambda x: x.rstrip('<5'))

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Headliner_df = Headliner_df.astype({'Номер сотрудника': int})

# %%
Headliner_df['Номер сотрудника'].tail()
# Out:
# 1537    74959339929
# 1538    74959339929
# 1539         188880
# 1540    74959339929
# 1541         188880
# Name: Номер сотрудника, dtype: int64

# %% [markdown]
# ##### 19. UTM-метка Content

# %%
Headliner_df['UTM-метка Content'].head()
# Out:
# 0                                                                                                                                    NaN
# 1                                                                                                                                    NaN
# 2                                                                                                                                    NaN
# 3                                                                                                                                    NaN
# 4    id|46117476237_46117476237|cid|91303199|gid|5246793629|aid|14682298498|adp|no|pos|premium1|src|search_none|dvc|desktop|coef|2261087
# Name: UTM-метка Content, dtype: object

# %%
print(Headliner_df['UTM-метка Content'].count())
print(Headliner_df['UTM-метка Content'].shape[0])
# Out:
# 190
# 1542

# %%
# Избавляемся от пустот в столбце 'UTM-метка Content'
Headliner_df['UTM-метка Content'] = Headliner_df['UTM-метка Content'].fillna('нет')

# %%
print(Headliner_df['UTM-метка Content'].count())
print(Headliner_df['UTM-метка Content'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['UTM-метка Content'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: UTM-метка Content, dtype: object

# %%
Headliner_df['UTM-метка Content'][Headliner_df['UTM-метка Content'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 20. Client ID Яндекс.Метрика

# %%
Headliner_df['Client ID Яндекс.Метрика'].head()
# Out:
# 0
# 1    1696487861755075289
# 2    1696487861755075289
# 3    1696487861755075289
# 4    1690822343860566395
# Name: Client ID Яндекс.Метрика, dtype: object

# %%
print(Headliner_df['Client ID Яндекс.Метрика'].count())
print(Headliner_df['Client ID Яндекс.Метрика'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Client ID Яндекс.Метрика'][Headliner_df['Client ID Яндекс.Метрика'] == ''].count()
# Out:
# 1107

# %%
# Меняем '' на '0' в столбце 'Client ID Яндекс.Метрика'
Headliner_df['Client ID Яндекс.Метрика'] = Headliner_df['Client ID Яндекс.Метрика'].apply(lambda x: '0' if x == '' else x)

# %%
Headliner_df['Client ID Яндекс.Метрика'].tail()
# Out:
# 1537                      0
# 1538                      0
# 1539                      0
# 1540                      0
# 1541    1692742040109634654
# Name: Client ID Яндекс.Метрика, dtype: object

# %%
Headliner_df['Client ID Яндекс.Метрика'][Headliner_df['Client ID Яндекс.Метрика'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 21. UTM-метка Medium

# %%
Headliner_df['UTM-метка Medium'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    cpc
# Name: UTM-метка Medium, dtype: object

# %%
print(Headliner_df['UTM-метка Medium'].count())
print(Headliner_df['UTM-метка Medium'].shape[0])
# Out:
# 202
# 1542

# %%
# Избавляемся от пустот в столбце 'UTM-метка Medium'
Headliner_df['UTM-метка Medium'] = Headliner_df['UTM-метка Medium'].fillna('нет')

# %%
print(Headliner_df['UTM-метка Medium'].count())
print(Headliner_df['UTM-метка Medium'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['UTM-метка Medium'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: UTM-метка Medium, dtype: object

# %%
Headliner_df['UTM-метка Medium'][Headliner_df['UTM-метка Medium'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 22. Операции

# %%
Headliner_df['Операции'].head()
# Out:
# 0                            Переадресация 1
# 1    Переадресация на последнего менеджера 1
# 2    Переадресация на последнего менеджера 1
# 3    Переадресация на последнего менеджера 1
# 4    Переадресация на последнего менеджера 1
# Name: Операции, dtype: object

# %%
print(Headliner_df['Операции'].count())
print(Headliner_df['Операции'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Операции'].tail()
# Out:
# 1537                                                                                                                                                             Переадресация 1
# 1538                                                                                                                                                             Переадресация 1
# 1539                                                                                                                                                             Переадресация 1
# 1540                                                                                                                                                             Переадресация 1
# 1541    Переадресация 1, Переадресация 1, Переадресация 1, Переадресация 1, Переадресация 1, Переадресация 1, Переадресация 1, Переадресация 1, Переадресация 1, Переадресация 1
# Name: Операции, dtype: object

# %%
Headliner_df['Операции'][Headliner_df['Операции'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 23. Трансфер

# %%
Headliner_df['Трансфер'].head()
# Out:
# 0    Нет
# 1    Нет
# 2    Нет
# 3    Нет
# 4    Нет
# Name: Трансфер, dtype: object

# %%
print(Headliner_df['Трансфер'].count())
print(Headliner_df['Трансфер'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Трансфер'].tail()
# Out:
# 1537    Нет
# 1538    Нет
# 1539    Нет
# 1540    Нет
# 1541    Нет
# Name: Трансфер, dtype: object

# %%
Headliner_df['Трансфер'][Headliner_df['Трансфер'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 24. Идентификатор сессии звонка

# %%
Headliner_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3277416842
# 1    3277407497
# 2    3270503799
# 3    3277402692
# 4    3277397412
# Name: Идентификатор сессии звонка, dtype: int64

# %%
print(Headliner_df['Идентификатор сессии звонка'].count())
print(Headliner_df['Идентификатор сессии звонка'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Идентификатор сессии звонка'].tail()
# Out:
# 1537    3180070252
# 1538    3169874110
# 1539    3173130009
# 1540    3169726155
# 1541    3179576367
# Name: Идентификатор сессии звонка, dtype: int64

# %% [markdown]
# ##### 25. Полная длительность ожидания

# %%
Headliner_df['Полная длительность ожидания'].head()
# Out:
# 0    00:00:01
# 1    00:00:09
# 2    00:00:09
# 3    00:00:06
# 4    00:00:08
# Name: Полная длительность ожидания, dtype: object

# %%
print(Headliner_df['Полная длительность ожидания'].count())
print(Headliner_df['Полная длительность ожидания'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Полная длительность ожидания'
Headliner_df['Полная длительность ожидания'] = pd.to_datetime(Headliner_df['Полная длительность ожидания']).dt.time

# %%
Headliner_df['Полная длительность ожидания'].tail()
# Out:
# 1537    00:00:10
# 1538    00:00:09
# 1539    00:00:01
# 1540    00:00:09
# 1541    00:12:16
# Name: Полная длительность ожидания, dtype: object

# %% [markdown]
# ##### 26. Расширенная UTM-метка Source

# %%
Headliner_df['Расширенная UTM-метка Source'].head()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4    yandex
# Name: Расширенная UTM-метка Source, dtype: object

# %%
print(Headliner_df['Расширенная UTM-метка Source'].count())
print(Headliner_df['Расширенная UTM-метка Source'].shape[0])
# Out:
# 316
# 1542

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Source'
Headliner_df['Расширенная UTM-метка Source'] = Headliner_df['Расширенная UTM-метка Source'].fillna('нет')

# %%
print(Headliner_df['Расширенная UTM-метка Source'].count())
print(Headliner_df['Расширенная UTM-метка Source'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Расширенная UTM-метка Source'].tail()
# Out:
# 1537              нет
# 1538              нет
# 1539    realty_yandex
# 1540              нет
# 1541              нет
# Name: Расширенная UTM-метка Source, dtype: object

# %%
Headliner_df['Расширенная UTM-метка Source'][Headliner_df['Расширенная UTM-метка Source'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 27. Расширенная UTM-метка Campaign

# %%
Headliner_df['Расширенная UTM-метка Campaign'].head()
# Out:
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4    brend_search_mmo_room|91303199
# Name: Расширенная UTM-метка Campaign, dtype: object

# %%
print(Headliner_df['Расширенная UTM-метка Campaign'].count())
print(Headliner_df['Расширенная UTM-метка Campaign'].shape[0])
# Out:
# 190
# 1542

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Campaign'
Headliner_df['Расширенная UTM-метка Campaign'] = Headliner_df['Расширенная UTM-метка Campaign'].fillna('нет')

# %%
print(Headliner_df['Расширенная UTM-метка Campaign'].count())
print(Headliner_df['Расширенная UTM-метка Campaign'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Расширенная UTM-метка Campaign'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Расширенная UTM-метка Campaign, dtype: object

# %%
Headliner_df['Расширенная UTM-метка Campaign'][Headliner_df['Расширенная UTM-метка Campaign'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 28. Расширенная UTM-метка Medium

# %%
Headliner_df['Расширенная UTM-метка Medium'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    cpc
# Name: Расширенная UTM-метка Medium, dtype: object

# %%
print(Headliner_df['Расширенная UTM-метка Medium'].count())
print(Headliner_df['Расширенная UTM-метка Medium'].shape[0])
# Out:
# 275
# 1542

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Medium'
Headliner_df['Расширенная UTM-метка Medium'] = Headliner_df['Расширенная UTM-метка Medium'].fillna('нет')

# %%
print(Headliner_df['Расширенная UTM-метка Medium'].count())
print(Headliner_df['Расширенная UTM-метка Medium'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Расширенная UTM-метка Medium'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Расширенная UTM-метка Medium, dtype: object

# %%
Headliner_df['Расширенная UTM-метка Medium'][Headliner_df['Расширенная UTM-метка Medium'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 29. Расширенная UTM-метка Content

# %%
Headliner_df['Расширенная UTM-метка Content'].head()
# Out:
# 0                                                                                                                                    NaN
# 1                                                                                                                                    NaN
# 2                                                                                                                                    NaN
# 3                                                                                                                                    NaN
# 4    id|46117476237_46117476237|cid|91303199|gid|5246793629|aid|14682298498|adp|no|pos|premium1|src|search_none|dvc|desktop|coef|2261087
# Name: Расширенная UTM-метка Content, dtype: object

# %%
print(Headliner_df['Расширенная UTM-метка Content'].count())
print(Headliner_df['Расширенная UTM-метка Content'].shape[0])
# Out:
# 190
# 1542

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Content'
Headliner_df['Расширенная UTM-метка Content'] = Headliner_df['Расширенная UTM-метка Content'].fillna('нет')

# %%
print(Headliner_df['Расширенная UTM-метка Content'].count())
print(Headliner_df['Расширенная UTM-метка Content'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Расширенная UTM-метка Content'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Расширенная UTM-метка Content, dtype: object

# %%
Headliner_df['Расширенная UTM-метка Content'][Headliner_df['Расширенная UTM-метка Content'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 30. Расширенная UTM-метка Term

# %%
Headliner_df['Расширенная UTM-метка Term'].head()
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4    46117476237_46117476237
# Name: Расширенная UTM-метка Term, dtype: object

# %%
print(Headliner_df['Расширенная UTM-метка Term'].count())
print(Headliner_df['Расширенная UTM-метка Term'].shape[0])
# Out:
# 172
# 1542

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Term'
Headliner_df['Расширенная UTM-метка Term'] = Headliner_df['Расширенная UTM-метка Term'].fillna('нет')

# %%
print(Headliner_df['Расширенная UTM-метка Term'].count())
print(Headliner_df['Расширенная UTM-метка Term'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Расширенная UTM-метка Term'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Расширенная UTM-метка Term, dtype: object

# %%
Headliner_df['Расширенная UTM-метка Term'][Headliner_df['Расширенная UTM-метка Term'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 31. Расширенная UTM-метка Referrer

# %%
Headliner_df['Расширенная UTM-метка Referrer'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Расширенная UTM-метка Referrer, dtype: float64

# %%
print(Headliner_df['Расширенная UTM-метка Referrer'].count())
print(Headliner_df['Расширенная UTM-метка Referrer'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Referrer'
Headliner_df['Расширенная UTM-метка Referrer'] = Headliner_df['Расширенная UTM-метка Referrer'].fillna('нет')

# %%
print(Headliner_df['Расширенная UTM-метка Referrer'].count())
print(Headliner_df['Расширенная UTM-метка Referrer'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Расширенная UTM-метка Referrer'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Расширенная UTM-метка Referrer, dtype: object

# %%
Headliner_df['Расширенная UTM-метка Referrer'][Headliner_df['Расширенная UTM-метка Referrer'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 32. Расширенная UTM-метка Expid

# %%
Headliner_df['Расширенная UTM-метка Expid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Расширенная UTM-метка Expid, dtype: float64

# %%
print(Headliner_df['Расширенная UTM-метка Expid'].count())
print(Headliner_df['Расширенная UTM-метка Expid'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Expid'
Headliner_df['Расширенная UTM-метка Expid'] = Headliner_df['Расширенная UTM-метка Expid'].fillna('нет')

# %%
print(Headliner_df['Расширенная UTM-метка Expid'].count())
print(Headliner_df['Расширенная UTM-метка Expid'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Расширенная UTM-метка Expid'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Расширенная UTM-метка Expid, dtype: object

# %%
Headliner_df['Расширенная UTM-метка Expid'][Headliner_df['Расширенная UTM-метка Expid'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 33. Длительность разговора

# %%
Headliner_df['Длительность разговора'].head()
# Out:
# 0    00:02:11
# 1    00:01:15
# 2    00:00:29
# 3    00:00:00
# 4    00:01:50
# Name: Длительность разговора, dtype: object

# %%
print(Headliner_df['Длительность разговора'].count())
print(Headliner_df['Длительность разговора'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Длительность разговора'
Headliner_df['Длительность разговора'] = pd.to_datetime(Headliner_df['Длительность разговора']).dt.time

# %%
Headliner_df['Длительность разговора'].tail()
# Out:
# 1537    00:00:51
# 1538    00:00:36
# 1539    00:03:19
# 1540    00:00:05
# 1541    00:00:00
# Name: Длительность разговора, dtype: object

# %% [markdown]
# ##### 34. Длительность постобработки

# %%
Headliner_df['Длительность постобработки'].head()
# Out:
# 0    00:00:00
# 1    00:00:00
# 2    00:00:00
# 3    00:00:00
# 4    00:00:00
# Name: Длительность постобработки, dtype: object

# %%
print(Headliner_df['Длительность постобработки'].count())
print(Headliner_df['Длительность постобработки'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Длительность постобработки'
Headliner_df['Длительность постобработки'] = pd.to_datetime(Headliner_df['Длительность постобработки']).dt.time

# %%
Headliner_df['Длительность постобработки'].tail()
# Out:
# 1537    00:00:00
# 1538    00:00:00
# 1539    00:00:00
# 1540    00:00:00
# 1541    00:00:00
# Name: Длительность постобработки, dtype: object

# %% [markdown]
# ##### 35. Чистая длительность разговора

# %%
Headliner_df['Чистая длительность разговора'].head()
# Out:
# 0    00:02:11
# 1    00:01:15
# 2    00:00:29
# 3    00:00:00
# 4    00:01:50
# Name: Чистая длительность разговора, dtype: object

# %%
print(Headliner_df['Чистая длительность разговора'].count())
print(Headliner_df['Чистая длительность разговора'].shape[0])
# Out:
# 1542
# 1542

# %%
# Приводим тип данных столбца 'Чистая длительность разговора'
Headliner_df['Чистая длительность разговора'] = pd.to_datetime(Headliner_df['Чистая длительность разговора']).dt.time

# %%
Headliner_df['Чистая длительность разговора'].tail()
# Out:
# 1537    00:00:50
# 1538    00:00:36
# 1539    00:03:19
# 1540    00:00:05
# 1541    00:00:00
# Name: Чистая длительность разговора, dtype: object

# %% [markdown]
# ##### 36. AdLense-метка ef_id

# %%
Headliner_df['AdLense-метка ef_id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: AdLense-метка ef_id, dtype: float64

# %%
print(Headliner_df['AdLense-метка ef_id'].count())
print(Headliner_df['AdLense-метка ef_id'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'AdLense-метка ef_id'
Headliner_df['AdLense-метка ef_id'] = Headliner_df['AdLense-метка ef_id'].fillna('нет')

# %%
print(Headliner_df['AdLense-метка ef_id'].count())
print(Headliner_df['AdLense-метка ef_id'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['AdLense-метка ef_id'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: AdLense-метка ef_id, dtype: object

# %%
Headliner_df['AdLense-метка ef_id'][Headliner_df['AdLense-метка ef_id'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 37. Метка yclid

# %%
Headliner_df['Метка yclid'].head()
# Out:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4    1823819050966056959
# Name: Метка yclid, dtype: object

# %%
print(Headliner_df['Метка yclid'].count())
print(Headliner_df['Метка yclid'].shape[0])
# Out:
# 173
# 1542

# %%
# Меняем '' на '0' в столбце 'Метка yclid'
Headliner_df['Метка yclid'] = Headliner_df['Метка yclid'].apply(lambda x: '0' if x == '' else x)

# %%
# Избавляемся от пустот в столбце 'Метка yclid'
Headliner_df['Метка yclid'] = Headliner_df['Метка yclid'].fillna('0')

# %%
print(Headliner_df['Метка yclid'].count())
print(Headliner_df['Метка yclid'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Метка yclid'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: Метка yclid, dtype: object

# %%
Headliner_df['Метка yclid'][Headliner_df['Метка yclid'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 38. Метка ymclid

# %%
Headliner_df['Метка ymclid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Метка ymclid, dtype: float64

# %%
print(Headliner_df['Метка ymclid'].count())
print(Headliner_df['Метка ymclid'].shape[0])
# Out:
# 0
# 1542

# %%
# Меняем '' на '0' в столбце 'Метка ymclid'
Headliner_df['Метка ymclid'] = Headliner_df['Метка ymclid'].apply(lambda x: '0' if x == '' else x)

# %%
# Избавляемся от пустот в столбце 'Метка ymclid'
Headliner_df['Метка ymclid'] = Headliner_df['Метка ymclid'].fillna('0')

# %%
print(Headliner_df['Метка ymclid'].count())
print(Headliner_df['Метка ymclid'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Метка ymclid'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: Метка ymclid, dtype: object

# %%
Headliner_df['Метка ymclid'][Headliner_df['Метка ymclid'] == ''].count()
# Out:
# 0

# %%
Headliner_df['Метка ymclid'][Headliner_df['Метка ymclid'] == '0'].count()
# Out:
# 1542

# %%
Headliner_df['Метка ymclid'][Headliner_df['Метка ymclid'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 39. Метка gclid

# %%
Headliner_df['Метка gclid'].head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Метка gclid, dtype: object

# %%
print(Headliner_df['Метка gclid'].count())
print(Headliner_df['Метка gclid'].shape[0])
# Out:
# 1542
# 1542

# %%
# Меняем '' на '0' в столбце 'Метка gclid'
Headliner_df['Метка gclid'] = Headliner_df['Метка gclid'].apply(lambda x: '0' if x == '' else x)

# %%
Headliner_df['Метка gclid'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: Метка gclid, dtype: object

# %%
Headliner_df['Метка gclid'][Headliner_df['Метка gclid'] == ''].count()
# Out:
# 0

# %%
Headliner_df['Метка gclid'][Headliner_df['Метка gclid'] == '0'].count()
# Out:
# 1542

# %%
Headliner_df['Метка gclid'][Headliner_df['Метка gclid'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 40. Метка from

# %%
Headliner_df['Метка from'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Метка from, dtype: float64

# %%
print(Headliner_df['Метка from'].count())
print(Headliner_df['Метка from'].shape[0])
# Out:
# 0
# 1542

# %%
# Меняем '' на '0' в столбце 'Метка from'
Headliner_df['Метка from'] = Headliner_df['Метка from'].apply(lambda x: '0' if x == '' else x)

# %%
# Избавляемся от пустот в столбце 'Метка from'
Headliner_df['Метка from'] = Headliner_df['Метка from'].fillna('0')

# %%
print(Headliner_df['Метка from'].count())
print(Headliner_df['Метка from'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Метка from'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: Метка from, dtype: object

# %%
Headliner_df['Метка from'][Headliner_df['Метка from'] == ''].count()
# Out:
# 0

# %%
Headliner_df['Метка from'][Headliner_df['Метка from'] == '0'].count()
# Out:
# 1542

# %%
Headliner_df['Метка from'][Headliner_df['Метка from'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 41. OS-метка service-name

# %%
Headliner_df['OS-метка service-name'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка service-name, dtype: float64

# %%
print(Headliner_df['OS-метка service-name'].count())
print(Headliner_df['OS-метка service-name'].shape[0])
# Out:
# 0
# 1542

# %%
# Меняем '' на 'нет' в столбце 'OS-метка service-name'
Headliner_df['OS-метка service-name'] = Headliner_df['OS-метка service-name'].apply(lambda x: 'нет' if x == '' else x)

# %%
# Избавляемся от пустот в столбце 'OS-метка service-name'
Headliner_df['OS-метка service-name'] = Headliner_df['OS-метка service-name'].fillna('нет')

# %%
print(Headliner_df['OS-метка service-name'].count())
print(Headliner_df['OS-метка service-name'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['OS-метка service-name'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: OS-метка service-name, dtype: object

# %%
Headliner_df['OS-метка service-name'][Headliner_df['OS-метка service-name'] == ''].count()
# Out:
# 0

# %%
Headliner_df['OS-метка service-name'][Headliner_df['OS-метка service-name'] == 'нет'].count()
# Out:
# 1542

# %%
Headliner_df['OS-метка service-name'][Headliner_df['OS-метка service-name'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 42. OS-метка campaign-id

# %%
Headliner_df['OS-метка campaign-id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка campaign-id, dtype: float64

# %%
print(Headliner_df['OS-метка campaign-id'].count())
print(Headliner_df['OS-метка campaign-id'].shape[0])
# Out:
# 0
# 1542

# %%
# Меняем '' на '0' в столбце 'OS-метка campaign-id'
Headliner_df['OS-метка campaign-id'] = Headliner_df['OS-метка campaign-id'].apply(lambda x: '0' if x == '' else x)

# %%
# Избавляемся от пустот в столбце 'OS-метка campaign-id'
Headliner_df['OS-метка campaign-id'] = Headliner_df['OS-метка campaign-id'].fillna('0')

# %%
print(Headliner_df['OS-метка campaign-id'].count())
print(Headliner_df['OS-метка campaign-id'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['OS-метка campaign-id'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: OS-метка campaign-id, dtype: object

# %%
Headliner_df['OS-метка campaign-id'][Headliner_df['OS-метка campaign-id'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 43. OS-метка ad-id

# %%
Headliner_df['OS-метка ad-id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка ad-id, dtype: float64

# %%
print(Headliner_df['OS-метка ad-id'].count())
print(Headliner_df['OS-метка ad-id'].shape[0])
# Out:
# 0
# 1542

# %%
# Меняем '' на '0' в столбце 'OS-метка ad-id'
Headliner_df['OS-метка ad-id'] = Headliner_df['OS-метка ad-id'].apply(lambda x: '0' if x == '' else x)

# %%
# Избавляемся от пустот в столбце 'OS-метка ad-id'
Headliner_df['OS-метка ad-id'] = Headliner_df['OS-метка ad-id'].fillna('0')

# %%
print(Headliner_df['OS-метка ad-id'].count())
print(Headliner_df['OS-метка ad-id'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['OS-метка ad-id'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: OS-метка ad-id, dtype: object

# %%
Headliner_df['OS-метка ad-id'][Headliner_df['OS-метка ad-id'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 44. OS-метка source-id

# %%
Headliner_df['OS-метка source-id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка source-id, dtype: float64

# %%
print(Headliner_df['OS-метка source-id'].count())
print(Headliner_df['OS-метка source-id'].shape[0])
# Out:
# 0
# 1542

# %%
# Меняем '' на '0' в столбце 'OS-метка source-id'
Headliner_df['OS-метка source-id'] = Headliner_df['OS-метка source-id'].apply(lambda x: '0' if x == '' else x)

# %%
# Избавляемся от пустот в столбце 'OS-метка source-id'
Headliner_df['OS-метка source-id'] = Headliner_df['OS-метка source-id'].fillna('0')

# %%
print(Headliner_df['OS-метка source-id'].count())
print(Headliner_df['OS-метка source-id'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['OS-метка source-id'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: OS-метка source-id, dtype: object

# %%
Headliner_df['OS-метка source-id'][Headliner_df['OS-метка source-id'] == ''].count()
# Out:
# 0

# %%
Headliner_df['OS-метка source-id'][Headliner_df['OS-метка source-id'] == '0'].count()
# Out:
# 1542

# %%
Headliner_df['OS-метка source-id'][Headliner_df['OS-метка source-id'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 45. UTM-метка Term

# %%
Headliner_df['UTM-метка Term'].head()
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4    46117476237_46117476237
# Name: UTM-метка Term, dtype: object

# %%
print(Headliner_df['UTM-метка Term'].count())
print(Headliner_df['UTM-метка Term'].shape[0])
# Out:
# 172
# 1542

# %%
# Меняем '' на '0' в столбце 'UTM-метка Term'
Headliner_df['UTM-метка Term'] = Headliner_df['UTM-метка Term'].apply(lambda x: '0' if x == '' else x)

# %%
# Избавляемся от пустот в столбце 'UTM-метка Term'
Headliner_df['UTM-метка Term'] = Headliner_df['UTM-метка Term'].fillna('0')

# %%
print(Headliner_df['UTM-метка Term'].count())
print(Headliner_df['UTM-метка Term'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['UTM-метка Term'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: UTM-метка Term, dtype: object

# %%
Headliner_df['UTM-метка Term'][Headliner_df['UTM-метка Term'] == ''].count()
# Out:
# 0

# %%
Headliner_df['UTM-метка Term'][Headliner_df['UTM-метка Term'] == '0'].count()
# Out:
# 1370

# %%
Headliner_df['UTM-метка Term'][Headliner_df['UTM-метка Term'] != '0'].count()
# Out:
# 172

# %% [markdown]
# ##### 46. UTM-метка Referrer

# %%
Headliner_df['UTM-метка Referrer'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: UTM-метка Referrer, dtype: float64

# %%
print(Headliner_df['UTM-метка Referrer'].count())
print(Headliner_df['UTM-метка Referrer'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'UTM-метка Referrer'
Headliner_df['UTM-метка Referrer'] = Headliner_df['UTM-метка Referrer'].fillna('0')

# %%
print(Headliner_df['UTM-метка Referrer'].count())
print(Headliner_df['UTM-метка Referrer'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['UTM-метка Referrer'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: UTM-метка Referrer, dtype: object

# %%
Headliner_df['UTM-метка Referrer'][Headliner_df['UTM-метка Referrer'] == ''].count()
# Out:
# 0

# %%
Headliner_df['UTM-метка Referrer'][Headliner_df['UTM-метка Referrer'] == '0'].count()
# Out:
# 1542

# %%
Headliner_df['UTM-метка Referrer'][Headliner_df['UTM-метка Referrer'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 47. UTM-метка Expid

# %%
Headliner_df['UTM-метка Expid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: UTM-метка Expid, dtype: float64

# %%
print(Headliner_df['UTM-метка Expid'].count())
print(Headliner_df['UTM-метка Expid'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'UTM-метка Expid'
Headliner_df['UTM-метка Expid'] = Headliner_df['UTM-метка Expid'].fillna('0')

# %%
print(Headliner_df['UTM-метка Expid'].count())
print(Headliner_df['UTM-метка Expid'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['UTM-метка Expid'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    0
# 1540    0
# 1541    0
# Name: UTM-метка Expid, dtype: object

# %%
Headliner_df['UTM-метка Expid'][Headliner_df['UTM-метка Expid'] == ''].count()
# Out:
# 0

# %%
Headliner_df['UTM-метка Expid'][Headliner_df['UTM-метка Expid'] == '0'].count()
# Out:
# 1542

# %%
Headliner_df['UTM-метка Expid'][Headliner_df['UTM-метка Expid'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 48. Посадочная страница

# %%
Headliner_df['Посадочная страница'].head()
# Out:
# 0                                                                                                                                                                                        NaN
# 1                                                                                                                                                                     https://head-liner.ru/
# 2                                                                                                                                                                     https://head-liner.ru/
# 3                                                                                                                                                                     https://head-liner.ru/
# 4    https://head-liner.ru/catalog/filter/?queue[]=3&range[price][from]=17500000&range[price][to]=60000000&range[area][from]=90&range[area][to]=120&range[floor][from]=2&range[floor][to]=51
# Name: Посадочная страница, dtype: object

# %%
print(Headliner_df['Посадочная страница'].count())
print(Headliner_df['Посадочная страница'].shape[0])
# Out:
# 461
# 1542

# %%
# Избавляемся от пустот в столбце 'Посадочная страница'
Headliner_df['Посадочная страница'] = Headliner_df['Посадочная страница'].fillna('нет')

# %%
print(Headliner_df['Посадочная страница'].count())
print(Headliner_df['Посадочная страница'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Посадочная страница'].tail()
# Out:
# 1537                                нет
# 1538                                нет
# 1539                                нет
# 1540                                нет
# 1541    https://head-liner.ru/contacts/
# Name: Посадочная страница, dtype: object

# %%
Headliner_df['Посадочная страница'][Headliner_df['Посадочная страница'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 49. Первая рекламная кампания

# %%
Headliner_df['Первая рекламная кампания'].head()
# Out:
# 0    Поисковое продвижение
# 1    Поисковое продвижение
# 2    Поисковое продвижение
# 3    Поисковое продвижение
# 4    Поисковое продвижение
# Name: Первая рекламная кампания, dtype: object

# %%
print(Headliner_df['Первая рекламная кампания'].count())
print(Headliner_df['Первая рекламная кампания'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Первая рекламная кампания'].tail()
# Out:
# 1537    Посетители без рекламной кампании
# 1538    Посетители без рекламной кампании
# 1539                      {Яндекс Директ}
# 1540    Посетители без рекламной кампании
# 1541    Посетители без рекламной кампании
# Name: Первая рекламная кампания, dtype: object

# %%
Headliner_df['Первая рекламная кампания'][Headliner_df['Первая рекламная кампания'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 50. Количество посещений

# %%
Headliner_df['Количество посещений'].head()
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4    14
# Name: Количество посещений, dtype: object

# %%
print(Headliner_df['Количество посещений'].count())
print(Headliner_df['Количество посещений'].shape[0])
# Out:
# 665
# 1542

# %%
# Избавляемся от пустот в столбце 'Количество посещений'
Headliner_df['Количество посещений'] = Headliner_df['Количество посещений'].fillna('0')

# %%
print(Headliner_df['Количество посещений'].count())
print(Headliner_df['Количество посещений'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Количество посещений'].tail()
# Out:
# 1537      0
# 1538      0
# 1539    {1}
# 1540      0
# 1541      1
# Name: Количество посещений, dtype: object

# %%
Headliner_df['Количество посещений'][Headliner_df['Количество посещений'] == ''].count()
# Out:
# 0

# %%
# Приводим тип данных столбца 'Количество посещений'
Headliner_df = Headliner_df.astype({'Количество посещений': str})

# %%
# Убираем '{}' в столбце 'Количество посещений'
Headliner_df['Количество посещений'] = Headliner_df['Количество посещений'].apply(lambda x: x.strip('{}'))

# %%
# Приводим тип данных столбца 'Количество посещений'
Headliner_df = Headliner_df.astype({'Количество посещений': int})

# %%
Headliner_df['Количество посещений'].tail()
# Out:
# 1537    0
# 1538    0
# 1539    1
# 1540    0
# 1541    1
# Name: Количество посещений, dtype: int64

# %% [markdown]
# ##### 51. Тип посетителя

# %%
Headliner_df['Тип посетителя'].head()
# Out:
# 0    Не заполнен
# 1          Новый
# 2          Новый
# 3          Новый
# 4    Вернувшийся
# Name: Тип посетителя, dtype: object

# %%
print(Headliner_df['Тип посетителя'].count())
print(Headliner_df['Тип посетителя'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Тип посетителя'].tail()
# Out:
# 1537      Не заполнен
# 1538      Не заполнен
# 1539    {Не заполнен}
# 1540      Не заполнен
# 1541            Новый
# Name: Тип посетителя, dtype: object

# %%
Headliner_df['Тип посетителя'][Headliner_df['Тип посетителя'] == ''].count()
# Out:
# 0

# %%
# Убираем '{}' в столбце 'Тип посетителя'
Headliner_df['Тип посетителя'] = Headliner_df['Тип посетителя'].apply(lambda x: x.strip('{}'))

# %%
Headliner_df['Тип посетителя'].tail()
# Out:
# 1537    Не заполнен
# 1538    Не заполнен
# 1539    Не заполнен
# 1540    Не заполнен
# 1541          Новый
# Name: Тип посетителя, dtype: object

# %% [markdown]
# ##### 52. Тип устройства

# %%
Headliner_df['Тип устройства'].head()
# Out:
# 0    Прочее
# 1        ПК
# 2        ПК
# 3        ПК
# 4        ПК
# Name: Тип устройства, dtype: object

# %%
print(Headliner_df['Тип устройства'].count())
print(Headliner_df['Тип устройства'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Тип устройства'].tail()
# Out:
# 1537    Прочее
# 1538    Прочее
# 1539    Прочее
# 1540    Прочее
# 1541        ПК
# Name: Тип устройства, dtype: object

# %%
Headliner_df['Тип устройства'][Headliner_df['Тип устройства'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 53. Client ID Google Analytics

# %%
Headliner_df['Client ID Google Analytics'].head()
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4    7.073664e+08
# Name: Client ID Google Analytics, dtype: float64

# %%
print(Headliner_df['Client ID Google Analytics'].count())
print(Headliner_df['Client ID Google Analytics'].shape[0])
# Out:
# 400
# 1542

# %%
# Избавляемся от пустот в столбце 'Client ID Google Analytics'
Headliner_df['Client ID Google Analytics'] = Headliner_df['Client ID Google Analytics'].fillna('0')

# %%
print(Headliner_df['Client ID Google Analytics'].count())
print(Headliner_df['Client ID Google Analytics'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Client ID Google Analytics'].tail()
# Out:
# 1537                    0
# 1538                    0
# 1539                    0
# 1540                    0
# 1541    1243306341.169274
# Name: Client ID Google Analytics, dtype: object

# %%
Headliner_df['Client ID Google Analytics'][Headliner_df['Client ID Google Analytics'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 54. ID ресурса Google Analytics

# %%
Headliner_df['ID ресурса Google Analytics'].head()
# Out:
# 0               NaN
# 1    UA-111037154-1
# 2    UA-111037154-1
# 3    UA-111037154-1
# 4    UA-111037154-1
# Name: ID ресурса Google Analytics, dtype: object

# %%
print(Headliner_df['ID ресурса Google Analytics'].count())
print(Headliner_df['ID ресурса Google Analytics'].shape[0])
# Out:
# 481
# 1542

# %%
# Избавляемся от пустот в столбце 'ID ресурса Google Analytics'
Headliner_df['ID ресурса Google Analytics'] = Headliner_df['ID ресурса Google Analytics'].fillna('0')

# %%
print(Headliner_df['ID ресурса Google Analytics'].count())
print(Headliner_df['ID ресурса Google Analytics'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['ID ресурса Google Analytics'].tail()
# Out:
# 1537                 0
# 1538                 0
# 1539                 0
# 1540                 0
# 1541    UA-111037154-1
# Name: ID ресурса Google Analytics, dtype: object

# %%
Headliner_df['ID ресурса Google Analytics'][Headliner_df['ID ресурса Google Analytics'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 55. ID счетчика Яндекс.Метрика

# %%
Headliner_df['ID счетчика Яндекс.Метрика'].head()
# Out:
# 0           NaN
# 1    46973610.0
# 2    46973610.0
# 3    46973610.0
# 4    46973610.0
# Name: ID счетчика Яндекс.Метрика, dtype: float64

# %%
print(Headliner_df['ID счетчика Яндекс.Метрика'].count())
print(Headliner_df['ID счетчика Яндекс.Метрика'].shape[0])
# Out:
# 481
# 1542

# %%
# Избавляемся от пустот в столбце 'ID счетчика Яндекс.Метрика'
Headliner_df['ID счетчика Яндекс.Метрика'] = Headliner_df['ID счетчика Яндекс.Метрика'].fillna('0')

# %%
print(Headliner_df['ID счетчика Яндекс.Метрика'].count())
print(Headliner_df['ID счетчика Яндекс.Метрика'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['ID счетчика Яндекс.Метрика'].tail()
# Out:
# 1537             0
# 1538             0
# 1539             0
# 1540             0
# 1541    46973610.0
# Name: ID счетчика Яндекс.Метрика, dtype: object

# %%
Headliner_df['ID счетчика Яндекс.Метрика'][Headliner_df['ID счетчика Яндекс.Метрика'] == ''].count()
# Out:
# 0

# %%
# Приводим тип данных столбца 'ID счетчика Яндекс.Метрика'
Headliner_df = Headliner_df.astype({'ID счетчика Яндекс.Метрика': int})

# %%
# Приводим тип данных столбца 'ID счетчика Яндекс.Метрика'
Headliner_df = Headliner_df.astype({'ID счетчика Яндекс.Метрика': str})

# %%
Headliner_df['ID счетчика Яндекс.Метрика'].tail()
# Out:
# 1537           0
# 1538           0
# 1539           0
# 1540           0
# 1541    46973610
# Name: ID счетчика Яндекс.Метрика, dtype: object

# %% [markdown]
# ##### 56. URL страницы обращения

# %%
Headliner_df['URL страницы обращения'].head()
# Out:
# 0                                                                                                                                                                                        NaN
# 1                                                                                                                                                            https://head-liner.ru/contacts/
# 2                                                                                                                                                      https://head-liner.ru/catalog/filter/
# 3                                                                                                                                                                     https://head-liner.ru/
# 4    https://head-liner.ru/catalog/filter/?queue[]=3&range[price][from]=17500000&range[price][to]=60000000&range[area][from]=90&range[area][to]=120&range[floor][from]=2&range[floor][to]=51
# Name: URL страницы обращения, dtype: object

# %%
print(Headliner_df['URL страницы обращения'].count())
print(Headliner_df['URL страницы обращения'].shape[0])
# Out:
# 478
# 1542

# %%
# Избавляемся от пустот в столбце 'URL страницы обращения'
Headliner_df['URL страницы обращения'] = Headliner_df['URL страницы обращения'].fillna('нет')

# %%
print(Headliner_df['URL страницы обращения'].count())
print(Headliner_df['URL страницы обращения'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['URL страницы обращения'] = Headliner_df['URL страницы обращения'].apply(lambda x: x.strip())

# %%
Headliner_df['URL страницы обращения'].tail()
# Out:
# 1537                                нет
# 1538                                нет
# 1539                                нет
# 1540                                нет
# 1541    https://head-liner.ru/contacts/
# Name: URL страницы обращения, dtype: object

# %%
Headliner_df['URL страницы обращения'][Headliner_df['URL страницы обращения'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 57. Страна

# %%
Headliner_df['Страна'].head()
# Out:
# 0       NaN
# 1    Россия
# 2    Россия
# 3    Россия
# 4    Россия
# Name: Страна, dtype: object

# %%
print(Headliner_df['Страна'].count())
print(Headliner_df['Страна'].shape[0])
# Out:
# 461
# 1542

# %%
# Избавляемся от пустот в столбце 'Страна'
Headliner_df['Страна'] = Headliner_df['Страна'].fillna('нет')

# %%
print(Headliner_df['Страна'].count())
print(Headliner_df['Страна'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Страна'].tail()
# Out:
# 1537         нет
# 1538         нет
# 1539         нет
# 1540         нет
# 1541    Германия
# Name: Страна, dtype: object

# %%
Headliner_df['Страна'][Headliner_df['Страна'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 58. Область

# %%
Headliner_df['Область'].head()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4    Москва
# Name: Область, dtype: object

# %%
print(Headliner_df['Область'].count())
print(Headliner_df['Область'].shape[0])
# Out:
# 427
# 1542

# %%
# Избавляемся от пустот в столбце 'Область'
Headliner_df['Область'] = Headliner_df['Область'].fillna('нет')

# %%
print(Headliner_df['Область'].count())
print(Headliner_df['Область'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Область'].tail()
# Out:
# 1537                 нет
# 1538                 нет
# 1539                 нет
# 1540                 нет
# 1541    Баден-Вюртемберг
# Name: Область, dtype: object

# %%
Headliner_df['Область'][Headliner_df['Область'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 59. Город

# %%
Headliner_df['Город'].head()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4    Москва
# Name: Город, dtype: object

# %%
print(Headliner_df['Город'].count())
print(Headliner_df['Город'].shape[0])
# Out:
# 426
# 1542

# %%
# Избавляемся от пустот в столбце 'Город'
Headliner_df['Город'] = Headliner_df['Город'].fillna('нет')

# %%
print(Headliner_df['Город'].count())
print(Headliner_df['Город'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Город'].tail()
# Out:
# 1537         нет
# 1538         нет
# 1539         нет
# 1540         нет
# 1541    Вайнхайм
# Name: Город, dtype: object

# %%
Headliner_df['Город'][Headliner_df['Город'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 60. Поисковая система

# %%
Headliner_df['Поисковая система'].head()
# Out:
# 0           NaN
# 1    google.com
# 2    google.com
# 3    google.com
# 4        yandex
# Name: Поисковая система, dtype: object

# %%
print(Headliner_df['Поисковая система'].count())
print(Headliner_df['Поисковая система'].shape[0])
# Out:
# 227
# 1542

# %%
# Избавляемся от пустот в столбце 'Поисковая система'
Headliner_df['Поисковая система'] = Headliner_df['Поисковая система'].fillna('нет')

# %%
print(Headliner_df['Поисковая система'].count())
print(Headliner_df['Поисковая система'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Поисковая система'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Поисковая система, dtype: object

# %%
Headliner_df['Поисковая система'][Headliner_df['Поисковая система'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 61. Реферер

# %%
Headliner_df['Реферер'].head()
# Out:
# 0                        NaN
# 1    https://www.google.com/
# 2    https://www.google.com/
# 3    https://www.google.com/
# 4         https://yandex.ru/
# Name: Реферер, dtype: object

# %%
print(Headliner_df['Реферер'].count())
print(Headliner_df['Реферер'].shape[0])
# Out:
# 328
# 1542

# %%
# Избавляемся от пустот в столбце 'Реферер'
Headliner_df['Реферер'] = Headliner_df['Реферер'].fillna('нет')

# %%
print(Headliner_df['Реферер'].count())
print(Headliner_df['Реферер'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Реферер'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Реферер, dtype: object

# %%
Headliner_df['Реферер'][Headliner_df['Реферер'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 62. Домен реферера

# %%
Headliner_df['Домен реферера'].head()
# Out:
# 0               NaN
# 1    www.google.com
# 2    www.google.com
# 3    www.google.com
# 4         yandex.ru
# Name: Домен реферера, dtype: object

# %%
print(Headliner_df['Домен реферера'].count())
print(Headliner_df['Домен реферера'].shape[0])
# Out:
# 328
# 1542

# %%
# Избавляемся от пустот в столбце 'Домен реферера'
Headliner_df['Домен реферера'] = Headliner_df['Домен реферера'].fillna('нет')

# %%
print(Headliner_df['Домен реферера'].count())
print(Headliner_df['Домен реферера'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Домен реферера'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Домен реферера, dtype: object

# %%
Headliner_df['Домен реферера'][Headliner_df['Домен реферера'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 63. Сайт

# %%
Headliner_df['Сайт'].head()
# Out:
# 0    head-liner.ru
# 1    head-liner.ru
# 2    head-liner.ru
# 3    head-liner.ru
# 4    head-liner.ru
# Name: Сайт, dtype: object

# %%
print(Headliner_df['Сайт'].count())
print(Headliner_df['Сайт'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Сайт'].tail()
# Out:
# 1537    head-liner.ru
# 1538    head-liner.ru
# 1539    head-liner.ru
# 1540    head-liner.ru
# 1541    head-liner.ru
# Name: Сайт, dtype: object

# %%
Headliner_df['Сайт'][Headliner_df['Сайт'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 64. Оценка сотрудника

# %%
Headliner_df['Оценка сотрудника'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Оценка сотрудника, dtype: float64

# %%
print(Headliner_df['Оценка сотрудника'].count())
print(Headliner_df['Оценка сотрудника'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'Оценка сотрудника'
Headliner_df['Оценка сотрудника'] = Headliner_df['Оценка сотрудника'].fillna('нет')

# %%
print(Headliner_df['Оценка сотрудника'].count())
print(Headliner_df['Оценка сотрудника'].shape[0])
# Out:
# 1542
# 1542

# %%
# Меняем '' на 'нет' в столбце 'Оценка сотрудника'
Headliner_df['Оценка сотрудника'] = Headliner_df['Оценка сотрудника'].apply(lambda x: 'нет' if x == '' else x)

# %%
Headliner_df['Оценка сотрудника'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Оценка сотрудника, dtype: object

# %%
Headliner_df['Оценка сотрудника'][Headliner_df['Оценка сотрудника'] == ''].count()
# Out:
# 0

# %%
Headliner_df['Оценка сотрудника'][Headliner_df['Оценка сотрудника'] == 'нет'].count()
# Out:
# 1542

# %%
Headliner_df['Оценка сотрудника'][Headliner_df['Оценка сотрудника'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 65. Внутренний звонок

# %%
Headliner_df['Внутренний звонок'].head()
# Out:
# 0    Нет
# 1    Нет
# 2    Нет
# 3    Нет
# 4    Нет
# Name: Внутренний звонок, dtype: object

# %%
print(Headliner_df['Внутренний звонок'].count())
print(Headliner_df['Внутренний звонок'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Внутренний звонок'].tail()
# Out:
# 1537    Нет
# 1538    Нет
# 1539    Нет
# 1540    Нет
# 1541    Нет
# Name: Внутренний звонок, dtype: object

# %%
Headliner_df['Внутренний звонок'][Headliner_df['Внутренний звонок'] == ''].count()
# Out:
# 0

# %%
Headliner_df['Внутренний звонок'][Headliner_df['Внутренний звонок'] == 'Нет'].count()
# Out:
# 1539

# %%
Headliner_df['Внутренний звонок'][Headliner_df['Внутренний звонок'] != 'Нет'].count()
# Out:
# 3

# %%
Headliner_df['Внутренний звонок'][Headliner_df['Внутренний звонок'] != 'Нет']
# Out:
# 1050    Да
# 1051    Да
# 1053    Да
# Name: Внутренний звонок, dtype: object

# %% [markdown]
# ##### 66. ФИО контакта

# %%
Headliner_df['ФИО контакта'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: ФИО контакта, dtype: float64

# %%
print(Headliner_df['ФИО контакта'].count())
print(Headliner_df['ФИО контакта'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'ФИО контакта'
Headliner_df['ФИО контакта'] = Headliner_df['ФИО контакта'].fillna('нет')

# %%
print(Headliner_df['ФИО контакта'].count())
print(Headliner_df['ФИО контакта'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['ФИО контакта'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: ФИО контакта, dtype: object

# %%
Headliner_df['ФИО контакта'][Headliner_df['ФИО контакта'] == ''].count()
# Out:
# 0

# %%
Headliner_df['ФИО контакта'][Headliner_df['ФИО контакта'] == 'нет'].count()
# Out:
# 1542

# %%
Headliner_df['ФИО контакта'][Headliner_df['ФИО контакта'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 67. Имя тренера

# %%
Headliner_df['Имя тренера'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Имя тренера, dtype: float64

# %%
print(Headliner_df['Имя тренера'].count())
print(Headliner_df['Имя тренера'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'Имя тренера'
Headliner_df['Имя тренера'] = Headliner_df['Имя тренера'].fillna('нет')

# %%
print(Headliner_df['Имя тренера'].count())
print(Headliner_df['Имя тренера'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Имя тренера'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Имя тренера, dtype: object

# %%
Headliner_df['Имя тренера'][Headliner_df['Имя тренера'] == ''].count()
# Out:
# 0

# %%
Headliner_df['Имя тренера'][Headliner_df['Имя тренера'] == 'нет'].count()
# Out:
# 1542

# %%
Headliner_df['Имя тренера'][Headliner_df['Имя тренера'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 68. Группа, выбранная посетителем

# %%
Headliner_df['Группа, выбранная посетителем'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Группа, выбранная посетителем, dtype: float64

# %%
print(Headliner_df['Группа, выбранная посетителем'].count())
print(Headliner_df['Группа, выбранная посетителем'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'Группа, выбранная посетителем'
Headliner_df['Группа, выбранная посетителем'] = Headliner_df['Группа, выбранная посетителем'].fillna('нет')

# %%
print(Headliner_df['Группа, выбранная посетителем'].count())
print(Headliner_df['Группа, выбранная посетителем'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Группа, выбранная посетителем'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Группа, выбранная посетителем, dtype: object

# %%
Headliner_df['Группа, выбранная посетителем'][Headliner_df['Группа, выбранная посетителем'] == ''].count()
# Out:
# 0

# %%
Headliner_df['Группа, выбранная посетителем'][Headliner_df['Группа, выбранная посетителем'] == 'нет'].count()
# Out:
# 1542

# %%
Headliner_df['Группа, выбранная посетителем'][Headliner_df['Группа, выбранная посетителем'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 69. Регион номера абонента

# %%
Headliner_df['Регион номера абонента'].head()
# Out:
# 0    Кемеровская обл.
# 1    Кемеровская обл.
# 2    Кемеровская обл.
# 3    Кемеровская обл.
# 4           г. Москва
# Name: Регион номера абонента, dtype: object

# %%
print(Headliner_df['Регион номера абонента'].count())
print(Headliner_df['Регион номера абонента'].shape[0])
# Out:
# 1541
# 1542

# %%
# Избавляемся от пустот в столбце 'Регион номера абонента'
Headliner_df['Регион номера абонента'] = Headliner_df['Регион номера абонента'].fillna('не определено')

# %%
print(Headliner_df['Регион номера абонента'].count())
print(Headliner_df['Регион номера абонента'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Регион номера абонента'].tail()
# Out:
# 1537        г. Москва
# 1538        г. Москва
# 1539        г. Москва
# 1540        г. Москва
# 1541    не определено
# Name: Регион номера абонента, dtype: object

# %%
Headliner_df['Регион номера абонента'][Headliner_df['Регион номера абонента'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 70. Страна номера абонента

# %%
Headliner_df['Страна номера абонента'].head()
# Out:
# 0    РФ
# 1    РФ
# 2    РФ
# 3    РФ
# 4    РФ
# Name: Страна номера абонента, dtype: object

# %%
print(Headliner_df['Страна номера абонента'].count())
print(Headliner_df['Страна номера абонента'].shape[0])
# Out:
# 1541
# 1542

# %%
# Избавляемся от пустот в столбце 'Страна номера абонента'
Headliner_df['Страна номера абонента'] = Headliner_df['Страна номера абонента'].fillna('не определено')

# %%
print(Headliner_df['Страна номера абонента'].count())
print(Headliner_df['Страна номера абонента'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Страна номера абонента'].tail()
# Out:
# 1537               РФ
# 1538               РФ
# 1539               РФ
# 1540               РФ
# 1541    не определено
# Name: Страна номера абонента, dtype: object

# %%
Headliner_df['Страна номера абонента'][Headliner_df['Страна номера абонента'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 71. Контакт из CRM

# %%
Headliner_df['Контакт из CRM'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Контакт из CRM, dtype: float64

# %%
print(Headliner_df['Контакт из CRM'].count())
print(Headliner_df['Контакт из CRM'].shape[0])
# Out:
# 0
# 1542

# %%
# Избавляемся от пустот в столбце 'Контакт из CRM'
Headliner_df['Контакт из CRM'] = Headliner_df['Контакт из CRM'].fillna('нет')

# %%
print(Headliner_df['Контакт из CRM'].count())
print(Headliner_df['Контакт из CRM'].shape[0])
# Out:
# 1542
# 1542

# %%
Headliner_df['Контакт из CRM'].tail()
# Out:
# 1537    нет
# 1538    нет
# 1539    нет
# 1540    нет
# 1541    нет
# Name: Контакт из CRM, dtype: object

# %%
Headliner_df['Контакт из CRM'][Headliner_df['Контакт из CRM'] == ''].count()
# Out:
# 0

# %%
Headliner_df['Контакт из CRM'][Headliner_df['Контакт из CRM'] == 'нет'].count()
# Out:
# 1542

# %%
Headliner_df['Контакт из CRM'][Headliner_df['Контакт из CRM'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Headliner_df.dtypes
# Out:
# Статус                                    object
# Тип                                       object
# Дата и время                      datetime64[ns]
# Номер абонента                             int64
# Виртуальный номер                          int64
# Рекламная кампания                        object
# Длительность звонка                       object
# Длительность ожидания ответа              object
# Причина завершения                        object
# Сценарий                                  object
# Сотрудник                                 object
# Комментарий                               object
# UTM-метка Source                          object
# ID посетителя                              int64
# Номер обращения                            int64
# Поисковый запрос                          object
# Теги                                      object
# UTM-метка Campaign                        object
# Номер сотрудника                           int64
# UTM-метка Content                         object
# Client ID Яндекс.Метрика                  object
# UTM-метка Medium                          object
# Операции                                  object
# Трансфер                                  object
# Идентификатор сессии звонка                int64
# Полная длительность ожидания              object
# Расширенная UTM-метка Source              object
# Расширенная UTM-метка Campaign            object
# Расширенная UTM-метка Medium              object
# Расширенная UTM-метка Content             object
# Расширенная UTM-метка Term                object
# Расширенная UTM-метка Referrer            object
# Расширенная UTM-метка Expid               object
# Длительность разговора                    object
# Длительность постобработки                object
# Чистая длительность разговора             object
# AdLense-метка ef_id                       object
# Метка yclid                               object
# Метка ymclid                              object
# Метка gclid                               object
# Метка from                                object
# OS-метка service-name                     object
# OS-метка campaign-id                      object
# OS-метка ad-id                            object
# OS-метка source-id                        object
# UTM-метка Term                            object
# UTM-метка Referrer                        object
# UTM-метка Expid                           object
# Посадочная страница                       object
# Первая рекламная кампания                 object
# Количество посещений                       int64
# Тип посетителя                            object
# Тип устройства                            object
# Client ID Google Analytics                object
# ID ресурса Google Analytics               object
# ID счетчика Яндекс.Метрика                object
# URL страницы обращения                    object
# Страна                                    object
# Область                                   object
# Город                                     object
# Поисковая система                         object
# Реферер                                   object
# Домен реферера                            object
# Сайт                                      object
# Оценка сотрудника                         object
# Внутренний звонок                         object
# ФИО контакта                              object
# Имя тренера                               object
# Группа, выбранная посетителем             object
# Регион номера абонента                    object
# Страна номера абонента                    object
# Контакт из CRM                            object
# dtype: object

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Headliner_df в файл
with open(df_path + 'Headliner_new_df.pkl', 'wb') as f:
  pkl.dump(Headliner_df, f)

# %% [markdown]
# ### Primavera

# %% [markdown]
# #### Создание датафрейма

# %%
# Читаем файл 'Примавера.xlsx' в датафрейм
Primavera_df = pd.read_excel(new_dataset_info_path + 'Примавера.xlsx',
                             skiprows=4)
Primavera_df.shape
# Out:
# (1523, 71)

# %%
Primavera_df.head()
# Out:
#        Статус                   Тип         Дата и время  Номер абонента  \
# 0    Принятый             Аналитика  2023-10-04 19:47:03    7.962401e+10
# 1    Принятый  Омниканальный виджет  2023-10-04 19:40:04    7.938796e+10
# 2    Принятый             Аналитика  2023-10-04 18:13:43    7.926400e+10
# 3  Потерянный  Омниканальный виджет  2023-10-04 18:11:55    7.946456e+10
# 4  Потерянный  Омниканальный виджет  2023-10-04 17:56:51    7.946456e+10
#
#                     Рекламная кампания Длительность звонка  Номер обращения  \
# 0            Roomberry | Лидогенерация            00:05:24                1
# 1                        Яндекс Директ            00:00:34             4346
# 2  Яндекс.Карты (расширенная карточка)            00:01:57               15
# 3    Посетители без рекламной кампании            00:00:03                6
# 4    Посетители без рекламной кампании            00:00:03                5
#
#                                 Теги          Сотрудник  \
# 0                                NaN   Operator7Metrium
# 1                                NaN  Svetlana Aristova
# 2                                NaN   Operator5Metrium
# 3  Не обработано - Нецелевой контакт                NaN
# 4  Не обработано - Нецелевой контакт                NaN
#
#            Первая рекламная кампания  ...  \
# 0  Посетители без рекламной кампании  ...
# 1                      Яндекс Директ  ...
# 2                       {Google SEO}  ...
# 3  Посетители без рекламной кампании  ...
# 4  Посетители без рекламной кампании  ...
#
#                   Расширенная UTM-метка Campaign Расширенная UTM-метка Medium  \
# 0                                            NaN                          NaN
# 1  m108|competitors_new_rsy_mmo|92541971|context                          cpc
# 2                                            NaN                          NaN
# 3                                           m108                          cpc
# 4                                           m108                          cpc
#
#                                                                                     Расширенная UTM-метка Content  \
# 0                                                                                                             NaN
# 1  5255717580|14773407867|46335276624|hoz-house.ru|desktop|14773407867|type1|46335276624|46335276624|0|none|98611
# 2                                                                                                             NaN
# 3                                                                                                             NaN
# 4                                                                                                             NaN
#
#     Расширенная UTM-метка Term Расширенная UTM-метка Referrer  \
# 0                          NaN                            NaN
# 1  river park кутузовский цена                            NaN
# 2                          NaN                            NaN
# 3           yan:video:m100022m                            NaN
# 4           yan:video:m100022m                            NaN
#
#   Расширенная UTM-метка Expid  OS-метка service-name OS-метка campaign-id  \
# 0                         NaN                    NaN                  NaN
# 1                         NaN                    NaN                  NaN
# 2                         NaN                    NaN                  NaN
# 3                         NaN                    NaN                  NaN
# 4                         NaN                    NaN                  NaN
#
#   OS-метка ad-id  OS-метка source-id
# 0            NaN                 NaN
# 1            NaN                 NaN
# 2            NaN                 NaN
# 3            NaN                 NaN
# 4            NaN                 NaN
#
# [5 rows x 71 columns]

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Статус

# %%
Primavera_df['Статус'].head()
# Out:
# 0      Принятый
# 1      Принятый
# 2      Принятый
# 3    Потерянный
# 4    Потерянный
# Name: Статус, dtype: object

# %%
print(Primavera_df['Статус'].count())
print(Primavera_df['Статус'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Статус'].tail()
# Out:
# 1518    Принятый
# 1519    Принятый
# 1520    Принятый
# 1521    Принятый
# 1522    Принятый
# Name: Статус, dtype: object

# %%
Primavera_df['Статус'][Primavera_df['Статус'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 1. Тип

# %%
Primavera_df['Тип'].head()
# Out:
# 0               Аналитика
# 1    Омниканальный виджет
# 2               Аналитика
# 3    Омниканальный виджет
# 4    Омниканальный виджет
# Name: Тип, dtype: object

# %%
print(Primavera_df['Тип'].count())
print(Primavera_df['Тип'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Тип'].tail()
# Out:
# 1518               Аналитика
# 1519               Аналитика
# 1520             Звонок ВАТС
# 1521               Аналитика
# 1522    Омниканальный виджет
# Name: Тип, dtype: object

# %%
Primavera_df['Тип'][Primavera_df['Тип'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 2. Дата и время

# %%
Primavera_df['Дата и время'].head()
# Out:
# 0    2023-10-04 19:47:03
# 1    2023-10-04 19:40:04
# 2    2023-10-04 18:13:43
# 3    2023-10-04 18:11:55
# 4    2023-10-04 17:56:51
# Name: Дата и время, dtype: object

# %%
print(Primavera_df['Дата и время'].count())
print(Primavera_df['Дата и время'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Дата и время'
Primavera_df['Дата и время'] = pd.to_datetime(Primavera_df['Дата и время'])

# %%
Primavera_df['Дата и время'].tail()
# Out:
# 1518   2023-09-01 12:05:19
# 1519   2023-09-01 11:41:53
# 1520   2023-09-01 11:16:24
# 1521   2023-09-01 09:25:53
# 1522   2023-09-01 09:00:12
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 3. Номер абонента

# %%
Primavera_df['Номер абонента'].head()
# Out:
# 0    7.962401e+10
# 1    7.938796e+10
# 2    7.926400e+10
# 3    7.946456e+10
# 4    7.946456e+10
# Name: Номер абонента, dtype: float64

# %%
print(Primavera_df['Номер абонента'].count())
print(Primavera_df['Номер абонента'].shape[0])
# Out:
# 1521
# 1523

# %%
# Избавляемся от пустот в столбце 'Номер абонента'
Primavera_df['Номер абонента'] = Primavera_df['Номер абонента'].fillna('0')

# %%
print(Primavera_df['Номер абонента'].count())
print(Primavera_df['Номер абонента'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Номер абонента'
Primavera_df = Primavera_df.astype({'Номер абонента': int})

# %%
Primavera_df['Номер абонента'].tail()
# Out:
# 1518    79199944228
# 1519    79377999852
# 1520    79161163889
# 1521    79264683596
# 1522    79853452555
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 4. Рекламная кампания

# %%
Primavera_df['Рекламная кампания'].head()
# Out:
# 0              Roomberry | Лидогенерация
# 1                          Яндекс Директ
# 2    Яндекс.Карты (расширенная карточка)
# 3      Посетители без рекламной кампании
# 4      Посетители без рекламной кампании
# Name: Рекламная кампания, dtype: object

# %%
print(Primavera_df['Рекламная кампания'].count())
print(Primavera_df['Рекламная кампания'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Рекламная кампания'].tail()
# Out:
# 1518                     Реферальный трафик
# 1519    Яндекс.Карты (расширенная карточка)
# 1520             Reffection | Лидогенерация
# 1521                   Циан | Базы | Звонок
# 1522                          Яндекс Директ
# Name: Рекламная кампания, dtype: object

# %%
Primavera_df['Рекламная кампания'][Primavera_df['Рекламная кампания'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 5. Длительность звонка

# %%
Primavera_df['Длительность звонка'].head()
# Out:
# 0    00:05:24
# 1    00:00:34
# 2    00:01:57
# 3    00:00:03
# 4    00:00:03
# Name: Длительность звонка, dtype: object

# %%
print(Primavera_df['Длительность звонка'].count())
print(Primavera_df['Длительность звонка'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Длительность звонка'
Primavera_df['Длительность звонка'] = pd.to_datetime(Primavera_df['Длительность звонка']).dt.time

# %%
Primavera_df['Длительность звонка'].tail()
# Out:
# 1518    00:00:22
# 1519    00:02:02
# 1520    00:05:19
# 1521    00:07:07
# 1522    00:00:46
# Name: Длительность звонка, dtype: object

# %% [markdown]
# ##### 6. Номер обращения

# %%
Primavera_df['Номер обращения'].head()
# Out:
# 0       1
# 1    4346
# 2      15
# 3       6
# 4       5
# Name: Номер обращения, dtype: int64

# %%
print(Primavera_df['Номер обращения'].count())
print(Primavera_df['Номер обращения'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Номер обращения'].tail()
# Out:
# 1518     1
# 1519     1
# 1520     2
# 1521     1
# 1522    88
# Name: Номер обращения, dtype: int64

# %% [markdown]
# ##### 7. Теги

# %%
Primavera_df['Теги'].head()
# Out:
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3    Не обработано - Нецелевой контакт
# 4    Не обработано - Нецелевой контакт
# Name: Теги, dtype: object

# %%
print(Primavera_df['Теги'].count())
print(Primavera_df['Теги'].shape[0])
# Out:
# 1511
# 1523

# %%
# Избавляемся от пустот в столбце 'Теги'
Primavera_df['Теги'] = Primavera_df['Теги'].fillna('Не обработано')

# %%
print(Primavera_df['Теги'].count())
print(Primavera_df['Теги'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Теги'].tail()
# Out:
# 1518    Нецелевой контакт - Нецелевой контакт_М108
# 1519                                  Целевой_М108
# 1520                                  Целевой_М108
# 1521                                  Целевой_М108
# 1522                                  Целевой_М108
# Name: Теги, dtype: object

# %%
Primavera_df['Теги'][Primavera_df['Теги'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 8. Сотрудник

# %%
Primavera_df['Сотрудник'].head()
# Out:
# 0     Operator7Metrium
# 1    Svetlana Aristova
# 2     Operator5Metrium
# 3                  NaN
# 4                  NaN
# Name: Сотрудник, dtype: object

# %%
print(Primavera_df['Сотрудник'].count())
print(Primavera_df['Сотрудник'].shape[0])
# Out:
# 780
# 1523

# %%
# Избавляемся от пустот в столбце 'Сотрудник'
Primavera_df['Сотрудник'] = Primavera_df['Сотрудник'].fillna('нет сотрудника')

# %%
print(Primavera_df['Сотрудник'].count())
print(Primavera_df['Сотрудник'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Сотрудник'].tail()
# Out:
# 1518         Operator7Metrium
# 1519    Ekaterina Rumyantseva
# 1520         Operator7Metrium
# 1521         Operator3Metrium
# 1522           Yana Solovyova
# Name: Сотрудник, dtype: object

# %%
Primavera_df['Сотрудник'][Primavera_df['Сотрудник'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 9. Первая рекламная кампания

# %%
Primavera_df['Первая рекламная кампания'].head()
# Out:
# 0    Посетители без рекламной кампании
# 1                        Яндекс Директ
# 2                         {Google SEO}
# 3    Посетители без рекламной кампании
# 4    Посетители без рекламной кампании
# Name: Первая рекламная кампания, dtype: object

# %%
print(Primavera_df['Первая рекламная кампания'].count())
print(Primavera_df['Первая рекламная кампания'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Первая рекламная кампания'].tail()
# Out:
# 1518    Посетители без рекламной кампании
# 1519    Посетители без рекламной кампании
# 1520    Посетители без рекламной кампании
# 1521    Посетители без рекламной кампании
# 1522                        Яндекс Директ
# Name: Первая рекламная кампания, dtype: object

# %%
Primavera_df['Первая рекламная кампания'][Primavera_df['Первая рекламная кампания'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 10. UTM-метка Campaign

# %%
Primavera_df['UTM-метка Campaign'].head()
# Out:
# 0                                              NaN
# 1    m108|competitors_new_rsy_mmo|92541971|context
# 2                                              NaN
# 3                                             m108
# 4                                             m108
# Name: UTM-метка Campaign, dtype: object

# %%
print(Primavera_df['UTM-метка Campaign'].count())
print(Primavera_df['UTM-метка Campaign'].shape[0])
# Out:
# 643
# 1523

# %%
# Избавляемся от пустот в столбце 'UTM-метка Campaign'
Primavera_df['UTM-метка Campaign'] = Primavera_df['UTM-метка Campaign'].fillna('нет')

# %%
print(Primavera_df['UTM-метка Campaign'].count())
print(Primavera_df['UTM-метка Campaign'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['UTM-метка Campaign'].tail()
# Out:
# 1518                                             нет
# 1519                                             нет
# 1520                                             нет
# 1521                                             нет
# 1522    m108|brand_vygoda_search_mmo|87274657|search
# Name: UTM-метка Campaign, dtype: object

# %%
Primavera_df['UTM-метка Campaign'][Primavera_df['UTM-метка Campaign'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 11. UTM-метка Term

# %%
Primavera_df['UTM-метка Term'].head()
# Out:
# 0                            NaN
# 1    river park кутузовский цена
# 2                            NaN
# 3             yan:video:m100022m
# 4             yan:video:m100022m
# Name: UTM-метка Term, dtype: object

# %%
print(Primavera_df['UTM-метка Term'].count())
print(Primavera_df['UTM-метка Term'].shape[0])
# Out:
# 249
# 1523

# %%
# Избавляемся от пустот в столбце 'UTM-метка Term'
Primavera_df['UTM-метка Term'] = Primavera_df['UTM-метка Term'].fillna('нет')

# %%
print(Primavera_df['UTM-метка Term'].count())
print(Primavera_df['UTM-метка Term'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['UTM-метка Term'].tail()
# Out:
# 1518                        нет
# 1519                        нет
# 1520                        нет
# 1521                        нет
# 1522    клубный город примавера
# Name: UTM-метка Term, dtype: object

# %%
Primavera_df['UTM-метка Term'][Primavera_df['UTM-метка Term'] == ''].count()
# Out:
# 0

# %%
Primavera_df['UTM-метка Term'][Primavera_df['UTM-метка Term'] == 'нет'].count()
# Out:
# 1274

# %%
Primavera_df['UTM-метка Term'][Primavera_df['UTM-метка Term'] != 'нет'].count()
# Out:
# 249

# %% [markdown]
# ##### 12. UTM-метка Source

# %%
Primavera_df['UTM-метка Source'].head()
# Out:
# 0        NaN
# 1     yandex
# 2        NaN
# 3    yastreb
# 4    yastreb
# Name: UTM-метка Source, dtype: object

# %%
print(Primavera_df['UTM-метка Source'].count())
print(Primavera_df['UTM-метка Source'].shape[0])
# Out:
# 643
# 1523

# %%
# Избавляемся от пустот в столбце 'UTM-метка Source'
Primavera_df['UTM-метка Source'] = Primavera_df['UTM-метка Source'].fillna('нет')

# %%
print(Primavera_df['UTM-метка Source'].count())
print(Primavera_df['UTM-метка Source'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['UTM-метка Source'].tail()
# Out:
# 1518       нет
# 1519       нет
# 1520       нет
# 1521       нет
# 1522    yandex
# Name: UTM-метка Source, dtype: object

# %%
Primavera_df['UTM-метка Source'][Primavera_df['UTM-метка Source'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 13. UTM-метка Medium

# %%
Primavera_df['UTM-метка Medium'].head()
# Out:
# 0    NaN
# 1    cpc
# 2    NaN
# 3    cpc
# 4    cpc
# Name: UTM-метка Medium, dtype: object

# %%
print(Primavera_df['UTM-метка Medium'].count())
print(Primavera_df['UTM-метка Medium'].shape[0])
# Out:
# 643
# 1523

# %%
# Избавляемся от пустот в столбце 'UTM-метка Medium'
Primavera_df['UTM-метка Medium'] = Primavera_df['UTM-метка Medium'].fillna('нет')

# %%
print(Primavera_df['UTM-метка Medium'].count())
print(Primavera_df['UTM-метка Medium'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['UTM-метка Medium'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    cpc
# Name: UTM-метка Medium, dtype: object

# %%
Primavera_df['UTM-метка Medium'][Primavera_df['UTM-метка Medium'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 14. UTM-метка Content

# %%
Primavera_df['UTM-метка Content'].head()
# Out:
# 0                                                                                                               NaN
# 1    5255717580|14773407867|46335276624|hoz-house.ru|desktop|14773407867|type1|46335276624|46335276624|0|none|98611
# 2                                                                                                               NaN
# 3                                                                                                               NaN
# 4                                                                                                               NaN
# Name: UTM-метка Content, dtype: object

# %%
print(Primavera_df['UTM-метка Content'].count())
print(Primavera_df['UTM-метка Content'].shape[0])
# Out:
# 544
# 1523

# %%
# Избавляемся от пустот в столбце 'UTM-метка Content'
Primavera_df['UTM-метка Content'] = Primavera_df['UTM-метка Content'].fillna('нет')

# %%
print(Primavera_df['UTM-метка Content'].count())
print(Primavera_df['UTM-метка Content'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['UTM-метка Content'].tail()
# Out:
# 1518                                                                                                       нет
# 1519                                                                                                       нет
# 1520                                                                                                       нет
# 1521                                                                                                       нет
# 1522    5188467605|14079055811|44610510913|none|mobile|14079055811|type1|44610510913|44610510913|1|premium|213
# Name: UTM-метка Content, dtype: object

# %%
Primavera_df['UTM-метка Content'][Primavera_df['UTM-метка Content'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 15. Client ID Яндекс.Метрика

# %%
Primavera_df['Client ID Яндекс.Метрика'].head()
# Out:
# 0
# 1    1687687885159084012
# 2
# 3    1696431055788521067
# 4    1696431055788521067
# Name: Client ID Яндекс.Метрика, dtype: object

# %%
print(Primavera_df['Client ID Яндекс.Метрика'].count())
print(Primavera_df['Client ID Яндекс.Метрика'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Client ID Яндекс.Метрика'].tail()
# Out:
# 1518                      0
# 1519                      0
# 1520                      0
# 1521                      0
# 1522    1693520452700448580
# Name: Client ID Яндекс.Метрика, dtype: object

# %%
Primavera_df['Client ID Яндекс.Метрика'][Primavera_df['Client ID Яндекс.Метрика'] == ''].count()
# Out:
# 662

# %%
# Меняем '' на '0' в столбце 'Client ID Яндекс.Метрика'
Primavera_df['Client ID Яндекс.Метрика'] = Primavera_df['Client ID Яндекс.Метрика'].apply(lambda x: '0' if x == '' else x)

# %%
Primavera_df['Client ID Яндекс.Метрика'][Primavera_df['Client ID Яндекс.Метрика'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 16. ID посетителя

# %%
Primavera_df['ID посетителя'].head()
# Out:
# 0             NaN
# 1    7.381792e+09
# 2    7.601193e+09
# 3    7.601243e+09
# 4    7.601243e+09
# Name: ID посетителя, dtype: float64

# %%
print(Primavera_df['ID посетителя'].count())
print(Primavera_df['ID посетителя'].shape[0])
# Out:
# 915
# 1523

# %%
# Избавляемся от пустот в столбце 'ID посетителя'
Primavera_df['ID посетителя'] = Primavera_df['ID посетителя'].fillna('0')

# %%
print(Primavera_df['ID посетителя'].count())
print(Primavera_df['ID посетителя'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'ID посетителя'
Primavera_df = Primavera_df.astype({'ID посетителя': int})

# %%
Primavera_df['ID посетителя'].tail()
# Out:
# 1518             0
# 1519             0
# 1520             0
# 1521             0
# 1522    7526219917
# Name: ID посетителя, dtype: int64

# %% [markdown]
# ##### 17. Страна номера абонента

# %%
Primavera_df['Страна номера абонента'].head()
# Out:
# 0    РФ
# 1    РФ
# 2    РФ
# 3    РФ
# 4    РФ
# Name: Страна номера абонента, dtype: object

# %%
print(Primavera_df['Страна номера абонента'].count())
print(Primavera_df['Страна номера абонента'].shape[0])
# Out:
# 1519
# 1523

# %%
# Избавляемся от пустот в столбце 'Страна номера абонента'
Primavera_df['Страна номера абонента'] = Primavera_df['Страна номера абонента'].fillna('нет')

# %%
print(Primavera_df['Страна номера абонента'].count())
print(Primavera_df['Страна номера абонента'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Страна номера абонента'].tail()
# Out:
# 1518    РФ
# 1519    РФ
# 1520    РФ
# 1521    РФ
# 1522    РФ
# Name: Страна номера абонента, dtype: object

# %%
Primavera_df['Страна номера абонента'][Primavera_df['Страна номера абонента'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 18. Регион номера абонента

# %%
Primavera_df['Регион номера абонента'].head()
# Out:
# 0    Ставропольский край
# 1    Республика Дагестан
# 2              г. Москва
# 3     РФ / не определено
# 4     РФ / не определено
# Name: Регион номера абонента, dtype: object

# %%
print(Primavera_df['Регион номера абонента'].count())
print(Primavera_df['Регион номера абонента'].shape[0])
# Out:
# 1519
# 1523

# %%
# Избавляемся от пустот в столбце 'Регион номера абонента'
Primavera_df['Регион номера абонента'] = Primavera_df['Регион номера абонента'].fillna('нет')

# %%
print(Primavera_df['Регион номера абонента'].count())
print(Primavera_df['Регион номера абонента'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Регион номера абонента'].tail()
# Out:
# 1518         г. Москва
# 1519    Самарская обл.
# 1520         г. Москва
# 1521         г. Москва
# 1522         г. Москва
# Name: Регион номера абонента, dtype: object

# %%
Primavera_df['Регион номера абонента'][Primavera_df['Регион номера абонента'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 19. Идентификатор звонка во внешней системе

# %%
Primavera_df['Идентификатор звонка во внешней системе'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Идентификатор звонка во внешней системе, dtype: float64

# %%
print(Primavera_df['Идентификатор звонка во внешней системе'].count())
print(Primavera_df['Идентификатор звонка во внешней системе'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Идентификатор звонка во внешней системе'
Primavera_df['Идентификатор звонка во внешней системе'] = Primavera_df['Идентификатор звонка во внешней системе'].fillna('0')

# %%
print(Primavera_df['Идентификатор звонка во внешней системе'].count())
print(Primavera_df['Идентификатор звонка во внешней системе'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Идентификатор звонка во внешней системе'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: Идентификатор звонка во внешней системе, dtype: object

# %%
Primavera_df['Идентификатор звонка во внешней системе'][Primavera_df['Идентификатор звонка во внешней системе'] == ''].count()
# Out:
# 0

# %%
# Приводим тип данных столбца 'Идентификатор звонка во внешней системе'
Primavera_df = Primavera_df.astype({'Идентификатор звонка во внешней системе': int})

# %% [markdown]
# ##### 20. Тип устройства

# %%
Primavera_df['Тип устройства'].head()
# Out:
# 0    Прочее
# 1        ПК
# 2    Прочее
# 3        ПК
# 4        ПК
# Name: Тип устройства, dtype: object

# %%
print(Primavera_df['Тип устройства'].count())
print(Primavera_df['Тип устройства'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Тип устройства'].tail()
# Out:
# 1518      Прочее
# 1519      Прочее
# 1520      Прочее
# 1521      Прочее
# 1522    Смартфон
# Name: Тип устройства, dtype: object

# %%
Primavera_df['Тип устройства'][Primavera_df['Тип устройства'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 21. URL страницы обращения

# %%
Primavera_df['URL страницы обращения'].head()
# Out:
# 0                                    NaN
# 1    https://primavera.moscow/#factoids=
# 2                                    NaN
# 3              https://primavera.moscow/
# 4              https://primavera.moscow/
# Name: URL страницы обращения, dtype: object

# %%
print(Primavera_df['URL страницы обращения'].count())
print(Primavera_df['URL страницы обращения'].shape[0])
# Out:
# 880
# 1523

# %%
# Избавляемся от пустот в столбце 'URL страницы обращения'
Primavera_df['URL страницы обращения'] = Primavera_df['URL страницы обращения'].fillna('нет')

# %%
print(Primavera_df['URL страницы обращения'].count())
print(Primavera_df['URL страницы обращения'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['URL страницы обращения'].tail()
# Out:
# 1518                                 нет
# 1519                                 нет
# 1520                                 нет
# 1521                                 нет
# 1522    https://primavera.moscow/company
# Name: URL страницы обращения, dtype: object

# %%
Primavera_df['URL страницы обращения'][Primavera_df['URL страницы обращения'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 22. Город

# %%
Primavera_df['Город'].head()
# Out:
# 0       NaN
# 1    Москва
# 2       NaN
# 3       NaN
# 4       NaN
# Name: Город, dtype: object

# %%
print(Primavera_df['Город'].count())
print(Primavera_df['Город'].shape[0])
# Out:
# 716
# 1523

# %%
# Избавляемся от пустот в столбце 'Город'
Primavera_df['Город'] = Primavera_df['Город'].fillna('нет')

# %%
print(Primavera_df['Город'].count())
print(Primavera_df['Город'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Город'].tail()
# Out:
# 1518       нет
# 1519       нет
# 1520       нет
# 1521       нет
# 1522    Москва
# Name: Город, dtype: object

# %%
Primavera_df['Город'][Primavera_df['Город'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 23. Страна

# %%
Primavera_df['Страна'].head()
# Out:
# 0       NaN
# 1    Россия
# 2       NaN
# 3    Россия
# 4    Россия
# Name: Страна, dtype: object

# %%
print(Primavera_df['Страна'].count())
print(Primavera_df['Страна'].shape[0])
# Out:
# 873
# 1523

# %%
# Избавляемся от пустот в столбце 'Страна'
Primavera_df['Страна'] = Primavera_df['Страна'].fillna('нет')

# %%
print(Primavera_df['Страна'].count())
print(Primavera_df['Страна'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Страна'].tail()
# Out:
# 1518       нет
# 1519       нет
# 1520       нет
# 1521       нет
# 1522    Россия
# Name: Страна, dtype: object

# %%
Primavera_df['Страна'][Primavera_df['Страна'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 24. Сайт

# %%
Primavera_df['Сайт'].head()
# Out:
# 0    primavera.moscow
# 1    primavera.moscow
# 2    primavera.moscow
# 3    primavera.moscow
# 4    primavera.moscow
# Name: Сайт, dtype: object

# %%
print(Primavera_df['Сайт'].count())
print(Primavera_df['Сайт'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Сайт'].tail()
# Out:
# 1518    primavera.moscow
# 1519    primavera.moscow
# 1520    primavera.moscow
# 1521    primavera.moscow
# 1522    primavera.moscow
# Name: Сайт, dtype: object

# %%
Primavera_df['Сайт'][Primavera_df['Сайт'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 25. Оценка сотрудника

# %%
Primavera_df['Оценка сотрудника'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Оценка сотрудника, dtype: float64

# %%
print(Primavera_df['Оценка сотрудника'].count())
print(Primavera_df['Оценка сотрудника'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Оценка сотрудника'
Primavera_df['Оценка сотрудника'] = Primavera_df['Оценка сотрудника'].fillna('нет')

# %%
print(Primavera_df['Оценка сотрудника'].count())
print(Primavera_df['Оценка сотрудника'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Оценка сотрудника'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    нет
# Name: Оценка сотрудника, dtype: object

# %%
Primavera_df['Оценка сотрудника'][Primavera_df['Оценка сотрудника'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Оценка сотрудника'][Primavera_df['Оценка сотрудника'] == 'нет'].count()
# Out:
# 1523

# %%
Primavera_df['Оценка сотрудника'][Primavera_df['Оценка сотрудника'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 26. Номер сотрудника

# %%
Primavera_df['Номер сотрудника'].head()
# Out:
# 0    111652.0
# 1    253206.0
# 2    111642.0
# 3         NaN
# 4         NaN
# Name: Номер сотрудника, dtype: float64

# %%
print(Primavera_df['Номер сотрудника'].count())
print(Primavera_df['Номер сотрудника'].shape[0])
# Out:
# 1104
# 1523

# %%
# Избавляемся от пустот в столбце 'Номер сотрудника'
Primavera_df['Номер сотрудника'] = Primavera_df['Номер сотрудника'].fillna('0')

# %%
print(Primavera_df['Номер сотрудника'].count())
print(Primavera_df['Номер сотрудника'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Primavera_df = Primavera_df.astype({'Номер сотрудника': int})

# %%
Primavera_df['Номер сотрудника'].tail()
# Out:
# 1518    111652
# 1519    253201
# 1520    111652
# 1521    111639
# 1522    253211
# Name: Номер сотрудника, dtype: int64

# %%
Primavera_df['Номер сотрудника'][Primavera_df['Номер сотрудника'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 27. Трансфер

# %%
Primavera_df['Трансфер'].head()
# Out:
# 0    Нет
# 1    Нет
# 2    Нет
# 3    Нет
# 4    Нет
# Name: Трансфер, dtype: object

# %%
print(Primavera_df['Трансфер'].count())
print(Primavera_df['Трансфер'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Трансфер'].tail()
# Out:
# 1518    Нет
# 1519    Нет
# 1520    Нет
# 1521    Нет
# 1522    Нет
# Name: Трансфер, dtype: object

# %%
Primavera_df['Трансфер'][Primavera_df['Трансфер'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 28. Внутренний звонок

# %%
Primavera_df['Внутренний звонок'].head()
# Out:
# 0    Нет
# 1    Нет
# 2    Нет
# 3    Нет
# 4    Нет
# Name: Внутренний звонок, dtype: object

# %%
print(Primavera_df['Внутренний звонок'].count())
print(Primavera_df['Внутренний звонок'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Внутренний звонок'].tail()
# Out:
# 1518    Нет
# 1519    Нет
# 1520    Нет
# 1521    Нет
# 1522    Нет
# Name: Внутренний звонок, dtype: object

# %%
Primavera_df['Внутренний звонок'][Primavera_df['Внутренний звонок'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Внутренний звонок'][Primavera_df['Внутренний звонок'] == 'Нет'].count()
# Out:
# 1517

# %%
Primavera_df['Внутренний звонок'][Primavera_df['Внутренний звонок'] != 'Нет'].count()
# Out:
# 6

# %%
Primavera_df['Внутренний звонок'][Primavera_df['Внутренний звонок'] != 'Нет']
# Out:
# 392     Да
# 1000    Да
# 1368    Да
# 1383    Да
# 1409    Да
# 1410    Да
# Name: Внутренний звонок, dtype: object

# %% [markdown]
# ##### 29. ФИО контакта

# %%
Primavera_df['ФИО контакта'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: ФИО контакта, dtype: float64

# %%
print(Primavera_df['ФИО контакта'].count())
print(Primavera_df['ФИО контакта'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'ФИО контакта'
Primavera_df['ФИО контакта'] = Primavera_df['ФИО контакта'].fillna('нет')

# %%
print(Primavera_df['ФИО контакта'].count())
print(Primavera_df['ФИО контакта'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['ФИО контакта'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    нет
# Name: ФИО контакта, dtype: object

# %%
Primavera_df['ФИО контакта'][Primavera_df['ФИО контакта'] == ''].count()
# Out:
# 0

# %%
Primavera_df['ФИО контакта'][Primavera_df['ФИО контакта'] == 'нет'].count()
# Out:
# 1523

# %%
Primavera_df['ФИО контакта'][Primavera_df['ФИО контакта'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 30. Имя тренера

# %%
Primavera_df['Имя тренера'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Имя тренера, dtype: float64

# %%
print(Primavera_df['Имя тренера'].count())
print(Primavera_df['Имя тренера'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Имя тренера'
Primavera_df['Имя тренера'] = Primavera_df['Имя тренера'].fillna('нет')

# %%
print(Primavera_df['Имя тренера'].count())
print(Primavera_df['Имя тренера'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Имя тренера'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    нет
# Name: Имя тренера, dtype: object

# %%
Primavera_df['Имя тренера'][Primavera_df['Имя тренера'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Имя тренера'][Primavera_df['Имя тренера'] == 'нет'].count()
# Out:
# 1523

# %%
Primavera_df['Имя тренера'][Primavera_df['Имя тренера'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 31. Сценарий

# %%
Primavera_df['Сценарий'].head()
# Out:
# 0                 Обработка вызова 2023
# 1    Обработка вызова 2023 для колбэков
# 2                 Обработка вызова 2023
# 3    Обработка вызова 2023 для колбэков
# 4    Обработка вызова 2023 для колбэков
# Name: Сценарий, dtype: object

# %%
print(Primavera_df['Сценарий'].count())
print(Primavera_df['Сценарий'].shape[0])
# Out:
# 1472
# 1523

# %%
# Избавляемся от пустот в столбце 'Сценарий'
Primavera_df['Сценарий'] = Primavera_df['Сценарий'].fillna('нет сценария')

# %%
print(Primavera_df['Сценарий'].count())
print(Primavera_df['Сценарий'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Сценарий'].tail()
# Out:
# 1518                 Обработка вызова 2023
# 1519                 Обработка вызова 2023
# 1520                 Обработка вызова 2023
# 1521                 Обработка вызова 2023
# 1522    Обработка вызова 2023 для колбэков
# Name: Сценарий, dtype: object

# %%
Primavera_df['Сценарий'][Primavera_df['Сценарий'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 32. Операции

# %%
Primavera_df['Операции'].head()
# Out:
# 0                                      Интерактивная обработка вызова 1
# 1    Интерактивная обработка вызова 1, Интерактивная обработка вызова 1
# 2                                      Интерактивная обработка вызова 1
# 3                                      Интерактивная обработка вызова 1
# 4                                      Интерактивная обработка вызова 1
# Name: Операции, dtype: object

# %%
print(Primavera_df['Операции'].count())
print(Primavera_df['Операции'].shape[0])
# Out:
# 1472
# 1523

# %%
# Избавляемся от пустот в столбце 'Операции'
Primavera_df['Операции'] = Primavera_df['Операции'].fillna('нет операций')

# %%
print(Primavera_df['Операции'].count())
print(Primavera_df['Операции'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Операции'].tail()
# Out:
# 1518                                      Интерактивная обработка вызова 1
# 1519    Интерактивная обработка вызова 1, Интерактивная обработка вызова 2
# 1520                                      Интерактивная обработка вызова 1
# 1521                                      Интерактивная обработка вызова 1
# 1522    Интерактивная обработка вызова 1, Интерактивная обработка вызова 1
# Name: Операции, dtype: object

# %%
Primavera_df['Операции'][Primavera_df['Операции'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 33. Идентификатор сессии звонка

# %%
Primavera_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3264304568
# 1    3276780397
# 2    3269705084
# 3    3276629522
# 4    3276598592
# Name: Идентификатор сессии звонка, dtype: int64

# %%
print(Primavera_df['Идентификатор сессии звонка'].count())
print(Primavera_df['Идентификатор сессии звонка'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Идентификатор сессии звонка'].tail()
# Out:
# 1518    3188422720
# 1519    3188347120
# 1520    3195799881
# 1521    3187995780
# 1522    3200997782
# Name: Идентификатор сессии звонка, dtype: int64

# %% [markdown]
# ##### 34. Группа, выбранная посетителем

# %%
Primavera_df['Группа, выбранная посетителем'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Группа, выбранная посетителем, dtype: float64

# %%
print(Primavera_df['Группа, выбранная посетителем'].count())
print(Primavera_df['Группа, выбранная посетителем'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Группа, выбранная посетителем'
Primavera_df['Группа, выбранная посетителем'] = Primavera_df['Группа, выбранная посетителем'].fillna('нет')

# %%
print(Primavera_df['Группа, выбранная посетителем'].count())
print(Primavera_df['Группа, выбранная посетителем'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Группа, выбранная посетителем'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    нет
# Name: Группа, выбранная посетителем, dtype: object

# %%
Primavera_df['Группа, выбранная посетителем'][Primavera_df['Группа, выбранная посетителем'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Группа, выбранная посетителем'][Primavera_df['Группа, выбранная посетителем'] == 'нет'].count()
# Out:
# 1523

# %%
Primavera_df['Группа, выбранная посетителем'][Primavera_df['Группа, выбранная посетителем'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 35. Длительность обработки

# %%
Primavera_df['Длительность обработки'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Длительность обработки, dtype: float64

# %%
print(Primavera_df['Длительность обработки'].count())
print(Primavera_df['Длительность обработки'].shape[0])
# Out:
# 92
# 1523

# %%
# Избавляемся от пустот в столбце 'Длительность обработки'
Primavera_df['Длительность обработки'] = Primavera_df['Длительность обработки'].fillna('0')

# %%
print(Primavera_df['Длительность обработки'].count())
print(Primavera_df['Длительность обработки'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Длительность обработки'
Primavera_df = Primavera_df.astype({'Длительность обработки': int})

# %%
Primavera_df['Длительность обработки'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: Длительность обработки, dtype: int64

# %%
Primavera_df['Длительность обработки'][Primavera_df['Длительность обработки'] != 0].count()
# Out:
# 92

# %%
Primavera_df['Длительность обработки'][Primavera_df['Длительность обработки'] != 0].head()
# Out:
# 8      67
# 26    345
# 38     37
# 72    504
# 98    412
# Name: Длительность обработки, dtype: int64

# %% [markdown]
# ##### 36. Комментарий

# %%
Primavera_df['Комментарий'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Комментарий, dtype: float64

# %%
print(Primavera_df['Комментарий'].count())
print(Primavera_df['Комментарий'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Комментарий'
Primavera_df['Комментарий'] = Primavera_df['Комментарий'].fillna('нет комментария')

# %%
print(Primavera_df['Комментарий'].count())
print(Primavera_df['Комментарий'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Комментарий'].tail()
# Out:
# 1518    нет комментария
# 1519    нет комментария
# 1520    нет комментария
# 1521    нет комментария
# 1522    нет комментария
# Name: Комментарий, dtype: object

# %%
Primavera_df['Комментарий'][Primavera_df['Комментарий'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 37. Контакт из CRM

# %%
Primavera_df['Контакт из CRM'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Контакт из CRM, dtype: float64

# %%
print(Primavera_df['Контакт из CRM'].count())
print(Primavera_df['Контакт из CRM'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Контакт из CRM'
Primavera_df['Контакт из CRM'] = Primavera_df['Контакт из CRM'].fillna('нет')

# %%
print(Primavera_df['Контакт из CRM'].count())
print(Primavera_df['Контакт из CRM'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Контакт из CRM'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    нет
# Name: Контакт из CRM, dtype: object

# %%
Primavera_df['Контакт из CRM'][Primavera_df['Контакт из CRM'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Контакт из CRM'][Primavera_df['Контакт из CRM'] == 'нет'].count()
# Out:
# 1523

# %%
Primavera_df['Контакт из CRM'][Primavera_df['Контакт из CRM'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 38. Поисковая система

# %%
Primavera_df['Поисковая система'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Поисковая система, dtype: object

# %%
print(Primavera_df['Поисковая система'].count())
print(Primavera_df['Поисковая система'].shape[0])
# Out:
# 229
# 1523

# %%
# Избавляемся от пустот в столбце 'Поисковая система'
Primavera_df['Поисковая система'] = Primavera_df['Поисковая система'].fillna('нет')

# %%
print(Primavera_df['Поисковая система'].count())
print(Primavera_df['Поисковая система'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Поисковая система'].tail()
# Out:
# 1518       нет
# 1519       нет
# 1520       нет
# 1521       нет
# 1522    yandex
# Name: Поисковая система, dtype: object

# %%
Primavera_df['Поисковая система'][Primavera_df['Поисковая система'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 39. Поисковый запрос

# %%
Primavera_df['Поисковый запрос'].head()
# Out:
# 0                            NaN
# 1    river park кутузовский цена
# 2                            NaN
# 3             yan:video:m100022m
# 4             yan:video:m100022m
# Name: Поисковый запрос, dtype: object

# %%
print(Primavera_df['Поисковый запрос'].count())
print(Primavera_df['Поисковый запрос'].shape[0])
# Out:
# 391
# 1523

# %%
# Избавляемся от пустот в столбце 'Поисковый запрос'
Primavera_df['Поисковый запрос'] = Primavera_df['Поисковый запрос'].fillna('нет запроса')

# %%
print(Primavera_df['Поисковый запрос'].count())
print(Primavera_df['Поисковый запрос'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Поисковый запрос'].tail()
# Out:
# 1518                нет запроса
# 1519                нет запроса
# 1520                нет запроса
# 1521                нет запроса
# 1522    клубный город примавера
# Name: Поисковый запрос, dtype: object

# %%
Primavera_df['Поисковый запрос'][Primavera_df['Поисковый запрос'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 40. Реферер

# %%
Primavera_df['Реферер'].head()
# Out:
# 0                             NaN
# 1           https://hoz-house.ru/
# 2                             NaN
# 3    https://home-rent-vr-sim.ru/
# 4    https://home-rent-vr-sim.ru/
# Name: Реферер, dtype: object

# %%
print(Primavera_df['Реферер'].count())
print(Primavera_df['Реферер'].shape[0])
# Out:
# 737
# 1523

# %%
# Избавляемся от пустот в столбце 'Реферер'
Primavera_df['Реферер'] = Primavera_df['Реферер'].fillna('нет')

# %%
print(Primavera_df['Реферер'].count())
print(Primavera_df['Реферер'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Реферер'].tail()
# Out:
# 1518                   нет
# 1519                   нет
# 1520                   нет
# 1521                   нет
# 1522    https://yandex.ru/
# Name: Реферер, dtype: object

# %%
Primavera_df['Реферер'][Primavera_df['Реферер'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 41. Домен реферера

# %%
Primavera_df['Домен реферера'].head()
# Out:
# 0                    NaN
# 1           hoz-house.ru
# 2                    NaN
# 3    home-rent-vr-sim.ru
# 4    home-rent-vr-sim.ru
# Name: Домен реферера, dtype: object

# %%
print(Primavera_df['Домен реферера'].count())
print(Primavera_df['Домен реферера'].shape[0])
# Out:
# 737
# 1523

# %%
# Избавляемся от пустот в столбце 'Домен реферера'
Primavera_df['Домен реферера'] = Primavera_df['Домен реферера'].fillna('нет')

# %%
print(Primavera_df['Домен реферера'].count())
print(Primavera_df['Домен реферера'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Домен реферера'].tail()
# Out:
# 1518          нет
# 1519          нет
# 1520          нет
# 1521          нет
# 1522    yandex.ru
# Name: Домен реферера, dtype: object

# %%
Primavera_df['Домен реферера'][Primavera_df['Домен реферера'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 42. Область

# %%
Primavera_df['Область'].head()
# Out:
# 0       NaN
# 1    Москва
# 2       NaN
# 3       NaN
# 4       NaN
# Name: Область, dtype: object

# %%
print(Primavera_df['Область'].count())
print(Primavera_df['Область'].shape[0])
# Out:
# 720
# 1523

# %%
# Избавляемся от пустот в столбце 'Область'
Primavera_df['Область'] = Primavera_df['Область'].fillna('нет')

# %%
print(Primavera_df['Область'].count())
print(Primavera_df['Область'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Область'].tail()
# Out:
# 1518       нет
# 1519       нет
# 1520       нет
# 1521       нет
# 1522    Москва
# Name: Область, dtype: object

# %%
Primavera_df['Область'][Primavera_df['Область'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 43. Посадочная страница

# %%
Primavera_df['Посадочная страница'].head()
# Out:
# 0                          NaN
# 1    https://primavera.moscow/
# 2                          NaN
# 3    https://primavera.moscow/
# 4    https://primavera.moscow/
# Name: Посадочная страница, dtype: object

# %%
print(Primavera_df['Посадочная страница'].count())
print(Primavera_df['Посадочная страница'].shape[0])
# Out:
# 873
# 1523

# %%
# Избавляемся от пустот в столбце 'Посадочная страница'
Primavera_df['Посадочная страница'] = Primavera_df['Посадочная страница'].fillna('нет')

# %%
print(Primavera_df['Посадочная страница'].count())
print(Primavera_df['Посадочная страница'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Посадочная страница'].tail()
# Out:
# 1518                          нет
# 1519                          нет
# 1520                          нет
# 1521                          нет
# 1522    https://primavera.moscow/
# Name: Посадочная страница, dtype: object

# %%
Primavera_df['Посадочная страница'][Primavera_df['Посадочная страница'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 44. Количество посещений

# %%
Primavera_df['Количество посещений'].head()
# Out:
# 0    NaN
# 1     28
# 2    {1}
# 3      1
# 4      1
# Name: Количество посещений, dtype: object

# %%
print(Primavera_df['Количество посещений'].count())
print(Primavera_df['Количество посещений'].shape[0])
# Out:
# 909
# 1523

# %%
# Избавляемся от пустот в столбце 'Количество посещений'
Primavera_df['Количество посещений'] = Primavera_df['Количество посещений'].fillna('0')

# %%
print(Primavera_df['Количество посещений'].count())
print(Primavera_df['Количество посещений'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Количество посещений'][Primavera_df['Количество посещений'] == ''].count()
# Out:
# 0

# %%
# Приводим тип данных столбца 'Количество посещений'
Primavera_df = Primavera_df.astype({'Количество посещений': str})

# %%
# Убираем '{}' в столбце 'Количество посещений'
Primavera_df['Количество посещений'] = Primavera_df['Количество посещений'].apply(lambda x: x.strip('{}'))

# %%
# Приводим тип данных столбца 'Количество посещений'
Primavera_df = Primavera_df.astype({'Количество посещений': int})

# %%
Primavera_df['Количество посещений'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    1
# Name: Количество посещений, dtype: int64

# %% [markdown]
# ##### 45. Тип посетителя

# %%
Primavera_df['Тип посетителя'].head()
# Out:
# 0      Не заполнен
# 1      Вернувшийся
# 2    {Не заполнен}
# 3            Новый
# 4            Новый
# Name: Тип посетителя, dtype: object

# %%
print(Primavera_df['Тип посетителя'].count())
print(Primavera_df['Тип посетителя'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Тип посетителя'][Primavera_df['Тип посетителя'] == ''].count()
# Out:
# 0

# %%
# Убираем '{}' в столбце 'Тип посетителя'
Primavera_df['Тип посетителя'] = Primavera_df['Тип посетителя'].apply(lambda x: x.strip('{}'))

# %%
Primavera_df['Тип посетителя'].tail()
# Out:
# 1518    Не заполнен
# 1519    Не заполнен
# 1520    Не заполнен
# 1521    Не заполнен
# 1522          Новый
# Name: Тип посетителя, dtype: object

# %% [markdown]
# ##### 46. Client ID Google Analytics

# %%
Primavera_df['Client ID Google Analytics'].head()
# Out:
# 0             NaN
# 1    4.147668e+08
# 2             NaN
# 3    1.793628e+09
# 4    1.793628e+09
# Name: Client ID Google Analytics, dtype: float64

# %%
print(Primavera_df['Client ID Google Analytics'].count())
print(Primavera_df['Client ID Google Analytics'].shape[0])
# Out:
# 830
# 1523

# %%
# Избавляемся от пустот в столбце 'Client ID Google Analytics'
Primavera_df['Client ID Google Analytics'] = Primavera_df['Client ID Google Analytics'].fillna('0')

# %%
print(Primavera_df['Client ID Google Analytics'].count())
print(Primavera_df['Client ID Google Analytics'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Client ID Google Analytics'][Primavera_df['Client ID Google Analytics'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Client ID Google Analytics'].tail()
# Out:
# 1518                    0
# 1519                    0
# 1520                    0
# 1521                    0
# 1522    1741185642.169352
# Name: Client ID Google Analytics, dtype: object

# %% [markdown]
# ##### 47. ID ресурса Google Analytics

# %%
Primavera_df['ID ресурса Google Analytics'].head()
# Out:
# 0               NaN
# 1    UA-211696639-1
# 2               NaN
# 3    UA-211696639-1
# 4    UA-211696639-1
# Name: ID ресурса Google Analytics, dtype: object

# %%
print(Primavera_df['ID ресурса Google Analytics'].count())
print(Primavera_df['ID ресурса Google Analytics'].shape[0])
# Out:
# 880
# 1523

# %%
# Избавляемся от пустот в столбце 'ID ресурса Google Analytics'
Primavera_df['ID ресурса Google Analytics'] = Primavera_df['ID ресурса Google Analytics'].fillna('0')

# %%
print(Primavera_df['ID ресурса Google Analytics'].count())
print(Primavera_df['ID ресурса Google Analytics'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['ID ресурса Google Analytics'].tail()
# Out:
# 1518                 0
# 1519                 0
# 1520                 0
# 1521                 0
# 1522    UA-211696639-1
# Name: ID ресурса Google Analytics, dtype: object

# %%
Primavera_df['ID ресурса Google Analytics'][Primavera_df['ID ресурса Google Analytics'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 48. ID счетчика Яндекс.Метрика

# %%
Primavera_df['ID счетчика Яндекс.Метрика'].head()
# Out:
# 0           NaN
# 1    86217072.0
# 2           NaN
# 3    86217072.0
# 4    86217072.0
# Name: ID счетчика Яндекс.Метрика, dtype: float64

# %%
print(Primavera_df['ID счетчика Яндекс.Метрика'].count())
print(Primavera_df['ID счетчика Яндекс.Метрика'].shape[0])
# Out:
# 880
# 1523

# %%
# Избавляемся от пустот в столбце 'ID счетчика Яндекс.Метрика'
Primavera_df['ID счетчика Яндекс.Метрика'] = Primavera_df['ID счетчика Яндекс.Метрика'].fillna('0')

# %%
print(Primavera_df['ID счетчика Яндекс.Метрика'].count())
print(Primavera_df['ID счетчика Яндекс.Метрика'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['ID счетчика Яндекс.Метрика'][Primavera_df['ID счетчика Яндекс.Метрика'] == ''].count()
# Out:
# 0

# %%
# Приводим тип данных столбца 'ID счетчика Яндекс.Метрика'
Primavera_df = Primavera_df.astype({'ID счетчика Яндекс.Метрика': int})

# %%
# Приводим тип данных столбца 'ID счетчика Яндекс.Метрика'
Primavera_df = Primavera_df.astype({'ID счетчика Яндекс.Метрика': str})

# %%
Primavera_df['ID счетчика Яндекс.Метрика'].tail()
# Out:
# 1518           0
# 1519           0
# 1520           0
# 1521           0
# 1522    86217072
# Name: ID счетчика Яндекс.Метрика, dtype: object

# %% [markdown]
# ##### 49. UTM-метка Referrer

# %%
Primavera_df['UTM-метка Referrer'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: UTM-метка Referrer, dtype: float64

# %%
print(Primavera_df['UTM-метка Referrer'].count())
print(Primavera_df['UTM-метка Referrer'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'UTM-метка Referrer'
Primavera_df['UTM-метка Referrer'] = Primavera_df['UTM-метка Referrer'].fillna('0')

# %%
print(Primavera_df['UTM-метка Referrer'].count())
print(Primavera_df['UTM-метка Referrer'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['UTM-метка Referrer'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: UTM-метка Referrer, dtype: object

# %%
Primavera_df['UTM-метка Referrer'][Primavera_df['UTM-метка Referrer'] == ''].count()
# Out:
# 0

# %%
Primavera_df['UTM-метка Referrer'][Primavera_df['UTM-метка Referrer'] == '0'].count()
# Out:
# 1523

# %%
Primavera_df['UTM-метка Referrer'][Primavera_df['UTM-метка Referrer'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 50. UTM-метка Expid

# %%
Primavera_df['UTM-метка Expid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: UTM-метка Expid, dtype: float64

# %%
print(Primavera_df['UTM-метка Expid'].count())
print(Primavera_df['UTM-метка Expid'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'UTM-метка Expid'
Primavera_df['UTM-метка Expid'] = Primavera_df['UTM-метка Expid'].fillna('0')

# %%
print(Primavera_df['UTM-метка Expid'].count())
print(Primavera_df['UTM-метка Expid'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['UTM-метка Expid'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: UTM-метка Expid, dtype: object

# %%
Primavera_df['UTM-метка Expid'][Primavera_df['UTM-метка Expid'] == ''].count()
# Out:
# 0

# %%
Primavera_df['UTM-метка Expid'][Primavera_df['UTM-метка Expid'] == '0'].count()
# Out:
# 1523

# %%
Primavera_df['UTM-метка Expid'][Primavera_df['UTM-метка Expid'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 51. AdLense-метка ef_id

# %%
Primavera_df['AdLense-метка ef_id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: AdLense-метка ef_id, dtype: float64

# %%
print(Primavera_df['AdLense-метка ef_id'].count())
print(Primavera_df['AdLense-метка ef_id'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'AdLense-метка ef_id'
Primavera_df['AdLense-метка ef_id'] = Primavera_df['AdLense-метка ef_id'].fillna('0')

# %%
print(Primavera_df['AdLense-метка ef_id'].count())
print(Primavera_df['AdLense-метка ef_id'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['AdLense-метка ef_id'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: AdLense-метка ef_id, dtype: object

# %%
Primavera_df['AdLense-метка ef_id'][Primavera_df['AdLense-метка ef_id'] == ''].count()
# Out:
# 0

# %%
Primavera_df['AdLense-метка ef_id'][Primavera_df['AdLense-метка ef_id'] == '0'].count()
# Out:
# 1523

# %%
Primavera_df['AdLense-метка ef_id'][Primavera_df['AdLense-метка ef_id'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 52. Метка yclid

# %%
Primavera_df['Метка yclid'].head()
# Out:
# 0                    NaN
# 1    5836554317678843133
# 2                    NaN
# 3    5834867805149009637
# 4    5834867805149009637
# Name: Метка yclid, dtype: object

# %%
print(Primavera_df['Метка yclid'].count())
print(Primavera_df['Метка yclid'].shape[0])
# Out:
# 529
# 1523

# %%
# Избавляемся от пустот в столбце 'Метка yclid'
Primavera_df['Метка yclid'] = Primavera_df['Метка yclid'].fillna('0')

# %%
print(Primavera_df['Метка yclid'].count())
print(Primavera_df['Метка yclid'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Метка yclid'].tail()
# Out:
# 1518                      0
# 1519                      0
# 1520                      0
# 1521                      0
# 1522    8038880999663206399
# Name: Метка yclid, dtype: object

# %%
Primavera_df['Метка yclid'][Primavera_df['Метка yclid'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 53. Метка ymclid

# %%
Primavera_df['Метка ymclid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Метка ymclid, dtype: float64

# %%
print(Primavera_df['Метка ymclid'].count())
print(Primavera_df['Метка ymclid'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Метка ymclid'
Primavera_df['Метка ymclid'] = Primavera_df['Метка ymclid'].fillna('0')

# %%
print(Primavera_df['Метка ymclid'].count())
print(Primavera_df['Метка ymclid'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Метка ymclid'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: Метка ymclid, dtype: object

# %%
Primavera_df['Метка ymclid'][Primavera_df['Метка ymclid'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Метка ymclid'][Primavera_df['Метка ymclid'] == '0'].count()
# Out:
# 1523

# %%
Primavera_df['Метка ymclid'][Primavera_df['Метка ymclid'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 54. Метка gclid

# %%
Primavera_df['Метка gclid'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Метка gclid, dtype: object

# %%
print(Primavera_df['Метка gclid'].count())
print(Primavera_df['Метка gclid'].shape[0])
# Out:
# 1
# 1523

# %%
# Избавляемся от пустот в столбце 'Метка gclid'
Primavera_df['Метка gclid'] = Primavera_df['Метка gclid'].fillna('0')

# %%
print(Primavera_df['Метка gclid'].count())
print(Primavera_df['Метка gclid'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Метка gclid'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: Метка gclid, dtype: object

# %%
Primavera_df['Метка gclid'][Primavera_df['Метка gclid'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Метка gclid'][Primavera_df['Метка gclid'] == '0'].count()
# Out:
# 1522

# %%
Primavera_df['Метка gclid'][Primavera_df['Метка gclid'] != '0'].count()
# Out:
# 1

# %%
Primavera_df['Метка gclid'][Primavera_df['Метка gclid'] != '0']
# Out:
# 339    EAIaIQobChMIwsberrfKgQMV9uyyCh2KhgidEAAYASAAEgLrWPD_BwE
# Name: Метка gclid, dtype: object

# %% [markdown]
# ##### 55. Метка from

# %%
Primavera_df['Метка from'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Метка from, dtype: float64

# %%
print(Primavera_df['Метка from'].count())
print(Primavera_df['Метка from'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Метка from'
Primavera_df['Метка from'] = Primavera_df['Метка from'].fillna('0')

# %%
print(Primavera_df['Метка from'].count())
print(Primavera_df['Метка from'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Метка from'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: Метка from, dtype: object

# %%
Primavera_df['Метка from'][Primavera_df['Метка from'] == ''].count()
# Out:
# 0

# %%
Primavera_df['Метка from'][Primavera_df['Метка from'] == '0'].count()
# Out:
# 1523

# %%
Primavera_df['Метка from'][Primavera_df['Метка from'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 56. Длительность разговора

# %%
Primavera_df['Длительность разговора'].head()
# Out:
# 0    00:05:20
# 1    00:00:13
# 2    00:01:53
# 3    00:00:00
# 4    00:00:00
# Name: Длительность разговора, dtype: object

# %%
print(Primavera_df['Длительность разговора'].count())
print(Primavera_df['Длительность разговора'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Длительность разговора'
Primavera_df['Длительность разговора'] = pd.to_datetime(Primavera_df['Длительность разговора']).dt.time

# %%
Primavera_df['Длительность разговора'].tail()
# Out:
# 1518    00:00:14
# 1519    00:01:34
# 1520    00:05:15
# 1521    00:07:03
# 1522    00:00:18
# Name: Длительность разговора, dtype: object

# %% [markdown]
# ##### 57. Длительность постобработки

# %%
Primavera_df['Длительность постобработки'].head()
# Out:
# 0    00:00:00
# 1    00:00:00
# 2    00:00:00
# 3    00:00:00
# 4    00:00:00
# Name: Длительность постобработки, dtype: object

# %%
print(Primavera_df['Длительность постобработки'].count())
print(Primavera_df['Длительность постобработки'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Длительность постобработки'
Primavera_df['Длительность постобработки'] = pd.to_datetime(Primavera_df['Длительность постобработки']).dt.time

# %%
Primavera_df['Длительность постобработки'].tail()
# Out:
# 1518    00:00:00
# 1519    00:00:00
# 1520    00:00:00
# 1521    00:00:00
# 1522    00:00:00
# Name: Длительность постобработки, dtype: object

# %% [markdown]
# ##### 58. Чистая длительность разговора

# %%
Primavera_df['Чистая длительность разговора'].head()
# Out:
# 0    00:05:20
# 1    00:00:12
# 2    00:01:53
# 3    00:00:00
# 4    00:00:00
# Name: Чистая длительность разговора, dtype: object

# %%
print(Primavera_df['Чистая длительность разговора'].count())
print(Primavera_df['Чистая длительность разговора'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Чистая длительность разговора'
Primavera_df['Чистая длительность разговора'] = pd.to_datetime(Primavera_df['Чистая длительность разговора']).dt.time

# %%
Primavera_df['Чистая длительность разговора'].tail()
# Out:
# 1518    00:00:14
# 1519    00:01:34
# 1520    00:05:15
# 1521    00:07:03
# 1522    00:00:17
# Name: Чистая длительность разговора, dtype: object

# %% [markdown]
# ##### 59. Полная длительность ожидания

# %%
Primavera_df['Полная длительность ожидания'].head()
# Out:
# 0    00:00:04
# 1    00:00:22
# 2    00:00:04
# 3    00:00:03
# 4    00:00:03
# Name: Полная длительность ожидания, dtype: object

# %%
print(Primavera_df['Полная длительность ожидания'].count())
print(Primavera_df['Полная длительность ожидания'].shape[0])
# Out:
# 1523
# 1523

# %%
# Приводим тип данных столбца 'Полная длительность ожидания'
Primavera_df['Полная длительность ожидания'] = pd.to_datetime(Primavera_df['Полная длительность ожидания']).dt.time

# %%
Primavera_df['Полная длительность ожидания'].tail()
# Out:
# 1518    00:00:08
# 1519    00:00:28
# 1520    00:00:04
# 1521    00:00:04
# 1522    00:00:29
# Name: Полная длительность ожидания, dtype: object

# %% [markdown]
# ##### 60. Расширенная UTM-метка Source

# %%
Primavera_df['Расширенная UTM-метка Source'].head()
# Out:
# 0        NaN
# 1     yandex
# 2        NaN
# 3    yastreb
# 4    yastreb
# Name: Расширенная UTM-метка Source, dtype: object

# %%
print(Primavera_df['Расширенная UTM-метка Source'].count())
print(Primavera_df['Расширенная UTM-метка Source'].shape[0])
# Out:
# 742
# 1523

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Source'
Primavera_df['Расширенная UTM-метка Source'] = Primavera_df['Расширенная UTM-метка Source'].fillna('нет')

# %%
print(Primavera_df['Расширенная UTM-метка Source'].count())
print(Primavera_df['Расширенная UTM-метка Source'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Расширенная UTM-метка Source'].tail()
# Out:
# 1518       нет
# 1519       нет
# 1520       нет
# 1521       нет
# 1522    yandex
# Name: Расширенная UTM-метка Source, dtype: object

# %%
Primavera_df['Расширенная UTM-метка Source'][Primavera_df['Расширенная UTM-метка Source'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 61. Расширенная UTM-метка Campaign

# %%
Primavera_df['Расширенная UTM-метка Campaign'].head()
# Out:
# 0                                              NaN
# 1    m108|competitors_new_rsy_mmo|92541971|context
# 2                                              NaN
# 3                                             m108
# 4                                             m108
# Name: Расширенная UTM-метка Campaign, dtype: object

# %%
print(Primavera_df['Расширенная UTM-метка Campaign'].count())
print(Primavera_df['Расширенная UTM-метка Campaign'].shape[0])
# Out:
# 644
# 1523

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Campaign'
Primavera_df['Расширенная UTM-метка Campaign'] = Primavera_df['Расширенная UTM-метка Campaign'].fillna('нет')

# %%
print(Primavera_df['Расширенная UTM-метка Campaign'].count())
print(Primavera_df['Расширенная UTM-метка Campaign'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Расширенная UTM-метка Campaign'].tail()
# Out:
# 1518                                             нет
# 1519                                             нет
# 1520                                             нет
# 1521                                             нет
# 1522    m108|brand_vygoda_search_mmo|87274657|search
# Name: Расширенная UTM-метка Campaign, dtype: object

# %%
Primavera_df['Расширенная UTM-метка Campaign'][Primavera_df['Расширенная UTM-метка Campaign'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 62. Расширенная UTM-метка Medium

# %%
Primavera_df['Расширенная UTM-метка Medium'].head()
# Out:
# 0    NaN
# 1    cpc
# 2    NaN
# 3    cpc
# 4    cpc
# Name: Расширенная UTM-метка Medium, dtype: object

# %%
print(Primavera_df['Расширенная UTM-метка Medium'].count())
print(Primavera_df['Расширенная UTM-метка Medium'].shape[0])
# Out:
# 683
# 1523

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Medium'
Primavera_df['Расширенная UTM-метка Medium'] = Primavera_df['Расширенная UTM-метка Medium'].fillna('нет')

# %%
print(Primavera_df['Расширенная UTM-метка Medium'].count())
print(Primavera_df['Расширенная UTM-метка Medium'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Расширенная UTM-метка Medium'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    cpc
# Name: Расширенная UTM-метка Medium, dtype: object

# %%
Primavera_df['Расширенная UTM-метка Medium'][Primavera_df['Расширенная UTM-метка Medium'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 63. Расширенная UTM-метка Content

# %%
Primavera_df['Расширенная UTM-метка Content'].head()
# Out:
# 0                                                                                                               NaN
# 1    5255717580|14773407867|46335276624|hoz-house.ru|desktop|14773407867|type1|46335276624|46335276624|0|none|98611
# 2                                                                                                               NaN
# 3                                                                                                               NaN
# 4                                                                                                               NaN
# Name: Расширенная UTM-метка Content, dtype: object

# %%
print(Primavera_df['Расширенная UTM-метка Content'].count())
print(Primavera_df['Расширенная UTM-метка Content'].shape[0])
# Out:
# 544
# 1523

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Content'
Primavera_df['Расширенная UTM-метка Content'] = Primavera_df['Расширенная UTM-метка Content'].fillna('нет')

# %%
print(Primavera_df['Расширенная UTM-метка Content'].count())
print(Primavera_df['Расширенная UTM-метка Content'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Расширенная UTM-метка Content'].tail()
# Out:
# 1518                                                                                                       нет
# 1519                                                                                                       нет
# 1520                                                                                                       нет
# 1521                                                                                                       нет
# 1522    5188467605|14079055811|44610510913|none|mobile|14079055811|type1|44610510913|44610510913|1|premium|213
# Name: Расширенная UTM-метка Content, dtype: object

# %%
Primavera_df['Расширенная UTM-метка Content'][Primavera_df['Расширенная UTM-метка Content'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 64. Расширенная UTM-метка Term

# %%
Primavera_df['Расширенная UTM-метка Term'].head()
# Out:
# 0                            NaN
# 1    river park кутузовский цена
# 2                            NaN
# 3             yan:video:m100022m
# 4             yan:video:m100022m
# Name: Расширенная UTM-метка Term, dtype: object

# %%
print(Primavera_df['Расширенная UTM-метка Term'].count())
print(Primavera_df['Расширенная UTM-метка Term'].shape[0])
# Out:
# 249
# 1523

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Term'
Primavera_df['Расширенная UTM-метка Term'] = Primavera_df['Расширенная UTM-метка Term'].fillna('нет')

# %%
print(Primavera_df['Расширенная UTM-метка Term'].count())
print(Primavera_df['Расширенная UTM-метка Term'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Расширенная UTM-метка Term'].tail()
# Out:
# 1518                        нет
# 1519                        нет
# 1520                        нет
# 1521                        нет
# 1522    клубный город примавера
# Name: Расширенная UTM-метка Term, dtype: object

# %%
Primavera_df['Расширенная UTM-метка Term'][Primavera_df['Расширенная UTM-метка Term'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 65. Расширенная UTM-метка Referrer

# %%
Primavera_df['Расширенная UTM-метка Referrer'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Расширенная UTM-метка Referrer, dtype: float64

# %%
print(Primavera_df['Расширенная UTM-метка Referrer'].count())
print(Primavera_df['Расширенная UTM-метка Referrer'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Referrer'
Primavera_df['Расширенная UTM-метка Referrer'] = Primavera_df['Расширенная UTM-метка Referrer'].fillna('нет')

# %%
print(Primavera_df['Расширенная UTM-метка Referrer'].count())
print(Primavera_df['Расширенная UTM-метка Referrer'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Расширенная UTM-метка Referrer'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    нет
# Name: Расширенная UTM-метка Referrer, dtype: object

# %%
Primavera_df['Расширенная UTM-метка Referrer'][Primavera_df['Расширенная UTM-метка Referrer'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 66. Расширенная UTM-метка Expid

# %%
Primavera_df['Расширенная UTM-метка Expid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Расширенная UTM-метка Expid, dtype: float64

# %%
print(Primavera_df['Расширенная UTM-метка Expid'].count())
print(Primavera_df['Расширенная UTM-метка Expid'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Expid'
Primavera_df['Расширенная UTM-метка Expid'] = Primavera_df['Расширенная UTM-метка Expid'].fillna('нет')

# %%
print(Primavera_df['Расширенная UTM-метка Expid'].count())
print(Primavera_df['Расширенная UTM-метка Expid'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['Расширенная UTM-метка Expid'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    нет
# Name: Расширенная UTM-метка Expid, dtype: object

# %%
Primavera_df['Расширенная UTM-метка Expid'][Primavera_df['Расширенная UTM-метка Expid'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 67. OS-метка service-name

# %%
Primavera_df['OS-метка service-name'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка service-name, dtype: float64

# %%
print(Primavera_df['OS-метка service-name'].count())
print(Primavera_df['OS-метка service-name'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'OS-метка service-name'
Primavera_df['OS-метка service-name'] = Primavera_df['OS-метка service-name'].fillna('нет')

# %%
print(Primavera_df['OS-метка service-name'].count())
print(Primavera_df['OS-метка service-name'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['OS-метка service-name'].tail()
# Out:
# 1518    нет
# 1519    нет
# 1520    нет
# 1521    нет
# 1522    нет
# Name: OS-метка service-name, dtype: object

# %%
Primavera_df['OS-метка service-name'][Primavera_df['OS-метка service-name'] == ''].count()
# Out:
# 0

# %%
Primavera_df['OS-метка service-name'][Primavera_df['OS-метка service-name'] == 'нет'].count()
# Out:
# 1523

# %%
Primavera_df['OS-метка service-name'][Primavera_df['OS-метка service-name'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 68. OS-метка campaign-id

# %%
Primavera_df['OS-метка campaign-id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка campaign-id, dtype: float64

# %%
print(Primavera_df['OS-метка campaign-id'].count())
print(Primavera_df['OS-метка campaign-id'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'OS-метка campaign-id'
Primavera_df['OS-метка campaign-id'] = Primavera_df['OS-метка campaign-id'].fillna('0')

# %%
print(Primavera_df['OS-метка campaign-id'].count())
print(Primavera_df['OS-метка campaign-id'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['OS-метка campaign-id'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: OS-метка campaign-id, dtype: object

# %%
Primavera_df['OS-метка campaign-id'][Primavera_df['OS-метка campaign-id'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 69. OS-метка ad-id

# %%
Primavera_df['OS-метка ad-id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка ad-id, dtype: float64

# %%
print(Primavera_df['OS-метка ad-id'].count())
print(Primavera_df['OS-метка ad-id'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'OS-метка ad-id'
Primavera_df['OS-метка ad-id'] = Primavera_df['OS-метка ad-id'].fillna('0')

# %%
print(Primavera_df['OS-метка ad-id'].count())
print(Primavera_df['OS-метка ad-id'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['OS-метка ad-id'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: OS-метка ad-id, dtype: object

# %%
Primavera_df['OS-метка ad-id'][Primavera_df['OS-метка ad-id'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 70. OS-метка source-id

# %%
Primavera_df['OS-метка source-id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка source-id, dtype: float64

# %%
print(Primavera_df['OS-метка source-id'].count())
print(Primavera_df['OS-метка source-id'].shape[0])
# Out:
# 0
# 1523

# %%
# Избавляемся от пустот в столбце 'OS-метка source-id'
Primavera_df['OS-метка source-id'] = Primavera_df['OS-метка source-id'].fillna('0')

# %%
print(Primavera_df['OS-метка source-id'].count())
print(Primavera_df['OS-метка source-id'].shape[0])
# Out:
# 1523
# 1523

# %%
Primavera_df['OS-метка source-id'].tail()
# Out:
# 1518    0
# 1519    0
# 1520    0
# 1521    0
# 1522    0
# Name: OS-метка source-id, dtype: object

# %%
Primavera_df['OS-метка source-id'][Primavera_df['OS-метка source-id'] == ''].count()
# Out:
# 0

# %%
Primavera_df['OS-метка source-id'][Primavera_df['OS-метка source-id'] == '0'].count()
# Out:
# 1523

# %%
Primavera_df['OS-метка source-id'][Primavera_df['OS-метка source-id'] != '0'].count()
# Out:
# 0

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Primavera_df.dtypes
# Out:
# Статус                                             object
# Тип                                                object
# Дата и время                               datetime64[ns]
# Номер абонента                                      int64
# Рекламная кампания                                 object
# Длительность звонка                                object
# Номер обращения                                     int64
# Теги                                               object
# Сотрудник                                          object
# Первая рекламная кампания                          object
# UTM-метка Campaign                                 object
# UTM-метка Term                                     object
# UTM-метка Source                                   object
# UTM-метка Medium                                   object
# UTM-метка Content                                  object
# Client ID Яндекс.Метрика                           object
# ID посетителя                                       int64
# Страна номера абонента                             object
# Регион номера абонента                             object
# Идентификатор звонка во внешней системе             int64
# Тип устройства                                     object
# URL страницы обращения                             object
# Город                                              object
# Страна                                             object
# Сайт                                               object
# Оценка сотрудника                                  object
# Номер сотрудника                                    int64
# Трансфер                                           object
# Внутренний звонок                                  object
# ФИО контакта                                       object
# Имя тренера                                        object
# Сценарий                                           object
# Операции                                           object
# Идентификатор сессии звонка                         int64
# Группа, выбранная посетителем                      object
# Длительность обработки                              int64
# Комментарий                                        object
# Контакт из CRM                                     object
# Поисковая система                                  object
# Поисковый запрос                                   object
# Реферер                                            object
# Домен реферера                                     object
# Область                                            object
# Посадочная страница                                object
# Количество посещений                                int64
# Тип посетителя                                     object
# Client ID Google Analytics                         object
# ID ресурса Google Analytics                        object
# ID счетчика Яндекс.Метрика                         object
# UTM-метка Referrer                                 object
# UTM-метка Expid                                    object
# AdLense-метка ef_id                                object
# Метка yclid                                        object
# Метка ymclid                                       object
# Метка gclid                                        object
# Метка from                                         object
# Длительность разговора                             object
# Длительность постобработки                         object
# Чистая длительность разговора                      object
# Полная длительность ожидания                       object
# Расширенная UTM-метка Source                       object
# Расширенная UTM-метка Campaign                     object
# Расширенная UTM-метка Medium                       object
# Расширенная UTM-метка Content                      object
# Расширенная UTM-метка Term                         object
# Расширенная UTM-метка Referrer                     object
# Расширенная UTM-метка Expid                        object
# OS-метка service-name                              object
# OS-метка campaign-id                               object
# OS-метка ad-id                                     object
# OS-метка source-id                                 object
# dtype: object

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Primavera_df в файл
with open(df_path + 'Primavera_new_df.pkl', 'wb') as f:
  pkl.dump(Primavera_df, f)

# %% [markdown]
# ### Paveletskaya_city

# %% [markdown]
# #### Создание датафрейма

# %%
# Читаем файл 'Павелецкая сити.xlsx' в датафрейм
Paveletskaya_city_df = pd.read_excel(new_dataset_info_path + 'Павелецкая сити.xlsx',
                                     skiprows=4)
Paveletskaya_city_df.shape
# Out:
# (1518, 74)

# %%
Paveletskaya_city_df.head()
# Out:
#        Статус                       Тип         Дата и время  Номер абонента  \
# 0    Принятый                 Аналитика  2023-10-04 22:46:01    7.968536e+10
# 1    Принятый  Динамический коллтрекинг  2023-10-04 20:02:36    7.906796e+10
# 2    Принятый                 Аналитика  2023-10-04 19:49:06    7.916059e+10
# 3  Потерянный   Автоперезвон по заявкам  2023-10-04 19:39:00    7.916059e+10
# 4  Потерянный   Автоперезвон по заявкам  2023-10-04 19:01:47    7.915439e+10
#
#                                 Теги  \
# 0                  Нецелевой контакт
# 1                  Нецелевой контакт
# 2                                NaN
# 3     Обработано - Нецелевой контакт
# 4  Не обработано - Нецелевой контакт
#
#                                           Рекламная кампания  \
# 0  Media108 | Павелецкая Сити | catalog | Google my business
# 1        Media108 | Павелецкая Сити | direct | Яндекс.Директ
# 2             MRGroup | Павелецкая Сити | seo | Google Поиск
# 3             MRGroup | Павелецкая Сити | seo | Google Поиск
# 4        Media108 | Павелецкая Сити | direct | Яндекс.Директ
#
#   Длительность звонка  Client ID Яндекс.Метрика Длительность ожидания ответа  \
# 0            00:00:06                       NaN                     00:00:00
# 1            00:00:03              1.694681e+18                     00:00:00
# 2            00:20:46              1.696437e+18                     00:00:00
# 3            00:00:33              1.696437e+18                     00:00:33
# 4            00:00:48              1.690479e+18                     00:00:48
#
#                  Сотрудник  ...  Чистая длительность разговора  \
# 0                    TRUNK  ...                       00:00:05
# 1                    TRUNK  ...                       00:00:02
# 2                    TRUNK  ...                       00:20:46
# 3  Обратный звонок (SIP<1)  ...                       00:00:00
# 4  Обратный звонок (SIP<1)  ...                       00:00:00
#
#    Полная длительность ожидания Идентификатор звонка во внешней системе  \
# 0                      00:00:01                                     NaN
# 1                      00:00:01                                     NaN
# 2                      00:00:00                                     NaN
# 3                      00:00:33                                     NaN
# 4                      00:00:48                                     NaN
#
#   Расширенная UTM-метка Source  \
# 0                          NaN
# 1                       yandex
# 2                          NaN
# 3                          NaN
# 4                       yandex
#
#                          Расширенная UTM-метка Campaign  \
# 0                                                   NaN
# 1             m108_pavcity_brand_net_mmo_exp_A|96311163
# 2                                                   NaN
# 3                                                   NaN
# 4  m108_pavcity_retarget_neotkaz_net_mmo_exp_A|96311169
#
#   Расширенная UTM-метка Medium  \
# 0                          NaN
# 1                          cpc
# 2                          NaN
# 3                          NaN
# 4                          cpc
#
#                                                                                                          Расширенная UTM-метка Content  \
# 0                                                                                                                                  NaN
# 1  id|47205529851_47205529851|cid|96311163|gid|5288452139|aid|15032859723|adp|no|pos|none0|src|context_dsp.yandex.ru|dvc|tablet|coef|0
# 2                                                                                                                                  NaN
# 3                                                                                                                                  NaN
# 4              id|55165192_55165192|cid|96311169|gid|5288452157|aid|15032860276|adp|no|pos|none0|src|context_dzen.ru|dvc|tablet|coef|0
#
#              Расширенная UTM-метка Term Расширенная UTM-метка Referrer  \
# 0                                   NaN                            NaN
# 1  купить квартиру павелецкая сити циан                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#    Расширенная UTM-метка Expid
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 74 columns]

# %% [markdown]
# #### Предобработка

# %% [markdown]
# ##### 0. Статус

# %%
Paveletskaya_city_df['Статус'].head()
# Out:
# 0      Принятый
# 1      Принятый
# 2      Принятый
# 3    Потерянный
# 4    Потерянный
# Name: Статус, dtype: object

# %%
print(Paveletskaya_city_df['Статус'].count())
print(Paveletskaya_city_df['Статус'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Статус'].tail()
# Out:
# 1513    Потерянный
# 1514      Принятый
# 1515      Принятый
# 1516      Принятый
# 1517    Потерянный
# Name: Статус, dtype: object

# %%
Paveletskaya_city_df['Статус'][Paveletskaya_city_df['Статус'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 1. Тип

# %%
Paveletskaya_city_df['Тип'].head()
# Out:
# 0                   Аналитика
# 1    Динамический коллтрекинг
# 2                   Аналитика
# 3     Автоперезвон по заявкам
# 4     Автоперезвон по заявкам
# Name: Тип, dtype: object

# %%
print(Paveletskaya_city_df['Тип'].count())
print(Paveletskaya_city_df['Тип'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Тип'].tail()
# Out:
# 1513            Звонки из VK Ads
# 1514    Динамический коллтрекинг
# 1515                   Аналитика
# 1516            Звонки из VK Ads
# 1517            Звонки из VK Ads
# Name: Тип, dtype: object

# %%
Paveletskaya_city_df['Тип'][Paveletskaya_city_df['Тип'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 2. Дата и время

# %%
Paveletskaya_city_df['Дата и время'].head()
# Out:
# 0    2023-10-04 22:46:01
# 1    2023-10-04 20:02:36
# 2    2023-10-04 19:49:06
# 3    2023-10-04 19:39:00
# 4    2023-10-04 19:01:47
# Name: Дата и время, dtype: object

# %%
print(Paveletskaya_city_df['Дата и время'].count())
print(Paveletskaya_city_df['Дата и время'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Дата и время'
Paveletskaya_city_df['Дата и время'] = pd.to_datetime(Paveletskaya_city_df['Дата и время'])

# %%
Paveletskaya_city_df['Дата и время'].tail()
# Out:
# 1513   2023-08-15 09:08:26
# 1514   2023-08-15 09:01:30
# 1515   2023-08-15 09:01:23
# 1516   2023-08-15 09:01:02
# 1517   2023-08-15 09:00:04
# Name: Дата и время, dtype: datetime64[ns]

# %% [markdown]
# ##### 3. Номер абонента

# %%
Paveletskaya_city_df['Номер абонента'].head()
# Out:
# 0    7.968536e+10
# 1    7.906796e+10
# 2    7.916059e+10
# 3    7.916059e+10
# 4    7.915439e+10
# Name: Номер абонента, dtype: float64

# %%
print(Paveletskaya_city_df['Номер абонента'].count())
print(Paveletskaya_city_df['Номер абонента'].shape[0])
# Out:
# 1517
# 1518

# %%
# Избавляемся от пустот в столбце 'Номер абонента'
Paveletskaya_city_df['Номер абонента'] = Paveletskaya_city_df['Номер абонента'].fillna('0')

# %%
print(Paveletskaya_city_df['Номер абонента'].count())
print(Paveletskaya_city_df['Номер абонента'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Номер абонента'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'Номер абонента': int})

# %%
Paveletskaya_city_df['Номер абонента'].tail()
# Out:
# 1513    79534354524
# 1514    79032902243
# 1515    79254065740
# 1516    79096297995
# 1517    79254065740
# Name: Номер абонента, dtype: int64

# %% [markdown]
# ##### 4. Теги

# %%
Paveletskaya_city_df['Теги'].head()
# Out:
# 0                    Нецелевой контакт
# 1                    Нецелевой контакт
# 2                                  NaN
# 3       Обработано - Нецелевой контакт
# 4    Не обработано - Нецелевой контакт
# Name: Теги, dtype: object

# %%
print(Paveletskaya_city_df['Теги'].count())
print(Paveletskaya_city_df['Теги'].shape[0])
# Out:
# 962
# 1518

# %%
# Избавляемся от пустот в столбце 'Теги'
Paveletskaya_city_df['Теги'] = Paveletskaya_city_df['Теги'].fillna('нет')

# %%
print(Paveletskaya_city_df['Теги'].count())
print(Paveletskaya_city_df['Теги'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Теги'].tail()
# Out:
# 1513    Не обработано - Нецелевой контакт
# 1514                    Нецелевой контакт
# 1515                    Нецелевой контакт
# 1516                                  нет
# 1517       Обработано - Нецелевой контакт
# Name: Теги, dtype: object

# %%
Paveletskaya_city_df['Теги'][Paveletskaya_city_df['Теги'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 5. Рекламная кампания

# %%
Paveletskaya_city_df['Рекламная кампания'].head()
# Out:
# 0    Media108 | Павелецкая Сити | catalog | Google my business
# 1          Media108 | Павелецкая Сити | direct | Яндекс.Директ
# 2               MRGroup | Павелецкая Сити | seo | Google Поиск
# 3               MRGroup | Павелецкая Сити | seo | Google Поиск
# 4          Media108 | Павелецкая Сити | direct | Яндекс.Директ
# Name: Рекламная кампания, dtype: object

# %%
print(Paveletskaya_city_df['Рекламная кампания'].count())
print(Paveletskaya_city_df['Рекламная кампания'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Рекламная кампания'].tail()
# Out:
# 1513           Media108 | Павелецкая Сити | social | VK Ads
# 1514    Media108 | Павелецкая Сити | direct | Яндекс.Директ
# 1515           Media108 | Павелецкая Сити | social | VK Ads
# 1516           Media108 | Павелецкая Сити | social | VK Ads
# 1517           Media108 | Павелецкая Сити | social | VK Ads
# Name: Рекламная кампания, dtype: object

# %%
Paveletskaya_city_df['Рекламная кампания'][Paveletskaya_city_df['Рекламная кампания'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 6. Длительность звонка

# %%
Paveletskaya_city_df['Длительность звонка'].head()
# Out:
# 0    00:00:06
# 1    00:00:03
# 2    00:20:46
# 3    00:00:33
# 4    00:00:48
# Name: Длительность звонка, dtype: object

# %%
print(Paveletskaya_city_df['Длительность звонка'].count())
print(Paveletskaya_city_df['Длительность звонка'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Длительность звонка'
Paveletskaya_city_df['Длительность звонка'] = pd.to_datetime(Paveletskaya_city_df['Длительность звонка']).dt.time

# %%
Paveletskaya_city_df['Длительность звонка'].tail()
# Out:
# 1513    00:00:55
# 1514    00:00:03
# 1515    00:00:07
# 1516    00:00:38
# 1517    00:00:57
# Name: Длительность звонка, dtype: object

# %% [markdown]
# ##### 7. Client ID Яндекс.Метрика

# %%
Paveletskaya_city_df['Client ID Яндекс.Метрика'].head()
# Out:
# 0             NaN
# 1    1.694681e+18
# 2    1.696437e+18
# 3    1.696437e+18
# 4    1.690479e+18
# Name: Client ID Яндекс.Метрика, dtype: float64

# %%
print(Paveletskaya_city_df['Client ID Яндекс.Метрика'].count())
print(Paveletskaya_city_df['Client ID Яндекс.Метрика'].shape[0])
# Out:
# 370
# 1518

# %%
# Избавляемся от пустот в столбце 'Client ID Яндекс.Метрика'
Paveletskaya_city_df['Client ID Яндекс.Метрика'] = Paveletskaya_city_df['Client ID Яндекс.Метрика'].fillna('0')

# %%
print(Paveletskaya_city_df['Client ID Яндекс.Метрика'].count())
print(Paveletskaya_city_df['Client ID Яндекс.Метрика'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Client ID Яндекс.Метрика'].tail()
# Out:
# 1513                        0
# 1514    1692029957998920704.0
# 1515                        0
# 1516                        0
# 1517                        0
# Name: Client ID Яндекс.Метрика, dtype: object

# %%
Paveletskaya_city_df['Client ID Яндекс.Метрика'][Paveletskaya_city_df['Client ID Яндекс.Метрика'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 8. Длительность ожидания ответа

# %%
Paveletskaya_city_df['Длительность ожидания ответа'].head()
# Out:
# 0    00:00:00
# 1    00:00:00
# 2    00:00:00
# 3    00:00:33
# 4    00:00:48
# Name: Длительность ожидания ответа, dtype: object

# %%
print(Paveletskaya_city_df['Длительность ожидания ответа'].count())
print(Paveletskaya_city_df['Длительность ожидания ответа'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Длительность ожидания ответа'
Paveletskaya_city_df['Длительность ожидания ответа'] = pd.to_datetime(Paveletskaya_city_df['Длительность ожидания ответа']).dt.time

# %%
Paveletskaya_city_df['Длительность ожидания ответа'].tail()
# Out:
# 1513    00:00:55
# 1514    00:00:00
# 1515    00:00:00
# 1516    00:00:32
# 1517    00:00:57
# Name: Длительность ожидания ответа, dtype: object

# %% [markdown]
# ##### 9. Сотрудник

# %%
Paveletskaya_city_df['Сотрудник'].head()
# Out:
# 0                      TRUNK
# 1                      TRUNK
# 2                      TRUNK
# 3    Обратный звонок (SIP<1)
# 4    Обратный звонок (SIP<1)
# Name: Сотрудник, dtype: object

# %%
print(Paveletskaya_city_df['Сотрудник'].count())
print(Paveletskaya_city_df['Сотрудник'].shape[0])
# Out:
# 1493
# 1518

# %%
# Избавляемся от пустот в столбце 'Сотрудник'
Paveletskaya_city_df['Сотрудник'] = Paveletskaya_city_df['Сотрудник'].fillna('нет сотрудника')

# %%
print(Paveletskaya_city_df['Сотрудник'].count())
print(Paveletskaya_city_df['Сотрудник'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Сотрудник'].tail()
# Out:
# 1513    Обратный звонок (SIP<1)
# 1514                      TRUNK
# 1515                      TRUNK
# 1516    Обратный звонок (SIP<1)
# 1517    Обратный звонок (SIP<1)
# Name: Сотрудник, dtype: object

# %%
Paveletskaya_city_df['Сотрудник'][Paveletskaya_city_df['Сотрудник'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 10. Номер обращения

# %%
Paveletskaya_city_df['Номер обращения'].head()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.0
# 4    4.0
# Name: Номер обращения, dtype: float64

# %%
print(Paveletskaya_city_df['Номер обращения'].count())
print(Paveletskaya_city_df['Номер обращения'].shape[0])
# Out:
# 1517
# 1518

# %%
# Избавляемся от пустот в столбце 'Номер обращения'
Paveletskaya_city_df['Номер обращения'] = Paveletskaya_city_df['Номер обращения'].fillna('0')

# %%
print(Paveletskaya_city_df['Номер обращения'].count())
print(Paveletskaya_city_df['Номер обращения'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Номер обращения'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'Номер обращения': int})

# %%
Paveletskaya_city_df['Номер обращения'].tail()
# Out:
# 1513    2
# 1514    2
# 1515    3
# 1516    2
# 1517    2
# Name: Номер обращения, dtype: int64

# %% [markdown]
# ##### 11. ID посетителя

# %%
Paveletskaya_city_df['ID посетителя'].head()
# Out:
# 0             NaN
# 1    7.645608e+09
# 2    7.717510e+09
# 3    7.717510e+09
# 4    7.494854e+09
# Name: ID посетителя, dtype: float64

# %%
print(Paveletskaya_city_df['ID посетителя'].count())
print(Paveletskaya_city_df['ID посетителя'].shape[0])
# Out:
# 611
# 1518

# %%
# Избавляемся от пустот в столбце 'ID посетителя'
Paveletskaya_city_df['ID посетителя'] = Paveletskaya_city_df['ID посетителя'].fillna('0')

# %%
print(Paveletskaya_city_df['ID посетителя'].count())
print(Paveletskaya_city_df['ID посетителя'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'ID посетителя'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'ID посетителя': int})

# %%
Paveletskaya_city_df['ID посетителя'].tail()
# Out:
# 1513    7551605279
# 1514    7550224114
# 1515    7550537684
# 1516    7550877564
# 1517    7550537684
# Name: ID посетителя, dtype: int64

# %% [markdown]
# ##### 12. UTM-метка Campaign

# %%
Paveletskaya_city_df['UTM-метка Campaign'].head()
# Out:
# 0                                                     NaN
# 1               m108_pavcity_brand_net_mmo_exp_A|96311163
# 2                                                     NaN
# 3                                                     NaN
# 4    m108_pavcity_retarget_neotkaz_net_mmo_exp_A|96311169
# Name: UTM-метка Campaign, dtype: object

# %%
print(Paveletskaya_city_df['UTM-метка Campaign'].count())
print(Paveletskaya_city_df['UTM-метка Campaign'].shape[0])
# Out:
# 339
# 1518

# %%
# Избавляемся от пустот в столбце 'UTM-метка Campaign'
Paveletskaya_city_df['UTM-метка Campaign'] = Paveletskaya_city_df['UTM-метка Campaign'].fillna('нет')

# %%
print(Paveletskaya_city_df['UTM-метка Campaign'].count())
print(Paveletskaya_city_df['UTM-метка Campaign'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['UTM-метка Campaign'].tail()
# Out:
# 1513                нет
# 1514    master|90303913
# 1515                нет
# 1516                нет
# 1517                нет
# Name: UTM-метка Campaign, dtype: object

# %%
Paveletskaya_city_df['UTM-метка Campaign'][Paveletskaya_city_df['UTM-метка Campaign'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 13. Город

# %%
Paveletskaya_city_df['Город'].head()
# Out:
# 0          NaN
# 1    Пятигорск
# 2       Москва
# 3       Москва
# 4       Москва
# Name: Город, dtype: object

# %%
print(Paveletskaya_city_df['Город'].count())
print(Paveletskaya_city_df['Город'].shape[0])
# Out:
# 359
# 1518

# %%
# Избавляемся от пустот в столбце 'Город'
Paveletskaya_city_df['Город'] = Paveletskaya_city_df['Город'].fillna('нет')

# %%
print(Paveletskaya_city_df['Город'].count())
print(Paveletskaya_city_df['Город'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Город'].tail()
# Out:
# 1513       нет
# 1514    Москва
# 1515       нет
# 1516       нет
# 1517       нет
# Name: Город, dtype: object

# %%
Paveletskaya_city_df['Город'][Paveletskaya_city_df['Город'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 14. Страна

# %%
Paveletskaya_city_df['Страна'].head()
# Out:
# 0       NaN
# 1    Россия
# 2    Россия
# 3    Россия
# 4    Россия
# Name: Страна, dtype: object

# %%
print(Paveletskaya_city_df['Страна'].count())
print(Paveletskaya_city_df['Страна'].shape[0])
# Out:
# 382
# 1518

# %%
# Избавляемся от пустот в столбце 'Страна'
Paveletskaya_city_df['Страна'] = Paveletskaya_city_df['Страна'].fillna('нет')

# %%
print(Paveletskaya_city_df['Страна'].count())
print(Paveletskaya_city_df['Страна'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Страна'].tail()
# Out:
# 1513       нет
# 1514    Россия
# 1515       нет
# 1516       нет
# 1517       нет
# Name: Страна, dtype: object

# %%
Paveletskaya_city_df['Страна'][Paveletskaya_city_df['Страна'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 15. Страна номера абонента

# %%
Paveletskaya_city_df['Страна номера абонента'].head()
# Out:
# 0    РФ
# 1    РФ
# 2    РФ
# 3    РФ
# 4    РФ
# Name: Страна номера абонента, dtype: object

# %%
print(Paveletskaya_city_df['Страна номера абонента'].count())
print(Paveletskaya_city_df['Страна номера абонента'].shape[0])
# Out:
# 1517
# 1518

# %%
# Избавляемся от пустот в столбце 'Страна номера абонента'
Paveletskaya_city_df['Страна номера абонента'] = Paveletskaya_city_df['Страна номера абонента'].fillna('не определено')

# %%
print(Paveletskaya_city_df['Страна номера абонента'].count())
print(Paveletskaya_city_df['Страна номера абонента'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Страна номера абонента'].tail()
# Out:
# 1513    РФ
# 1514    РФ
# 1515    РФ
# 1516    РФ
# 1517    РФ
# Name: Страна номера абонента, dtype: object

# %%
Paveletskaya_city_df['Страна номера абонента'][Paveletskaya_city_df['Страна номера абонента'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 16. UTM-метка Content

# %%
Paveletskaya_city_df['UTM-метка Content'].head()
# Out:
# 0                                                                                                                                    NaN
# 1    id|47205529851_47205529851|cid|96311163|gid|5288452139|aid|15032859723|adp|no|pos|none0|src|context_dsp.yandex.ru|dvc|tablet|coef|0
# 2                                                                                                                                    NaN
# 3                                                                                                                                    NaN
# 4                id|55165192_55165192|cid|96311169|gid|5288452157|aid|15032860276|adp|no|pos|none0|src|context_dzen.ru|dvc|tablet|coef|0
# Name: UTM-метка Content, dtype: object

# %%
print(Paveletskaya_city_df['UTM-метка Content'].count())
print(Paveletskaya_city_df['UTM-метка Content'].shape[0])
# Out:
# 319
# 1518

# %%
# Избавляемся от пустот в столбце 'UTM-метка Content'
Paveletskaya_city_df['UTM-метка Content'] = Paveletskaya_city_df['UTM-метка Content'].fillna('нет')

# %%
print(Paveletskaya_city_df['UTM-метка Content'].count())
print(Paveletskaya_city_df['UTM-метка Content'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['UTM-метка Content'].tail()
# Out:
# 1513                                                                                                                              нет
# 1514    id|50275842_50275842|cid|90303913|gid|5236363476|aid|14838740692|adp|no|pos|none0|src|context_dsp.yandex.ru|dvc|mobile|coef|0
# 1515                                                                                                                              нет
# 1516                                                                                                                              нет
# 1517                                                                                                                              нет
# Name: UTM-метка Content, dtype: object

# %%
Paveletskaya_city_df['UTM-метка Content'][Paveletskaya_city_df['UTM-метка Content'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 17. Тип устройства

# %%
Paveletskaya_city_df['Тип устройства'].head()
# Out:
# 0     Прочее
# 1    Планшет
# 2         ПК
# 3         ПК
# 4    Планшет
# Name: Тип устройства, dtype: object

# %%
print(Paveletskaya_city_df['Тип устройства'].count())
print(Paveletskaya_city_df['Тип устройства'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Тип устройства'].tail()
# Out:
# 1513      Прочее
# 1514    Смартфон
# 1515      Прочее
# 1516      Прочее
# 1517      Прочее
# Name: Тип устройства, dtype: object

# %%
Paveletskaya_city_df['Тип устройства'][Paveletskaya_city_df['Тип устройства'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 18. Сайт

# %%
Paveletskaya_city_df['Сайт'].head()
# Out:
# 0    pavcity.ru
# 1    pavcity.ru
# 2    pavcity.ru
# 3    pavcity.ru
# 4    pavcity.ru
# Name: Сайт, dtype: object

# %%
print(Paveletskaya_city_df['Сайт'].count())
print(Paveletskaya_city_df['Сайт'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Сайт'].tail()
# Out:
# 1513    pavcity.ru
# 1514    pavcity.ru
# 1515    pavcity.ru
# 1516    pavcity.ru
# 1517    pavcity.ru
# Name: Сайт, dtype: object

# %%
Paveletskaya_city_df['Сайт'][Paveletskaya_city_df['Сайт'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 19. Оценка сотрудника

# %%
Paveletskaya_city_df['Оценка сотрудника'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Оценка сотрудника, dtype: float64

# %%
print(Paveletskaya_city_df['Оценка сотрудника'].count())
print(Paveletskaya_city_df['Оценка сотрудника'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Оценка сотрудника'
Paveletskaya_city_df['Оценка сотрудника'] = Paveletskaya_city_df['Оценка сотрудника'].fillna('нет')

# %%
print(Paveletskaya_city_df['Оценка сотрудника'].count())
print(Paveletskaya_city_df['Оценка сотрудника'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Оценка сотрудника'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Оценка сотрудника, dtype: object

# %%
Paveletskaya_city_df['Оценка сотрудника'][Paveletskaya_city_df['Оценка сотрудника'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Оценка сотрудника'][Paveletskaya_city_df['Оценка сотрудника'] == 'нет'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['Оценка сотрудника'][Paveletskaya_city_df['Оценка сотрудника'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 20. Виртуальный номер

# %%
Paveletskaya_city_df['Виртуальный номер'].head()
# Out:
# 0    74954315336
# 1    74954871153
# 2    74954871142
# 3    74954871142
# 4    74951069644
# Name: Виртуальный номер, dtype: int64

# %%
print(Paveletskaya_city_df['Виртуальный номер'].count())
print(Paveletskaya_city_df['Виртуальный номер'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Виртуальный номер'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'Виртуальный номер': int})

# %%
Paveletskaya_city_df['Виртуальный номер'].tail()
# Out:
# 1513    74950326372
# 1514    74951323095
# 1515    74950326372
# 1516    74950326372
# 1517    74950326372
# Name: Виртуальный номер, dtype: int64

# %% [markdown]
# ##### 21. Номер сотрудника

# %%
Paveletskaya_city_df['Номер сотрудника'].head()
# Out:
# 0      00288
# 1      00288
# 2      00288
# 3    00288<1
# 4    00288<1
# Name: Номер сотрудника, dtype: object

# %%
print(Paveletskaya_city_df['Номер сотрудника'].count())
print(Paveletskaya_city_df['Номер сотрудника'].shape[0])
# Out:
# 1518
# 1518

# %%
# Обрезаем '<1' в столбце 'Номер сотрудника'
Paveletskaya_city_df['Номер сотрудника'] = Paveletskaya_city_df['Номер сотрудника'].apply(lambda x: x.rstrip('<1'))

# %%
Paveletskaya_city_df['Номер сотрудника'][Paveletskaya_city_df['Номер сотрудника'] == ''].count()
# Out:
# 0

# %%
# Приводим тип данных столбца 'Номер сотрудника'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'Номер сотрудника': int})

# %%
Paveletskaya_city_df['Номер сотрудника'].tail()
# Out:
# 1513    288
# 1514    288
# 1515    288
# 1516    288
# 1517    288
# Name: Номер сотрудника, dtype: int64

# %% [markdown]
# ##### 22. Трансфер

# %%
Paveletskaya_city_df['Трансфер'].head()
# Out:
# 0    Нет
# 1    Нет
# 2    Нет
# 3    Нет
# 4    Нет
# Name: Трансфер, dtype: object

# %%
print(Paveletskaya_city_df['Трансфер'].count())
print(Paveletskaya_city_df['Трансфер'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Трансфер'].tail()
# Out:
# 1513    Нет
# 1514    Нет
# 1515    Нет
# 1516    Нет
# 1517    Нет
# Name: Трансфер, dtype: object

# %%
Paveletskaya_city_df['Трансфер'][Paveletskaya_city_df['Трансфер'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 23. Внутренний звонок

# %%
Paveletskaya_city_df['Внутренний звонок'].head()
# Out:
# 0    Нет
# 1    Нет
# 2    Нет
# 3    Нет
# 4    Нет
# Name: Внутренний звонок, dtype: object

# %%
print(Paveletskaya_city_df['Внутренний звонок'].count())
print(Paveletskaya_city_df['Внутренний звонок'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Внутренний звонок'].tail()
# Out:
# 1513    Нет
# 1514    Нет
# 1515    Нет
# 1516    Нет
# 1517    Нет
# Name: Внутренний звонок, dtype: object

# %%
Paveletskaya_city_df['Внутренний звонок'][Paveletskaya_city_df['Внутренний звонок'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Внутренний звонок'][Paveletskaya_city_df['Внутренний звонок'] == 'Нет'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['Внутренний звонок'][Paveletskaya_city_df['Внутренний звонок'] != 'Нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 24. ФИО контакта

# %%
Paveletskaya_city_df['ФИО контакта'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: ФИО контакта, dtype: float64

# %%
print(Paveletskaya_city_df['ФИО контакта'].count())
print(Paveletskaya_city_df['ФИО контакта'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'ФИО контакта'
Paveletskaya_city_df['ФИО контакта'] = Paveletskaya_city_df['ФИО контакта'].fillna('нет')

# %%
print(Paveletskaya_city_df['ФИО контакта'].count())
print(Paveletskaya_city_df['ФИО контакта'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['ФИО контакта'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: ФИО контакта, dtype: object

# %%
Paveletskaya_city_df['ФИО контакта'][Paveletskaya_city_df['ФИО контакта'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['ФИО контакта'][Paveletskaya_city_df['ФИО контакта'] == 'нет'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['ФИО контакта'][Paveletskaya_city_df['ФИО контакта'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 25. Имя тренера

# %%
Paveletskaya_city_df['Имя тренера'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Имя тренера, dtype: float64

# %%
print(Paveletskaya_city_df['Имя тренера'].count())
print(Paveletskaya_city_df['Имя тренера'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Имя тренера'
Paveletskaya_city_df['Имя тренера'] = Paveletskaya_city_df['Имя тренера'].fillna('нет')

# %%
print(Paveletskaya_city_df['Имя тренера'].count())
print(Paveletskaya_city_df['Имя тренера'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Имя тренера'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Имя тренера, dtype: object

# %%
Paveletskaya_city_df['Имя тренера'][Paveletskaya_city_df['Имя тренера'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Имя тренера'][Paveletskaya_city_df['Имя тренера'] == 'нет'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['Имя тренера'][Paveletskaya_city_df['Имя тренера'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 26. Сценарий

# %%
Paveletskaya_city_df['Сценарий'].head()
# Out:
# 0         TRUNK
# 1         TRUNK
# 2         TRUNK
# 3    ОЗ (SIP<1)
# 4    ОЗ (SIP<1)
# Name: Сценарий, dtype: object

# %%
print(Paveletskaya_city_df['Сценарий'].count())
print(Paveletskaya_city_df['Сценарий'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Сценарий'].tail()
# Out:
# 1513    ОЗ (SIP<1)
# 1514         TRUNK
# 1515         TRUNK
# 1516    ОЗ (SIP<1)
# 1517    ОЗ (SIP<1)
# Name: Сценарий, dtype: object

# %%
Paveletskaya_city_df['Сценарий'][Paveletskaya_city_df['Сценарий'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 27. Операции

# %%
Paveletskaya_city_df['Операции'].head()
# Out:
# 0                  Переадресация 1
# 1                  Переадресация 1
# 2                  Переадресация 1
# 3    Переадресация на сотрудника 1
# 4    Переадресация на сотрудника 1
# Name: Операции, dtype: object

# %%
print(Paveletskaya_city_df['Операции'].count())
print(Paveletskaya_city_df['Операции'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Операции'].tail()
# Out:
# 1513    Переадресация на сотрудника 1
# 1514                  Переадресация 1
# 1515                  Переадресация 1
# 1516    Переадресация на сотрудника 1
# 1517    Переадресация на сотрудника 1
# Name: Операции, dtype: object

# %%
Paveletskaya_city_df['Операции'][Paveletskaya_city_df['Операции'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 28. Идентификатор сессии звонка

# %%
Paveletskaya_city_df['Идентификатор сессии звонка'].head()
# Out:
# 0    3264400553
# 1    3264319898
# 2    3269863984
# 3    3269876069
# 4    3269823834
# Name: Идентификатор сессии звонка, dtype: int64

# %%
print(Paveletskaya_city_df['Идентификатор сессии звонка'].count())
print(Paveletskaya_city_df['Идентификатор сессии звонка'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Идентификатор сессии звонка'].tail()
# Out:
# 1513    3155178349
# 1514    3155993466
# 1515    3155994241
# 1516    3155158169
# 1517    3155155674
# Name: Идентификатор сессии звонка, dtype: int64

# %% [markdown]
# ##### 29. Причина завершения

# %%
Paveletskaya_city_df['Причина завершения'].head()
# Out:
# 0    Абонент разорвал соединение
# 1    Абонент разорвал соединение
# 2    Абонент разорвал соединение
# 3     Не дозвонились до абонента
# 4     Не дозвонились до абонента
# Name: Причина завершения, dtype: object

# %%
print(Paveletskaya_city_df['Причина завершения'].count())
print(Paveletskaya_city_df['Причина завершения'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Причина завершения'].tail()
# Out:
# 1513       Не дозвонились до абонента
# 1514      Абонент разорвал соединение
# 1515      Абонент разорвал соединение
# 1516    Сотрудник разорвал соединение
# 1517       Не дозвонились до абонента
# Name: Причина завершения, dtype: object

# %%
Paveletskaya_city_df['Причина завершения'][Paveletskaya_city_df['Причина завершения'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 30. Группа, выбранная посетителем

# %%
Paveletskaya_city_df['Группа, выбранная посетителем'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Группа, выбранная посетителем, dtype: float64

# %%
print(Paveletskaya_city_df['Группа, выбранная посетителем'].count())
print(Paveletskaya_city_df['Группа, выбранная посетителем'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Группа, выбранная посетителем'
Paveletskaya_city_df['Группа, выбранная посетителем'] = Paveletskaya_city_df['Группа, выбранная посетителем'].fillna('нет')

# %%
print(Paveletskaya_city_df['Группа, выбранная посетителем'].count())
print(Paveletskaya_city_df['Группа, выбранная посетителем'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Группа, выбранная посетителем'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Группа, выбранная посетителем, dtype: object

# %%
Paveletskaya_city_df['Группа, выбранная посетителем'][Paveletskaya_city_df['Группа, выбранная посетителем'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Группа, выбранная посетителем'][Paveletskaya_city_df['Группа, выбранная посетителем'] == 'нет'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['Группа, выбранная посетителем'][Paveletskaya_city_df['Группа, выбранная посетителем'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 31. Длительность обработки

# %%
Paveletskaya_city_df['Длительность обработки'].head()
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3    1860.0
# 4       NaN
# Name: Длительность обработки, dtype: float64

# %%
print(Paveletskaya_city_df['Длительность обработки'].count())
print(Paveletskaya_city_df['Длительность обработки'].shape[0])
# Out:
# 16
# 1518

# %%
# Избавляемся от пустот в столбце 'Длительность обработки'
Paveletskaya_city_df['Длительность обработки'] = Paveletskaya_city_df['Длительность обработки'].fillna('0')

# %%
print(Paveletskaya_city_df['Длительность обработки'].count())
print(Paveletskaya_city_df['Длительность обработки'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Длительность обработки'][Paveletskaya_city_df['Длительность обработки'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Длительность обработки'][Paveletskaya_city_df['Длительность обработки'] != '0'].head()
# Out:
# 3      1860.0
# 12     3920.0
# 59      107.0
# 442     151.0
# 449    5334.0
# Name: Длительность обработки, dtype: object

# %%
# Приводим тип данных столбца 'Длительность обработки'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'Длительность обработки': int})

# %%
Paveletskaya_city_df['Длительность обработки'].tail()
# Out:
# 1513     0
# 1514     0
# 1515     0
# 1516     0
# 1517    87
# Name: Длительность обработки, dtype: int64

# %% [markdown]
# ##### 32. Регион номера абонента

# %%
Paveletskaya_city_df['Регион номера абонента'].head()
# Out:
# 0    г. Москва
# 1    г. Москва
# 2    г. Москва
# 3    г. Москва
# 4    г. Москва
# Name: Регион номера абонента, dtype: object

# %%
print(Paveletskaya_city_df['Регион номера абонента'].count())
print(Paveletskaya_city_df['Регион номера абонента'].shape[0])
# Out:
# 1517
# 1518

# %%
# Избавляемся от пустот в столбце 'Регион номера абонента'
Paveletskaya_city_df['Регион номера абонента'] = Paveletskaya_city_df['Регион номера абонента'].fillna('не определено')

# %%
print(Paveletskaya_city_df['Регион номера абонента'].count())
print(Paveletskaya_city_df['Регион номера абонента'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Регион номера абонента'].tail()
# Out:
# 1513    Тульская обл.
# 1514        г. Москва
# 1515        г. Москва
# 1516        г. Москва
# 1517        г. Москва
# Name: Регион номера абонента, dtype: object

# %%
Paveletskaya_city_df['Регион номера абонента'][Paveletskaya_city_df['Регион номера абонента'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 33. Комментарий

# %%
Paveletskaya_city_df['Комментарий'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Комментарий, dtype: float64

# %%
print(Paveletskaya_city_df['Комментарий'].count())
print(Paveletskaya_city_df['Комментарий'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Комментарий'
Paveletskaya_city_df['Комментарий'] = Paveletskaya_city_df['Комментарий'].fillna('нет комментария')

# %%
print(Paveletskaya_city_df['Комментарий'].count())
print(Paveletskaya_city_df['Комментарий'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Комментарий'].tail()
# Out:
# 1513    нет комментария
# 1514    нет комментария
# 1515    нет комментария
# 1516    нет комментария
# 1517    нет комментария
# Name: Комментарий, dtype: object

# %%
Paveletskaya_city_df['Комментарий'][Paveletskaya_city_df['Комментарий'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 34. Контакт из CRM

# %%
Paveletskaya_city_df['Контакт из CRM'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Контакт из CRM, dtype: float64

# %%
print(Paveletskaya_city_df['Контакт из CRM'].count())
print(Paveletskaya_city_df['Контакт из CRM'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Контакт из CRM'
Paveletskaya_city_df['Контакт из CRM'] = Paveletskaya_city_df['Контакт из CRM'].fillna('нет')

# %%
print(Paveletskaya_city_df['Контакт из CRM'].count())
print(Paveletskaya_city_df['Контакт из CRM'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Контакт из CRM'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Контакт из CRM, dtype: object

# %%
Paveletskaya_city_df['Контакт из CRM'][Paveletskaya_city_df['Контакт из CRM'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Контакт из CRM'][Paveletskaya_city_df['Контакт из CRM'] == 'нет'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['Контакт из CRM'][Paveletskaya_city_df['Контакт из CRM'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 35. Поисковая система

# %%
Paveletskaya_city_df['Поисковая система'].head()
# Out:
# 0           NaN
# 1           NaN
# 2    google.com
# 3    google.com
# 4           NaN
# Name: Поисковая система, dtype: object

# %%
print(Paveletskaya_city_df['Поисковая система'].count())
print(Paveletskaya_city_df['Поисковая система'].shape[0])
# Out:
# 173
# 1518

# %%
# Избавляемся от пустот в столбце 'Поисковая система'
Paveletskaya_city_df['Поисковая система'] = Paveletskaya_city_df['Поисковая система'].fillna('нет')

# %%
print(Paveletskaya_city_df['Поисковая система'].count())
print(Paveletskaya_city_df['Поисковая система'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Поисковая система'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Поисковая система, dtype: object

# %%
Paveletskaya_city_df['Поисковая система'][Paveletskaya_city_df['Поисковая система'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 36. Поисковый запрос

# %%
Paveletskaya_city_df['Поисковый запрос'].head()
# Out:
# 0                                     NaN
# 1    купить квартиру павелецкая сити циан
# 2                                     NaN
# 3                                     NaN
# 4        {продажа квартиры замоскворечье}
# Name: Поисковый запрос, dtype: object

# %%
print(Paveletskaya_city_df['Поисковый запрос'].count())
print(Paveletskaya_city_df['Поисковый запрос'].shape[0])
# Out:
# 305
# 1518

# %%
# Избавляемся от пустот в столбце 'Поисковый запрос'
Paveletskaya_city_df['Поисковый запрос'] = Paveletskaya_city_df['Поисковый запрос'].fillna('нет запроса')

# %%
print(Paveletskaya_city_df['Поисковый запрос'].count())
print(Paveletskaya_city_df['Поисковый запрос'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Поисковый запрос'].tail()
# Out:
# 1513    нет запроса
# 1514    нет запроса
# 1515    нет запроса
# 1516    нет запроса
# 1517    нет запроса
# Name: Поисковый запрос, dtype: object

# %%
Paveletskaya_city_df['Поисковый запрос'][Paveletskaya_city_df['Поисковый запрос'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 37. Реферер

# %%
Paveletskaya_city_df['Реферер'].head()
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       NaN
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        https://pavcity.ru/?utm_source=yandex&utm_medium=cpc&utm_campaign=m108_pavcity_brand_net_mmo_exp_A|96311163&utm_term=купить квартиру павелецкая сити циан&utm_content=id|47205529851_47205529851|cid|96311163|gid|5288452139|aid|15032859723|adp|no|pos|none0|src|context_dsp.yandex.ru|dvc|tablet|coef|0&cm_id=96311163_5288452139_15032859723_47205529851_47205529851_dsp.yandex.ru_context_type1_no_tablet_none_10738&yclid=5375981140258656955
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   https://www.google.com/
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   https://www.google.com/
# 4    https://yandex.ru/an/count/WYmejI_zOoVX2Ldr0VKG0CDUTIOQbKeGJ2jaF9qxJQ3Fvt9dp_OxTzvmv-jtlDvmXwjiDXCpi5dve5GkSWX06J2BGSVHwumz-SgY6vtMu98iEbiYAaQi_0R9OhgErWGP2WSkG0k5ioj02stYKO0MYcKiG2jzyZoVq6UUJo203VS2blDrWEPBLb829XR8wUPOqVWgKYST4f8XGWIv3IZFYVne1WSB1AK-gTVg5EYcIclfrGQgez0Rhs_f7LHBy-ZzT5gjEpTt4tH8iJANQ2JmoetNpeGGmnDsv_CD4ywERX0RymG-GKuY2LGyhIyoi0UvXtPft3sv7aMWXjI8QnODkR8UcGotQBX76zpA2Wp1Ao7blk_xnWFuoW1seqfCYH5pcVRBmjQ1hAxLcPXqg1co22HJCrlwnn1Oa6cDBuRSjE3B1sFEx287cEuD3rP39YXa2MZg9O2u-CNU3fBA3t_7BKG-c8Cyylzoa4V-NWxoo9zBn0Z-ErtcGVvQkio3_BDqcGUPQSuGQCSiDw421Ovkv82LihLBysOlzcNFvdWaxCbUZkiGwyS-puCD62AdH_flp10bNhBUUwJ3TIdxBQthUgCErwNijJTasApFnX1X0h8OYCsLIgNIEe0KbKrlKNu9VW2HSCI2tOmN_0oWIRujFiNAME0_wGHfyHIsCaFMpuJJx0bR1cKPh5MPzWtzLFEdKUOWF08z9w8XFdbUWAi-8AuHgWanygBHSUOxrme1~2?target_ref=https://yastatic.net/video-player/0x4245470b306/pages-common/iframe-default/iframe-default.html&adsdk-bundle-version=880829&adsdk-bundle-name=Multiroll&ad-session-id=9599271696435091214&vsid=740e37f9ece4de43cd9...
# Name: Реферер, dtype: object

# %%
print(Paveletskaya_city_df['Реферер'].count())
print(Paveletskaya_city_df['Реферер'].shape[0])
# Out:
# 339
# 1518

# %%
# Избавляемся от пустот в столбце 'Реферер'
Paveletskaya_city_df['Реферер'] = Paveletskaya_city_df['Реферер'].fillna('нет')

# %%
print(Paveletskaya_city_df['Реферер'].count())
print(Paveletskaya_city_df['Реферер'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Реферер'].tail()
# Out:
# 1513                                                                                                                                                                                                                                                                                                                                                                         нет
# 1514    https://pavcity.ru/?utm_source=yandex&utm_medium=cpc&utm_campaign=master|90303913&utm_term=&utm_content=id|50275842_50275842|cid|90303913|gid|5236363476|aid|14838740692|adp|no|pos|none0|src|context_dsp.yandex.ru|dvc|mobile|coef|0&cm_id=90303913_5236363476_14838740692_50275842_50275842_dsp.yandex.ru_context_type1_no_mobile_none_10758&yclid=4681149557971424271
# 1515                                                                                                                                                                                                                                                                                                                                                                         нет
# 1516                                                                                                                                                                                                                                                                                                                                                                         нет
# 1517                                                                                                                                                                                                                                                                                                                                                                         нет
# Name: Реферер, dtype: object

# %%
Paveletskaya_city_df['Реферер'][Paveletskaya_city_df['Реферер'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 38. Домен реферера

# %%
Paveletskaya_city_df['Домен реферера'].head()
# Out:
# 0               NaN
# 1        pavcity.ru
# 2    www.google.com
# 3    www.google.com
# 4         yandex.ru
# Name: Домен реферера, dtype: object

# %%
print(Paveletskaya_city_df['Домен реферера'].count())
print(Paveletskaya_city_df['Домен реферера'].shape[0])
# Out:
# 339
# 1518

# %%
# Избавляемся от пустот в столбце 'Домен реферера'
Paveletskaya_city_df['Домен реферера'] = Paveletskaya_city_df['Домен реферера'].fillna('нет')

# %%
print(Paveletskaya_city_df['Домен реферера'].count())
print(Paveletskaya_city_df['Домен реферера'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Домен реферера'].tail()
# Out:
# 1513           нет
# 1514    pavcity.ru
# 1515           нет
# 1516           нет
# 1517           нет
# Name: Домен реферера, dtype: object

# %%
Paveletskaya_city_df['Домен реферера'][Paveletskaya_city_df['Домен реферера'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 39. Область

# %%
Paveletskaya_city_df['Область'].head()
# Out:
# 0                    NaN
# 1    Ставропольский край
# 2                 Москва
# 3                 Москва
# 4                 Москва
# Name: Область, dtype: object

# %%
print(Paveletskaya_city_df['Область'].count())
print(Paveletskaya_city_df['Область'].shape[0])
# Out:
# 363
# 1518

# %%
# Избавляемся от пустот в столбце 'Область'
Paveletskaya_city_df['Область'] = Paveletskaya_city_df['Область'].fillna('нет')

# %%
print(Paveletskaya_city_df['Область'].count())
print(Paveletskaya_city_df['Область'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Область'].tail()
# Out:
# 1513       нет
# 1514    Москва
# 1515       нет
# 1516       нет
# 1517       нет
# Name: Область, dtype: object

# %%
Paveletskaya_city_df['Область'][Paveletskaya_city_df['Область'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 40. Посадочная страница

# %%
Paveletskaya_city_df['Посадочная страница'].head()
# Out:
# 0                    NaN
# 1    https://pavcity.ru/
# 2    https://pavcity.ru/
# 3    https://pavcity.ru/
# 4    https://pavcity.ru/
# Name: Посадочная страница, dtype: object

# %%
print(Paveletskaya_city_df['Посадочная страница'].count())
print(Paveletskaya_city_df['Посадочная страница'].shape[0])
# Out:
# 555
# 1518

# %%
# Избавляемся от пустот в столбце 'Посадочная страница'
Paveletskaya_city_df['Посадочная страница'] = Paveletskaya_city_df['Посадочная страница'].fillna('нет')

# %%
print(Paveletskaya_city_df['Посадочная страница'].count())
print(Paveletskaya_city_df['Посадочная страница'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Посадочная страница'].tail()
# Out:
# 1513      https://pavcity.ru/
# 1514      https://pavcity.ru/
# 1515    {https://pavcity.ru/}
# 1516      https://pavcity.ru/
# 1517      https://pavcity.ru/
# Name: Посадочная страница, dtype: object

# %%
Paveletskaya_city_df['Посадочная страница'][Paveletskaya_city_df['Посадочная страница'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 41. Первая рекламная кампания

# %%
Paveletskaya_city_df['Первая рекламная кампания'].head()
# Out:
# 0                      Посетители без рекламной кампании
# 1    Media108 | Павелецкая Сити | direct | Яндекс.Директ
# 2         MRGroup | Павелецкая Сити | seo | Google Поиск
# 3         MRGroup | Павелецкая Сити | seo | Google Поиск
# 4    Media108 | Павелецкая Сити | direct | Яндекс.Директ
# Name: Первая рекламная кампания, dtype: object

# %%
print(Paveletskaya_city_df['Первая рекламная кампания'].count())
print(Paveletskaya_city_df['Первая рекламная кампания'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Первая рекламная кампания'].tail()
# Out:
# 1513           Media108 | Павелецкая Сити | social | VK Ads
# 1514    Media108 | Павелецкая Сити | direct | Яндекс.Директ
# 1515         {Media108 | Павелецкая Сити | social | VK Ads}
# 1516           Media108 | Павелецкая Сити | social | VK Ads
# 1517           Media108 | Павелецкая Сити | social | VK Ads
# Name: Первая рекламная кампания, dtype: object

# %%
Paveletskaya_city_df['Первая рекламная кампания'][Paveletskaya_city_df['Первая рекламная кампания'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 42. Количество посещений

# %%
Paveletskaya_city_df['Количество посещений'].head()
# Out:
# 0    NaN
# 1      2
# 2      1
# 3      1
# 4     41
# Name: Количество посещений, dtype: object

# %%
print(Paveletskaya_city_df['Количество посещений'].count())
print(Paveletskaya_city_df['Количество посещений'].shape[0])
# Out:
# 599
# 1518

# %%
# Избавляемся от пустот в столбце 'Количество посещений'
Paveletskaya_city_df['Количество посещений'] = Paveletskaya_city_df['Количество посещений'].fillna('0')

# %%
print(Paveletskaya_city_df['Количество посещений'].count())
print(Paveletskaya_city_df['Количество посещений'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Количество посещений'][Paveletskaya_city_df['Количество посещений'] == ''].count()
# Out:
# 0

# %%
# Приводим тип данных столбца 'Количество посещений'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'Количество посещений': str})

# %%
# Убираем '{}' в столбце 'Количество посещений'
Paveletskaya_city_df['Количество посещений'] = Paveletskaya_city_df['Количество посещений'].apply(lambda x: x.strip('{}'))

# %%
# Приводим тип данных столбца 'Количество посещений'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'Количество посещений': int})

# %%
Paveletskaya_city_df['Количество посещений'].tail()
# Out:
# 1513    1
# 1514    2
# 1515    1
# 1516    1
# 1517    1
# Name: Количество посещений, dtype: int64

# %% [markdown]
# ##### 43. Тип посетителя

# %%
Paveletskaya_city_df['Тип посетителя'].head()
# Out:
# 0    Не заполнен
# 1    Вернувшийся
# 2          Новый
# 3          Новый
# 4    Вернувшийся
# Name: Тип посетителя, dtype: object

# %%
print(Paveletskaya_city_df['Тип посетителя'].count())
print(Paveletskaya_city_df['Тип посетителя'].shape[0])
# Out:
# 1518
# 1518

# %%
# Убираем '{}' в столбце 'Тип посетителя'
Paveletskaya_city_df['Тип посетителя'] = Paveletskaya_city_df['Тип посетителя'].apply(lambda x: x.strip('{}'))

# %%
Paveletskaya_city_df['Тип посетителя'].tail()
# Out:
# 1513          Новый
# 1514    Вернувшийся
# 1515          Новый
# 1516          Новый
# 1517          Новый
# Name: Тип посетителя, dtype: object

# %%
Paveletskaya_city_df['Тип посетителя'][Paveletskaya_city_df['Тип посетителя'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 44. Client ID Google Analytics

# %%
Paveletskaya_city_df['Client ID Google Analytics'].head()
# Out:
# 0             NaN
# 1    1.284079e+09
# 2    1.946364e+09
# 3    1.946364e+09
# 4    1.384131e+09
# Name: Client ID Google Analytics, dtype: float64

# %%
print(Paveletskaya_city_df['Client ID Google Analytics'].count())
print(Paveletskaya_city_df['Client ID Google Analytics'].shape[0])
# Out:
# 379
# 1518

# %%
# Избавляемся от пустот в столбце 'Client ID Google Analytics'
Paveletskaya_city_df['Client ID Google Analytics'] = Paveletskaya_city_df['Client ID Google Analytics'].fillna('0')

# %%
print(Paveletskaya_city_df['Client ID Google Analytics'].count())
print(Paveletskaya_city_df['Client ID Google Analytics'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Client ID Google Analytics'].tail()
# Out:
# 1513                   0
# 1514    801330055.169203
# 1515                   0
# 1516                   0
# 1517                   0
# Name: Client ID Google Analytics, dtype: object

# %%
Paveletskaya_city_df['Client ID Google Analytics'][Paveletskaya_city_df['Client ID Google Analytics'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 45. ID ресурса Google Analytics

# %%
Paveletskaya_city_df['ID ресурса Google Analytics'].head()
# Out:
# 0              NaN
# 1    UA-43866177-8
# 2    UA-43866177-8
# 3    UA-43866177-8
# 4    UA-43866177-8
# Name: ID ресурса Google Analytics, dtype: object

# %%
print(Paveletskaya_city_df['ID ресурса Google Analytics'].count())
print(Paveletskaya_city_df['ID ресурса Google Analytics'].shape[0])
# Out:
# 561
# 1518

# %%
# Избавляемся от пустот в столбце 'ID ресурса Google Analytics'
Paveletskaya_city_df['ID ресурса Google Analytics'] = Paveletskaya_city_df['ID ресурса Google Analytics'].fillna('0')

# %%
print(Paveletskaya_city_df['ID ресурса Google Analytics'].count())
print(Paveletskaya_city_df['ID ресурса Google Analytics'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['ID ресурса Google Analytics'].tail()
# Out:
# 1513    UA-43866177-8
# 1514    UA-43866177-8
# 1515    UA-43866177-8
# 1516    UA-43866177-8
# 1517    UA-43866177-8
# Name: ID ресурса Google Analytics, dtype: object

# %%
Paveletskaya_city_df['ID ресурса Google Analytics'][Paveletskaya_city_df['ID ресурса Google Analytics'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 46. ID счетчика Яндекс.Метрика

# %%
Paveletskaya_city_df['ID счетчика Яндекс.Метрика'].head()
# Out:
# 0           NaN
# 1    57251161.0
# 2    57251161.0
# 3    57251161.0
# 4    57251161.0
# Name: ID счетчика Яндекс.Метрика, dtype: float64

# %%
print(Paveletskaya_city_df['ID счетчика Яндекс.Метрика'].count())
print(Paveletskaya_city_df['ID счетчика Яндекс.Метрика'].shape[0])
# Out:
# 561
# 1518

# %%
# Избавляемся от пустот в столбце 'ID счетчика Яндекс.Метрика'
Paveletskaya_city_df['ID счетчика Яндекс.Метрика'] = Paveletskaya_city_df['ID счетчика Яндекс.Метрика'].fillna('0')

# %%
print(Paveletskaya_city_df['ID счетчика Яндекс.Метрика'].count())
print(Paveletskaya_city_df['ID счетчика Яндекс.Метрика'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['ID счетчика Яндекс.Метрика'][Paveletskaya_city_df['ID счетчика Яндекс.Метрика'] == ''].count()
# Out:
# 0

# %%
# Приводим тип данных столбца 'ID счетчика Яндекс.Метрика'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'ID счетчика Яндекс.Метрика': int})

# %%
# Приводим тип данных столбца 'ID счетчика Яндекс.Метрика'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'ID счетчика Яндекс.Метрика': str})

# %%
Paveletskaya_city_df['ID счетчика Яндекс.Метрика'].tail()
# Out:
# 1513    57251161
# 1514    57251161
# 1515    57251161
# 1516    57251161
# 1517    57251161
# Name: ID счетчика Яндекс.Метрика, dtype: object

# %% [markdown]
# ##### 47. URL страницы обращения

# %%
Paveletskaya_city_df['URL страницы обращения'].head()
# Out:
# 0                    NaN
# 1    https://pavcity.ru/
# 2    https://pavcity.ru/
# 3    https://pavcity.ru/
# 4    https://pavcity.ru/
# Name: URL страницы обращения, dtype: object

# %%
print(Paveletskaya_city_df['URL страницы обращения'].count())
print(Paveletskaya_city_df['URL страницы обращения'].shape[0])
# Out:
# 561
# 1518

# %%
# Избавляемся от пустот в столбце 'URL страницы обращения'
Paveletskaya_city_df['URL страницы обращения'] = Paveletskaya_city_df['URL страницы обращения'].fillna('нет')

# %%
print(Paveletskaya_city_df['URL страницы обращения'].count())
print(Paveletskaya_city_df['URL страницы обращения'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['URL страницы обращения'].tail()
# Out:
# 1513    https://pavcity.ru/
# 1514    https://pavcity.ru/
# 1515    https://pavcity.ru/
# 1516    https://pavcity.ru/
# 1517    https://pavcity.ru/
# Name: URL страницы обращения, dtype: object

# %%
Paveletskaya_city_df['URL страницы обращения'][Paveletskaya_city_df['URL страницы обращения'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 48. UTM-метка Source

# %%
Paveletskaya_city_df['UTM-метка Source'].head()
# Out:
# 0       NaN
# 1    yandex
# 2       NaN
# 3       NaN
# 4    yandex
# Name: UTM-метка Source, dtype: object

# %%
print(Paveletskaya_city_df['UTM-метка Source'].count())
print(Paveletskaya_city_df['UTM-метка Source'].shape[0])
# Out:
# 339
# 1518

# %%
# Избавляемся от пустот в столбце 'UTM-метка Source'
Paveletskaya_city_df['UTM-метка Source'] = Paveletskaya_city_df['UTM-метка Source'].fillna('нет')

# %%
print(Paveletskaya_city_df['UTM-метка Source'].count())
print(Paveletskaya_city_df['UTM-метка Source'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['UTM-метка Source'].tail()
# Out:
# 1513       нет
# 1514    yandex
# 1515       нет
# 1516       нет
# 1517       нет
# Name: UTM-метка Source, dtype: object

# %%
Paveletskaya_city_df['UTM-метка Source'][Paveletskaya_city_df['UTM-метка Source'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 49. UTM-метка Medium

# %%
Paveletskaya_city_df['UTM-метка Medium'].head()
# Out:
# 0    NaN
# 1    cpc
# 2    NaN
# 3    NaN
# 4    cpc
# Name: UTM-метка Medium, dtype: object

# %%
print(Paveletskaya_city_df['UTM-метка Medium'].count())
print(Paveletskaya_city_df['UTM-метка Medium'].shape[0])
# Out:
# 339
# 1518

# %%
# Избавляемся от пустот в столбце 'UTM-метка Medium'
Paveletskaya_city_df['UTM-метка Medium'] = Paveletskaya_city_df['UTM-метка Medium'].fillna('нет')

# %%
print(Paveletskaya_city_df['UTM-метка Medium'].count())
print(Paveletskaya_city_df['UTM-метка Medium'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['UTM-метка Medium'].tail()
# Out:
# 1513    нет
# 1514    cpc
# 1515    нет
# 1516    нет
# 1517    нет
# Name: UTM-метка Medium, dtype: object

# %%
Paveletskaya_city_df['UTM-метка Medium'][Paveletskaya_city_df['UTM-метка Medium'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 50. UTM-метка Term

# %%
Paveletskaya_city_df['UTM-метка Term'].head()
# Out:
# 0                                     NaN
# 1    купить квартиру павелецкая сити циан
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# Name: UTM-метка Term, dtype: object

# %%
print(Paveletskaya_city_df['UTM-метка Term'].count())
print(Paveletskaya_city_df['UTM-метка Term'].shape[0])
# Out:
# 225
# 1518

# %%
# Избавляемся от пустот в столбце 'UTM-метка Term'
Paveletskaya_city_df['UTM-метка Term'] = Paveletskaya_city_df['UTM-метка Term'].fillna('нет')

# %%
print(Paveletskaya_city_df['UTM-метка Term'].count())
print(Paveletskaya_city_df['UTM-метка Term'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['UTM-метка Term'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: UTM-метка Term, dtype: object

# %%
Paveletskaya_city_df['UTM-метка Term'][Paveletskaya_city_df['UTM-метка Term'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['UTM-метка Term'][Paveletskaya_city_df['UTM-метка Term'] == 'нет'].count()
# Out:
# 1293

# %%
Paveletskaya_city_df['UTM-метка Term'][Paveletskaya_city_df['UTM-метка Term'] != 'нет'].count()
# Out:
# 225

# %% [markdown]
# ##### 51. UTM-метка Referrer

# %%
Paveletskaya_city_df['UTM-метка Referrer'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: UTM-метка Referrer, dtype: float64

# %%
print(Paveletskaya_city_df['UTM-метка Referrer'].count())
print(Paveletskaya_city_df['UTM-метка Referrer'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'UTM-метка Referrer'
Paveletskaya_city_df['UTM-метка Referrer'] = Paveletskaya_city_df['UTM-метка Referrer'].fillna('нет')

# %%
print(Paveletskaya_city_df['UTM-метка Referrer'].count())
print(Paveletskaya_city_df['UTM-метка Referrer'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['UTM-метка Referrer'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: UTM-метка Referrer, dtype: object

# %%
Paveletskaya_city_df['UTM-метка Referrer'][Paveletskaya_city_df['UTM-метка Referrer'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['UTM-метка Referrer'][Paveletskaya_city_df['UTM-метка Referrer'] == 'нет'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['UTM-метка Referrer'][Paveletskaya_city_df['UTM-метка Referrer'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 52. UTM-метка Expid

# %%
Paveletskaya_city_df['UTM-метка Expid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: UTM-метка Expid, dtype: float64

# %%
print(Paveletskaya_city_df['UTM-метка Expid'].count())
print(Paveletskaya_city_df['UTM-метка Expid'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'UTM-метка Expid'
Paveletskaya_city_df['UTM-метка Expid'] = Paveletskaya_city_df['UTM-метка Expid'].fillna('нет')

# %%
print(Paveletskaya_city_df['UTM-метка Expid'].count())
print(Paveletskaya_city_df['UTM-метка Expid'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['UTM-метка Expid'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: UTM-метка Expid, dtype: object

# %%
Paveletskaya_city_df['UTM-метка Expid'][Paveletskaya_city_df['UTM-метка Expid'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['UTM-метка Expid'][Paveletskaya_city_df['UTM-метка Expid'] == 'нет'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['UTM-метка Expid'][Paveletskaya_city_df['UTM-метка Expid'] != 'нет'].count()
# Out:
# 0

# %% [markdown]
# ##### 53. OS-метка service-name

# %%
Paveletskaya_city_df['OS-метка service-name'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: OS-метка service-name, dtype: object

# %%
print(Paveletskaya_city_df['OS-метка service-name'].count())
print(Paveletskaya_city_df['OS-метка service-name'].shape[0])
# Out:
# 2
# 1518

# %%
# Избавляемся от пустот в столбце 'OS-метка service-name'
Paveletskaya_city_df['OS-метка service-name'] = Paveletskaya_city_df['OS-метка service-name'].fillna('нет')

# %%
print(Paveletskaya_city_df['OS-метка service-name'].count())
print(Paveletskaya_city_df['OS-метка service-name'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['OS-метка service-name'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: OS-метка service-name, dtype: object

# %%
Paveletskaya_city_df['OS-метка service-name'][Paveletskaya_city_df['OS-метка service-name'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['OS-метка service-name'][Paveletskaya_city_df['OS-метка service-name'] == 'нет'].count()
# Out:
# 1516

# %%
Paveletskaya_city_df['OS-метка service-name'][Paveletskaya_city_df['OS-метка service-name'] != 'нет'].count()
# Out:
# 2

# %%
Paveletskaya_city_df['OS-метка service-name'][Paveletskaya_city_df['OS-метка service-name'] != 'нет']
# Out:
# 1206    direct.yandex.ru
# 1482    direct.yandex.ru
# Name: OS-метка service-name, dtype: object

# %% [markdown]
# ##### 54. OS-метка campaign-id

# %%
Paveletskaya_city_df['OS-метка campaign-id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка campaign-id, dtype: float64

# %%
print(Paveletskaya_city_df['OS-метка campaign-id'].count())
print(Paveletskaya_city_df['OS-метка campaign-id'].shape[0])
# Out:
# 2
# 1518

# %%
# Избавляемся от пустот в столбце 'OS-метка campaign-id'
Paveletskaya_city_df['OS-метка campaign-id'] = Paveletskaya_city_df['OS-метка campaign-id'].fillna('0')

# %%
print(Paveletskaya_city_df['OS-метка campaign-id'].count())
print(Paveletskaya_city_df['OS-метка campaign-id'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['OS-метка campaign-id'].tail()
# Out:
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    0
# Name: OS-метка campaign-id, dtype: object

# %%
Paveletskaya_city_df['OS-метка campaign-id'][Paveletskaya_city_df['OS-метка campaign-id'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['OS-метка campaign-id'][Paveletskaya_city_df['OS-метка campaign-id'] == '0'].count()
# Out:
# 1516

# %%
Paveletskaya_city_df['OS-метка campaign-id'][Paveletskaya_city_df['OS-метка campaign-id'] != '0'].count()
# Out:
# 2

# %%
Paveletskaya_city_df = Paveletskaya_city_df.astype({'OS-метка campaign-id': int})

# %%
Paveletskaya_city_df = Paveletskaya_city_df.astype({'OS-метка campaign-id': str})

# %%
Paveletskaya_city_df['OS-метка campaign-id'][Paveletskaya_city_df['OS-метка campaign-id'] != '0']
# Out:
# 1206    50231905
# 1482    53841693
# Name: OS-метка campaign-id, dtype: object

# %% [markdown]
# ##### 55. OS-метка ad-id

# %%
Paveletskaya_city_df['OS-метка ad-id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: OS-метка ad-id, dtype: float64

# %%
print(Paveletskaya_city_df['OS-метка ad-id'].count())
print(Paveletskaya_city_df['OS-метка ad-id'].shape[0])
# Out:
# 2
# 1518

# %%
# Избавляемся от пустот в столбце 'OS-метка ad-id'
Paveletskaya_city_df['OS-метка ad-id'] = Paveletskaya_city_df['OS-метка ad-id'].fillna('0')

# %%
print(Paveletskaya_city_df['OS-метка ad-id'].count())
print(Paveletskaya_city_df['OS-метка ad-id'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['OS-метка ad-id'].tail()
# Out:
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    0
# Name: OS-метка ad-id, dtype: object

# %%
Paveletskaya_city_df['OS-метка ad-id'][Paveletskaya_city_df['OS-метка ad-id'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['OS-метка ad-id'][Paveletskaya_city_df['OS-метка ad-id'] == '0'].count()
# Out:
# 1516

# %%
Paveletskaya_city_df['OS-метка ad-id'][Paveletskaya_city_df['OS-метка ad-id'] != '0'].count()
# Out:
# 2

# %%
# Приводим тип данных столбца 'OS-метка ad-id'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'OS-метка ad-id': int})

# %%
# Приводим тип данных столбца 'OS-метка ad-id'
Paveletskaya_city_df = Paveletskaya_city_df.astype({'OS-метка ad-id': str})

# %%
Paveletskaya_city_df['OS-метка ad-id'][Paveletskaya_city_df['OS-метка ad-id'] != '0']
# Out:
# 1206    10016275729
# 1482    11012736878
# Name: OS-метка ad-id, dtype: object

# %% [markdown]
# ##### 56. OS-метка source-id

# %%
Paveletskaya_city_df['OS-метка source-id'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: OS-метка source-id, dtype: object

# %%
print(Paveletskaya_city_df['OS-метка source-id'].count())
print(Paveletskaya_city_df['OS-метка source-id'].shape[0])
# Out:
# 2
# 1518

# %%
# Избавляемся от пустот в столбце 'OS-метка source-id'
Paveletskaya_city_df['OS-метка source-id'] = Paveletskaya_city_df['OS-метка source-id'].fillna('0')

# %%
print(Paveletskaya_city_df['OS-метка source-id'].count())
print(Paveletskaya_city_df['OS-метка source-id'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['OS-метка source-id'].tail()
# Out:
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    0
# Name: OS-метка source-id, dtype: object

# %%
Paveletskaya_city_df['OS-метка source-id'][Paveletskaya_city_df['OS-метка source-id'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['OS-метка source-id'][Paveletskaya_city_df['OS-метка source-id'] == '0'].count()
# Out:
# 1516

# %%
Paveletskaya_city_df['OS-метка source-id'][Paveletskaya_city_df['OS-метка source-id'] != '0'].count()
# Out:
# 2

# %%
Paveletskaya_city_df['OS-метка source-id'][Paveletskaya_city_df['OS-метка source-id'] != '0']
# Out:
# 1206    yandex.ru:guarantee
# 1482    yandex.ru:guarantee
# Name: OS-метка source-id, dtype: object

# %% [markdown]
# ##### 57. AdLense-метка ef_id

# %%
Paveletskaya_city_df['AdLense-метка ef_id'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: AdLense-метка ef_id, dtype: float64

# %%
print(Paveletskaya_city_df['AdLense-метка ef_id'].count())
print(Paveletskaya_city_df['AdLense-метка ef_id'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'AdLense-метка ef_id'
Paveletskaya_city_df['AdLense-метка ef_id'] = Paveletskaya_city_df['AdLense-метка ef_id'].fillna('0')

# %%
print(Paveletskaya_city_df['AdLense-метка ef_id'].count())
print(Paveletskaya_city_df['AdLense-метка ef_id'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['AdLense-метка ef_id'].tail()
# Out:
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    0
# Name: AdLense-метка ef_id, dtype: object

# %%
Paveletskaya_city_df['AdLense-метка ef_id'][Paveletskaya_city_df['AdLense-метка ef_id'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['AdLense-метка ef_id'][Paveletskaya_city_df['AdLense-метка ef_id'] == '0'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['AdLense-метка ef_id'][Paveletskaya_city_df['AdLense-метка ef_id'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 58. Метка yclid

# %%
Paveletskaya_city_df['Метка yclid'].head()
# Out:
# 0                    NaN
# 1    5375981140258656955
# 2                    NaN
# 3                    NaN
# 4    5835925593675854519
# Name: Метка yclid, dtype: object

# %%
print(Paveletskaya_city_df['Метка yclid'].count())
print(Paveletskaya_city_df['Метка yclid'].shape[0])
# Out:
# 318
# 1518

# %%
# Избавляемся от пустот в столбце 'Метка yclid'
Paveletskaya_city_df['Метка yclid'] = Paveletskaya_city_df['Метка yclid'].fillna('0')

# %%
print(Paveletskaya_city_df['Метка yclid'].count())
print(Paveletskaya_city_df['Метка yclid'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Метка yclid'].tail()
# Out:
# 1513                      0
# 1514    4681149557971424271
# 1515                      0
# 1516                      0
# 1517                      0
# Name: Метка yclid, dtype: object

# %%
Paveletskaya_city_df['Метка yclid'][Paveletskaya_city_df['Метка yclid'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 59. Метка ymclid

# %%
Paveletskaya_city_df['Метка ymclid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Метка ymclid, dtype: float64

# %%
print(Paveletskaya_city_df['Метка ymclid'].count())
print(Paveletskaya_city_df['Метка ymclid'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Метка ymclid'
Paveletskaya_city_df['Метка ymclid'] = Paveletskaya_city_df['Метка ymclid'].fillna('0')

# %%
print(Paveletskaya_city_df['Метка ymclid'].count())
print(Paveletskaya_city_df['Метка ymclid'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Метка ymclid'].tail()
# Out:
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    0
# Name: Метка ymclid, dtype: object

# %%
Paveletskaya_city_df['Метка ymclid'][Paveletskaya_city_df['Метка ymclid'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Метка ymclid'][Paveletskaya_city_df['Метка ymclid'] == '0'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['Метка ymclid'][Paveletskaya_city_df['Метка ymclid'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 60. Метка gclid

# %%
Paveletskaya_city_df['Метка gclid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Метка gclid, dtype: float64

# %%
print(Paveletskaya_city_df['Метка gclid'].count())
print(Paveletskaya_city_df['Метка gclid'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Метка gclid'
Paveletskaya_city_df['Метка gclid'] = Paveletskaya_city_df['Метка gclid'].fillna('0')

# %%
print(Paveletskaya_city_df['Метка gclid'].count())
print(Paveletskaya_city_df['Метка gclid'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Метка gclid'].tail()
# Out:
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    0
# Name: Метка gclid, dtype: object

# %%
Paveletskaya_city_df['Метка gclid'][Paveletskaya_city_df['Метка gclid'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Метка gclid'][Paveletskaya_city_df['Метка gclid'] == '0'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['Метка gclid'][Paveletskaya_city_df['Метка gclid'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 61. Метка from

# %%
Paveletskaya_city_df['Метка from'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Метка from, dtype: float64

# %%
print(Paveletskaya_city_df['Метка from'].count())
print(Paveletskaya_city_df['Метка from'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Метка from'
Paveletskaya_city_df['Метка from'] = Paveletskaya_city_df['Метка from'].fillna('0')

# %%
print(Paveletskaya_city_df['Метка from'].count())
print(Paveletskaya_city_df['Метка from'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Метка from'].tail()
# Out:
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    0
# Name: Метка from, dtype: object

# %%
Paveletskaya_city_df['Метка from'][Paveletskaya_city_df['Метка from'] == ''].count()
# Out:
# 0

# %%
Paveletskaya_city_df['Метка from'][Paveletskaya_city_df['Метка from'] == '0'].count()
# Out:
# 1518

# %%
Paveletskaya_city_df['Метка from'][Paveletskaya_city_df['Метка from'] != '0'].count()
# Out:
# 0

# %% [markdown]
# ##### 62. Длительность разговора

# %%
Paveletskaya_city_df['Длительность разговора'].head()
# Out:
# 0    00:00:06
# 1    00:00:03
# 2    00:20:46
# 3    00:00:00
# 4    00:00:00
# Name: Длительность разговора, dtype: object

# %%
print(Paveletskaya_city_df['Длительность разговора'].count())
print(Paveletskaya_city_df['Длительность разговора'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Длительность разговора'
Paveletskaya_city_df['Длительность разговора'] = pd.to_datetime(Paveletskaya_city_df['Длительность разговора']).dt.time

# %%
Paveletskaya_city_df['Длительность разговора'].tail()
# Out:
# 1513    00:00:00
# 1514    00:00:03
# 1515    00:00:07
# 1516    00:00:06
# 1517    00:00:00
# Name: Длительность разговора, dtype: object

# %% [markdown]
# ##### 63. Длительность постобработки

# %%
Paveletskaya_city_df['Длительность постобработки'].head()
# Out:
# 0    00:00:00
# 1    00:00:00
# 2    00:00:00
# 3    00:00:00
# 4    00:00:00
# Name: Длительность постобработки, dtype: object

# %%
print(Paveletskaya_city_df['Длительность постобработки'].count())
print(Paveletskaya_city_df['Длительность постобработки'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Длительность постобработки'
Paveletskaya_city_df['Длительность постобработки'] = pd.to_datetime(Paveletskaya_city_df['Длительность постобработки']).dt.time

# %%
Paveletskaya_city_df['Длительность постобработки'].tail()
# Out:
# 1513    00:00:00
# 1514    00:00:00
# 1515    00:00:00
# 1516    00:00:00
# 1517    00:00:00
# Name: Длительность постобработки, dtype: object

# %% [markdown]
# ##### 64. Чистая длительность разговора

# %%
Paveletskaya_city_df['Чистая длительность разговора'].head()
# Out:
# 0    00:00:05
# 1    00:00:02
# 2    00:20:46
# 3    00:00:00
# 4    00:00:00
# Name: Чистая длительность разговора, dtype: object

# %%
print(Paveletskaya_city_df['Чистая длительность разговора'].count())
print(Paveletskaya_city_df['Чистая длительность разговора'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Чистая длительность разговора'
Paveletskaya_city_df['Чистая длительность разговора'] = pd.to_datetime(Paveletskaya_city_df['Чистая длительность разговора']).dt.time

# %%
Paveletskaya_city_df['Чистая длительность разговора'].tail()
# Out:
# 1513    00:00:00
# 1514    00:00:02
# 1515    00:00:07
# 1516    00:00:06
# 1517    00:00:00
# Name: Чистая длительность разговора, dtype: object

# %% [markdown]
# ##### 65. Полная длительность ожидания

# %%
Paveletskaya_city_df['Полная длительность ожидания'].head()
# Out:
# 0    00:00:01
# 1    00:00:01
# 2    00:00:00
# 3    00:00:33
# 4    00:00:48
# Name: Полная длительность ожидания, dtype: object

# %%
print(Paveletskaya_city_df['Полная длительность ожидания'].count())
print(Paveletskaya_city_df['Полная длительность ожидания'].shape[0])
# Out:
# 1518
# 1518

# %%
# Приводим тип данных столбца 'Полная длительность ожидания'
Paveletskaya_city_df['Полная длительность ожидания'] = pd.to_datetime(Paveletskaya_city_df['Полная длительность ожидания']).dt.time

# %%
Paveletskaya_city_df['Полная длительность ожидания'].tail()
# Out:
# 1513    00:00:55
# 1514    00:00:01
# 1515    00:00:00
# 1516    00:00:32
# 1517    00:00:57
# Name: Полная длительность ожидания, dtype: object

# %% [markdown]
# ##### 66. Идентификатор звонка во внешней системе

# %%
Paveletskaya_city_df['Идентификатор звонка во внешней системе'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Идентификатор звонка во внешней системе, dtype: float64

# %%
print(Paveletskaya_city_df['Идентификатор звонка во внешней системе'].count())
print(Paveletskaya_city_df['Идентификатор звонка во внешней системе'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Идентификатор звонка во внешней системе'
Paveletskaya_city_df['Идентификатор звонка во внешней системе'] = Paveletskaya_city_df['Идентификатор звонка во внешней системе'].fillna('0')

# %%
print(Paveletskaya_city_df['Идентификатор звонка во внешней системе'].count())
print(Paveletskaya_city_df['Идентификатор звонка во внешней системе'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Идентификатор звонка во внешней системе'].tail()
# Out:
# 1513    0
# 1514    0
# 1515    0
# 1516    0
# 1517    0
# Name: Идентификатор звонка во внешней системе, dtype: object

# %%
Paveletskaya_city_df['Идентификатор звонка во внешней системе'][Paveletskaya_city_df['Идентификатор звонка во внешней системе'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 67. Расширенная UTM-метка Source

# %%
Paveletskaya_city_df['Расширенная UTM-метка Source'].head()
# Out:
# 0       NaN
# 1    yandex
# 2       NaN
# 3       NaN
# 4    yandex
# Name: Расширенная UTM-метка Source, dtype: object

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Source'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Source'].shape[0])
# Out:
# 339
# 1518

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Source'
Paveletskaya_city_df['Расширенная UTM-метка Source'] = Paveletskaya_city_df['Расширенная UTM-метка Source'].fillna('нет')

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Source'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Source'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Расширенная UTM-метка Source'].tail()
# Out:
# 1513       нет
# 1514    yandex
# 1515       нет
# 1516       нет
# 1517       нет
# Name: Расширенная UTM-метка Source, dtype: object

# %%
Paveletskaya_city_df['Расширенная UTM-метка Source'][Paveletskaya_city_df['Расширенная UTM-метка Source'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 68. Расширенная UTM-метка Campaign

# %%
Paveletskaya_city_df['Расширенная UTM-метка Campaign'].head()
# Out:
# 0                                                     NaN
# 1               m108_pavcity_brand_net_mmo_exp_A|96311163
# 2                                                     NaN
# 3                                                     NaN
# 4    m108_pavcity_retarget_neotkaz_net_mmo_exp_A|96311169
# Name: Расширенная UTM-метка Campaign, dtype: object

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Campaign'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Campaign'].shape[0])
# Out:
# 339
# 1518

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Campaign'
Paveletskaya_city_df['Расширенная UTM-метка Campaign'] = Paveletskaya_city_df['Расширенная UTM-метка Campaign'].fillna('нет')

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Campaign'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Campaign'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Расширенная UTM-метка Campaign'].tail()
# Out:
# 1513                нет
# 1514    master|90303913
# 1515                нет
# 1516                нет
# 1517                нет
# Name: Расширенная UTM-метка Campaign, dtype: object

# %%
Paveletskaya_city_df['Расширенная UTM-метка Campaign'][Paveletskaya_city_df['Расширенная UTM-метка Campaign'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 69. Расширенная UTM-метка Medium

# %%
Paveletskaya_city_df['Расширенная UTM-метка Medium'].head()
# Out:
# 0    NaN
# 1    cpc
# 2    NaN
# 3    NaN
# 4    cpc
# Name: Расширенная UTM-метка Medium, dtype: object

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Medium'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Medium'].shape[0])
# Out:
# 339
# 1518

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Medium'
Paveletskaya_city_df['Расширенная UTM-метка Medium'] = Paveletskaya_city_df['Расширенная UTM-метка Medium'].fillna('нет')

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Medium'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Medium'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Расширенная UTM-метка Medium'].tail()
# Out:
# 1513    нет
# 1514    cpc
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Расширенная UTM-метка Medium, dtype: object

# %%
Paveletskaya_city_df['Расширенная UTM-метка Medium'][Paveletskaya_city_df['Расширенная UTM-метка Medium'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 70. Расширенная UTM-метка Content

# %%
Paveletskaya_city_df['Расширенная UTM-метка Content'].head()
# Out:
# 0                                                                                                                                    NaN
# 1    id|47205529851_47205529851|cid|96311163|gid|5288452139|aid|15032859723|adp|no|pos|none0|src|context_dsp.yandex.ru|dvc|tablet|coef|0
# 2                                                                                                                                    NaN
# 3                                                                                                                                    NaN
# 4                id|55165192_55165192|cid|96311169|gid|5288452157|aid|15032860276|adp|no|pos|none0|src|context_dzen.ru|dvc|tablet|coef|0
# Name: Расширенная UTM-метка Content, dtype: object

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Content'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Content'].shape[0])
# Out:
# 319
# 1518

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Content'
Paveletskaya_city_df['Расширенная UTM-метка Content'] = Paveletskaya_city_df['Расширенная UTM-метка Content'].fillna('нет')

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Content'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Content'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Расширенная UTM-метка Content'].tail()
# Out:
# 1513                                                                                                                              нет
# 1514    id|50275842_50275842|cid|90303913|gid|5236363476|aid|14838740692|adp|no|pos|none0|src|context_dsp.yandex.ru|dvc|mobile|coef|0
# 1515                                                                                                                              нет
# 1516                                                                                                                              нет
# 1517                                                                                                                              нет
# Name: Расширенная UTM-метка Content, dtype: object

# %%
Paveletskaya_city_df['Расширенная UTM-метка Content'][Paveletskaya_city_df['Расширенная UTM-метка Content'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 71. Расширенная UTM-метка Term

# %%
Paveletskaya_city_df['Расширенная UTM-метка Term'].head()
# Out:
# 0                                     NaN
# 1    купить квартиру павелецкая сити циан
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# Name: Расширенная UTM-метка Term, dtype: object

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Term'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Term'].shape[0])
# Out:
# 225
# 1518

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Term'
Paveletskaya_city_df['Расширенная UTM-метка Term'] = Paveletskaya_city_df['Расширенная UTM-метка Term'].fillna('нет')

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Term'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Term'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Расширенная UTM-метка Term'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Расширенная UTM-метка Term, dtype: object

# %%
Paveletskaya_city_df['Расширенная UTM-метка Term'][Paveletskaya_city_df['Расширенная UTM-метка Term'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 72. Расширенная UTM-метка Referrer

# %%
Paveletskaya_city_df['Расширенная UTM-метка Referrer'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Расширенная UTM-метка Referrer, dtype: float64

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Referrer'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Referrer'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Referrer'
Paveletskaya_city_df['Расширенная UTM-метка Referrer'] = Paveletskaya_city_df['Расширенная UTM-метка Referrer'].fillna('нет')

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Referrer'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Referrer'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Расширенная UTM-метка Referrer'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Расширенная UTM-метка Referrer, dtype: object

# %%
Paveletskaya_city_df['Расширенная UTM-метка Referrer'][Paveletskaya_city_df['Расширенная UTM-метка Referrer'] == ''].count()
# Out:
# 0

# %% [markdown]
# ##### 73. Расширенная UTM-метка Expid

# %%
Paveletskaya_city_df['Расширенная UTM-метка Expid'].head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: Расширенная UTM-метка Expid, dtype: float64

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Expid'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Expid'].shape[0])
# Out:
# 0
# 1518

# %%
# Избавляемся от пустот в столбце 'Расширенная UTM-метка Expid'
Paveletskaya_city_df['Расширенная UTM-метка Expid'] = Paveletskaya_city_df['Расширенная UTM-метка Expid'].fillna('нет')

# %%
print(Paveletskaya_city_df['Расширенная UTM-метка Expid'].count())
print(Paveletskaya_city_df['Расширенная UTM-метка Expid'].shape[0])
# Out:
# 1518
# 1518

# %%
Paveletskaya_city_df['Расширенная UTM-метка Expid'].tail()
# Out:
# 1513    нет
# 1514    нет
# 1515    нет
# 1516    нет
# 1517    нет
# Name: Расширенная UTM-метка Expid, dtype: object

# %%
Paveletskaya_city_df['Расширенная UTM-метка Expid'][Paveletskaya_city_df['Расширенная UTM-метка Expid'] == ''].count()
# Out:
# 0

# %% [markdown]
# #### Типы данных

# %%
# Смотрим типы данных
Paveletskaya_city_df.dtypes
# Out:
# Статус                                             object
# Тип                                                object
# Дата и время                               datetime64[ns]
# Номер абонента                                      int64
# Теги                                               object
# Рекламная кампания                                 object
# Длительность звонка                                object
# Client ID Яндекс.Метрика                           object
# Длительность ожидания ответа                       object
# Сотрудник                                          object
# Номер обращения                                     int64
# ID посетителя                                       int64
# UTM-метка Campaign                                 object
# Город                                              object
# Страна                                             object
# Страна номера абонента                             object
# UTM-метка Content                                  object
# Тип устройства                                     object
# Сайт                                               object
# Оценка сотрудника                                  object
# Виртуальный номер                                   int64
# Номер сотрудника                                    int64
# Трансфер                                           object
# Внутренний звонок                                  object
# ФИО контакта                                       object
# Имя тренера                                        object
# Сценарий                                           object
# Операции                                           object
# Идентификатор сессии звонка                         int64
# Причина завершения                                 object
# Группа, выбранная посетителем                      object
# Длительность обработки                              int64
# Регион номера абонента                             object
# Комментарий                                        object
# Контакт из CRM                                     object
# Поисковая система                                  object
# Поисковый запрос                                   object
# Реферер                                            object
# Домен реферера                                     object
# Область                                            object
# Посадочная страница                                object
# Первая рекламная кампания                          object
# Количество посещений                                int64
# Тип посетителя                                     object
# Client ID Google Analytics                         object
# ID ресурса Google Analytics                        object
# ID счетчика Яндекс.Метрика                         object
# URL страницы обращения                             object
# UTM-метка Source                                   object
# UTM-метка Medium                                   object
# UTM-метка Term                                     object
# UTM-метка Referrer                                 object
# UTM-метка Expid                                    object
# OS-метка service-name                              object
# OS-метка campaign-id                               object
# OS-метка ad-id                                     object
# OS-метка source-id                                 object
# AdLense-метка ef_id                                object
# Метка yclid                                        object
# Метка ymclid                                       object
# Метка gclid                                        object
# Метка from                                         object
# Длительность разговора                             object
# Длительность постобработки                         object
# Чистая длительность разговора                      object
# Полная длительность ожидания                       object
# Идентификатор звонка во внешней системе            object
# Расширенная UTM-метка Source                       object
# Расширенная UTM-метка Campaign                     object
# Расширенная UTM-метка Medium                       object
# Расширенная UTM-метка Content                      object
# Расширенная UTM-метка Term                         object
# Расширенная UTM-метка Referrer                     object
# Расширенная UTM-метка Expid                        object
# dtype: object

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Paveletskaya_city_df в файл
with open(df_path + 'Paveletskaya_city_new_df.pkl', 'wb') as f:
  pkl.dump(Paveletskaya_city_df, f)

# %% [markdown]
# ## Соединение датафреймов с информацией о звонках

# %% [markdown]
# ### Загрузка датафреймов

# %%
# Загрузка прежних датафреймов с информацией о звонках
with open(df_path + 'Headliner_df.pkl', 'rb') as f:
  Headliner_df = pkl.load(f)

with open(df_path + 'Primavera_df.pkl', 'rb') as f:
  Primavera_df = pkl.load(f)

with open(df_path + 'Paveletskaya_city_df.pkl', 'rb') as f:
  Paveletskaya_city_df = pkl.load(f)

with open(df_path + 'Paveletskaya_df.pkl', 'rb') as f:
  Paveletskaya_df = pkl.load(f)

# %%
# Загрузка новых датафреймов с информацией о звонках
with open(df_path + 'Headliner_new_df.pkl', 'rb') as f:
  Headliner_new_df = pkl.load(f)

with open(df_path + 'Primavera_new_df.pkl', 'rb') as f:
  Primavera_new_df = pkl.load(f)

with open(df_path + 'Paveletskaya_city_new_df.pkl', 'rb') as f:
  Paveletskaya_city_new_df = pkl.load(f)

# %%
# Загрузка новых датафреймов, полученных из новых файлов записей звонков
with open(df_path + 'Headliner_new_calls_df.pkl', 'rb') as f:
  Headliner_new_calls_df = pkl.load(f)

with open(df_path + 'Primavera_new_calls_df.pkl', 'rb') as f:
  Primavera_new_calls_df = pkl.load(f)

with open(df_path + 'Paveletskaya_city_new_calls_df.pkl', 'rb') as f:
  Paveletskaya_city_new_calls_df = pkl.load(f)

# %%
# Загрузка новых датафреймов, полученных из новых файлов транскрибации записей звонков
with open(df_path + 'Headliner_new_transcriptions_df.pkl', 'rb') as f:
  Headliner_new_transcriptions_df = pkl.load(f)

with open(df_path + 'Primavera_new_transcriptions_df.pkl', 'rb') as f:
  Primavera_new_transcriptions_df = pkl.load(f)

with open(df_path + 'Paveletskaya_city_new_transcriptions_df.pkl', 'rb') as f:
  Paveletskaya_city_new_transcriptions_df = pkl.load(f)

# %% [markdown]
# ### Headliner

# %% [markdown]
# #### Добавление столбцов

# %% [markdown]
# ##### `Идентификатор звонка во внешней системе`, `Длительность обработки`

# %%
# Смотрим несовпадающие столбцы Headliner_new_df vs Headliner_df
for column in Headliner_new_df.columns.tolist():
  if column not in Headliner_df.columns.tolist():
    print(f"Headliner_new_df['{column}'], тип данных: {Headliner_new_df[column].dtypes}")

# %%
# Смотрим несовпадающие столбцы Headliner_df vs Headliner_new_df
for column in Headliner_df.columns.tolist():
  if column not in Headliner_new_df.columns.tolist():
    print(f'Headliner_df[{column}], тип данных: {Headliner_df[column].dtypes}')
# Out:
# Headliner_df[Идентификатор звонка во внешней системе], тип данных: int64
# Headliner_df[Длительность обработки], тип данных: int64
# Headliner_df[Файл записи звонка], тип данных: object

# %%
# Добавляем столбец 'Идентификатор звонка во внешней системе' в Headliner_new_df
Headliner_new_df['Идентификатор звонка во внешней системе'] = 0

# %%
# Добавляем столбец 'Длительность обработки' в Headliner_new_df
Headliner_new_df['Длительность обработки'] = 0

# %% [markdown]
# ##### `Файл записи звонка`

# %%
# Смотрим несовпадающие столбцы Headliner_new_calls_df vs Headliner_new_df
for column in Headliner_new_calls_df.columns.tolist():
  if column not in Headliner_new_df.columns.tolist():
    print(f"Headliner_new_calls_df['{column}'], {Headliner_new_calls_df[column].shape[0]} строк, тип данных: {Headliner_new_calls_df[column].dtypes}")
print(f"Headliner_new_df, {Headliner_new_df.shape[0]} строк")
# Out:
# Headliner_new_calls_df['Файл записи звонка'], 1226 строк, тип данных: object
# Headliner_new_df, 1542 строк

# %%
Headliner_new_calls_df['Файл записи звонка'].head()
# Out:
# 0    Новые записи звонков/Записи Headliner/2023-09-26_10-06-23.403699_from_79584153294_to_74959339902_session_3252459256_talk.mp3
# 1        Новые записи звонков/Записи Headliner/2023-09-21_18-54-50.120569_from_79951538090_to_0188880_session_3235156678_talk.mp3
# 2        Новые записи звонков/Записи Headliner/2023-09-27_16-10-52.316459_from_79853697070_to_0188880_session_3253840089_talk.mp3
# 3    Новые записи звонков/Записи Headliner/2023-09-25_09-12-02.428401_from_79858141531_to_74959339902_session_3249639806_talk.mp3
# 4    Новые записи звонков/Записи Headliner/2023-09-28_11-08-32.052586_from_79851881681_to_74959339902_session_3262172387_talk.mp3
# Name: Файл записи звонка, dtype: object

# %%
# Добавляем столбец 'Файл записи звонка' в Headliner_new_df
Headliner_new_df = Headliner_new_df.merge(Headliner_new_calls_df[['Идентификатор сессии звонка','Файл записи звонка']], how='outer', on=['Идентификатор сессии звонка'])

# %%
# Смотрим долю непустых записей в столбце 'Файл записи звонка'
print(Headliner_new_df['Файл записи звонка'].count())
print(Headliner_new_df['Файл записи звонка'].shape[0])
# Out:
# 1226
# 1542

# %%
# Запоняем пустоты в столбце 'Файл записи звонка' значением 'нет файла'
Headliner_new_df['Файл записи звонка'] = Headliner_new_df['Файл записи звонка'].fillna('нет файла')

# %%
# Смотрим долю непустых записей в столбце 'Файл записи звонка'
print(Headliner_new_df['Файл записи звонка'].count())
print(Headliner_new_df['Файл записи звонка'].shape[0])
# Out:
# 1542
# 1542

# %%
# Сортируем Headliner_new_df по столбцу 'Идентификатор сессии звонка'
Headliner_new_df = Headliner_new_df.sort_values('Идентификатор сессии звонка')

# %%
# Индексируем по порядку
Headliner_new_df.index = range(Headliner_new_df.shape[0])

# %%
# Нет файлов
Headliner_new_df['Файл записи звонка'][Headliner_new_df['Файл записи звонка'] == 'нет файла'].count()
# Out:
# 316

# %%
# Есть файлы
Headliner_new_df['Файл записи звонка'][Headliner_new_df['Файл записи звонка'] != 'нет файла'].count()
# Out:
# 1226

# %% [markdown]
# ##### `Файл whisper-транскрибации записи звонка`, `Текст whisper-транскрибации записи звонка`

# %%
# Смотрим несовпадающие столбцы Headliner_new_transcriptions_df vs Headliner_new_df
for column in Headliner_new_transcriptions_df.columns.tolist():
  if column not in Headliner_new_df.columns.tolist():
    print(f"Headliner_new_transcriptions_df['{column}'], {Headliner_new_transcriptions_df[column].shape[0]} строк, тип данных: {Headliner_new_transcriptions_df[column].dtypes}")
print(f"Headliner_new_df, {Headliner_new_df.shape[0]} строк")
# Out:
# Headliner_new_transcriptions_df['Файл whisper-транскрибации записи звонка'], 1226 строк, тип данных: object
# Headliner_new_transcriptions_df['Текст whisper-транскрибации записи звонка'], 1226 строк, тип данных: object
# Headliner_new_df, 1542 строк

# %%
Headliner_new_transcriptions_df['Файл whisper-транскрибации записи звонка'].head()
# Out:
# 0        Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_11-18-46.243226_from_79133420036_to_0188880_session_3188273510_talk.txt
# 1    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_12-07-24.419439_from_79687467064_to_74959339929_session_3188426705_talk.txt
# 2    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_12-10-00.806885_from_79687467064_to_74959339929_session_3201544602_talk.txt
# 3    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_12-20-37.789876_from_79851620909_to_74959339929_session_3188461175_talk.txt
# 4    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Headliner/2023-09-01_12-53-13.411858_from_74959891229_to_74959339929_session_3191589263_talk.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %%
Headliner_new_transcriptions_df['Текст whisper-транскрибации записи звонка'].head()
# Out:
# 0    Здравствуйте, вы позвонили в группу компании «Картро». Благодарим вас за звонок. Пожалуйста, дождитесь ответа оператора. Группа компании «Картро» Статьяна, здравствуйте. Статьяна, здравствуйте. Меня зовут Анжела. Хотела вас уточнить по ЖК «Хоббелайнер». Интересует третья очередь или еще какая-то четвертая, а, вторая очередь. Третья очередь. Квартиры 30 и 40 квадратов. Хорошо, я вас поденю с менеджером. Минуту оставайтесь на линии. Спасибо. Жилой комплекс «Хоббелайнер». Меня зовут Виталия. Здравствуйте. Виталия, здравствуйте. Меня зовут Анжела. По поводу квартиры «Хоббелайнер». Вторая, третья очередь. Интересует квартиры 30 и 40 квадратов. Во второй очереди 30 квадратных метров по проекту не было. Площадь от 40 квадратных метров начиналась. Сейчас минимальный бюджет в построенной второй очереди начинается от 22 миллионов за 43 квадратных метра. Есть варианты с площадью 30 квадратных метров со сроком выдачи в ключе 2024 год. По бюджету начинается от 17,5 миллионов. Это со всеми макс...
# 1                                                                                                                                                                                                                                                                             Добрый день, слушаю вас. Как Вы зваетесь? Как Вы сказали, извините. Михаил. Михаил, мне нужно, знаете что, ООО «Элиткомплекс» по какому адресу находится? Шминцский проезд, 39, курс 2. Оттуда приехали, говорят, что нет такого. Охрана никого не пускает. Первый этаж, куда им идти? За минуту. 39, курс 2, первый этаж, помещение 18, кабинет 2-10. Это находится примерно рядом с вкусвиллом. Там дальше вкусвилл будет. Так, подождите, подождите, вот этот адрес, курс 2, первый этаж, помещение 18, кабинет 2-10. Кабинет 2-10, да? Да. Так, это и вот вкусвилл. Да, от вкусвилла, там буквально получается, если смотреть на вкусвилл, с правой стороны будет вход. С правой стороны вход от вкусвилл, да? Да, да, да. Угу, все, спасибо вам большое.
# 2    Алло, Михаил, это снова я. Скажите, пожалуйста, вот там никто, ну охрану туда не пускают. Может кто-то спуститься? Как этого устроить? Кто-нибудь может туда подойти, потому что их там не запускают? Я пока не могу подсказать. Блин, ну что делать? Они ехали. Если вы не в правильном помещении... Не, не, не, они в правильном. Нас все нашли, говорит, лозунг кусил, все нашли, в помещении стоят, там ждут, и кого ждут неизвестно. И там ехали, там еще... Там есть секретарь, который может принять документы. Вы это объясните охраннику, что ему нужно секретарь, чтобы он принял документы, и все. Может быть просто секретарь переехал в другое место. Вот. Нужен секретарь, который примет документы, и все. Вот и все. Блин, а отлично, мы будем искать того секретаря. Там точно должен быть кто-то, может быть, правда? Может быть просто секретарь, который принимает документы, он на обед отошел, поэтому охрана не пускает вас. Нужно это охране объяснить, они смогут подсказать. Потому что охранник думает, ...
# 3    ЗВОНОК ТЕЛЕФОНА ЗВОНОК ТЕЛЕФОНА Добрый день, группа «Картас». Михаил слушает вас. Здравствуйте. Михаил, нужно акт прямой передачи сделать. Включайте. Подскажите, какой проект, фамилия, собственник? Фамилия Белов, Щелково-Богородск. Да. Белов Андреанович. Я просто у вас здесь стою, охрана не пускает, говорит. Никуда не знает. А, я понял, Щелково-Богородск. Вам же объясняли, что необходимо заявление написать письменное. Да, а вот куда войти нужно? Только после рассмотрения данного заявления вам смогут сделать дубликат акта. Просто так это не делается. Нет, я вас понял. Я просто вот у вас в Москве стою, куда мне нужно идти? Кому вызвать, чтобы я написал заявление? Держите к тому адресу. Шмидтовский проезд, 39, корпус 2, этаж 1, помещение 18, кабинет 210. Ну, я вот здесь стою, охрана меня не пускает. Можно объяснить? Что такое отдел продаж? Отделы продаж, наверное, надо стоять или где? С одной стороны, у вас там технические документы делают. Куда нужно с этим актом бежать? Вам заявлен...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             *** Music ***
# Name: Текст whisper-транскрибации записи звонка, dtype: object

# %%
# Добавляем столбцы 'Файл whisper-транскрибации записи звонка' и 'Текст whisper-транскрибации записи звонка' в Headliner_new_df
Headliner_new_df = Headliner_new_df.merge(Headliner_new_transcriptions_df[['Идентификатор сессии звонка',
                                                                           'Файл whisper-транскрибации записи звонка',
                                                                           'Текст whisper-транскрибации записи звонка']],
                                          how='outer',
                                          on=['Идентификатор сессии звонка'])

# %%
# Смотрим долю непустых записей в столбце 'Файл whisper-транскрибации записи звонка'
print(Headliner_new_df['Файл whisper-транскрибации записи звонка'].count())
print(Headliner_new_df['Файл whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1226
# 1542

# %%
# Запоняем пустоты в столбце 'Файл whisper-транскрибации записи звонка' значением 'нет файла'
Headliner_new_df['Файл whisper-транскрибации записи звонка'] = Headliner_new_df['Файл whisper-транскрибации записи звонка'].fillna('нет файла')

# %%
# Смотрим долю непустых записей в столбце 'Файл whisper-транскрибации записи звонка'
print(Headliner_new_df['Файл whisper-транскрибации записи звонка'].count())
print(Headliner_new_df['Файл whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1542
# 1542

# %%
# Смотрим долю непустых записей в столбце 'Текст whisper-транскрибации записи звонка'
print(Headliner_new_df['Текст whisper-транскрибации записи звонка'].count())
print(Headliner_new_df['Текст whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1226
# 1542

# %%
# Запоняем пустоты в столбце 'Текст whisper-транскрибации записи звонка' значением 'нет текста'
Headliner_new_df['Текст whisper-транскрибации записи звонка'] = Headliner_new_df['Текст whisper-транскрибации записи звонка'].fillna('нет текста')

# %%
# Смотрим долю непустых записей в столбце 'Текст whisper-транскрибации записи звонка'
print(Headliner_new_df['Текст whisper-транскрибации записи звонка'].count())
print(Headliner_new_df['Текст whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1542
# 1542

# %%
# Сортируем Headliner_new_df по столбцу 'Идентификатор сессии звонка'
Headliner_new_df = Headliner_new_df.sort_values('Идентификатор сессии звонка')

# %%
# Индексируем по порядку
Headliner_new_df.index = range(Headliner_new_df.shape[0])

# %%
# Нет файлов
Headliner_new_df['Файл whisper-транскрибации записи звонка'][Headliner_new_df['Файл whisper-транскрибации записи звонка'] == 'нет файла'].count()
# Out:
# 316

# %%
# Есть файлы
Headliner_new_df['Файл whisper-транскрибации записи звонка'][Headliner_new_df['Файл whisper-транскрибации записи звонка'] != 'нет файла'].count()
# Out:
# 1226

# %% [markdown]
# ##### `Класс`

# %%
# Добавляем столбец 'Класс' в Headliner_new_df
Headliner_new_df['Класс'] = 'Нецелевой'

# %%
# Теги целевых звонков
target_teg_list = []
pattern = '.*Целевой_М108.*|.*первичный целевой.*'
for teg in Headliner_new_df['Теги'].unique():
  if re.findall(pattern.lower(), teg.lower()):
    target_teg_list.append(teg)

# %%
# Целевые звонки
Headliner_new_df.loc[Headliner_new_df['Теги'].isin(target_teg_list), 'Класс'] = 'Целевой'

# %%
# Целевые звонки
Headliner_new_df['Класс'][Headliner_new_df['Класс'] == 'Целевой'].count()
# Out:
# 194

# %%
# Нецелевые звонки
Headliner_new_df['Класс'][Headliner_new_df['Класс'] != 'Целевой'].count()
# Out:
# 1348

# %%
# Нецелевые звонки
Headliner_new_df['Класс'][Headliner_new_df['Класс'] == 'Нецелевой'].count()
# Out:
# 1348

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Headliner_new_df в файл
with open(df_path + 'Headliner_new_df.pkl', 'wb') as f:
  pkl.dump(Headliner_new_df, f)

# %% [markdown]
# ### Primavera

# %% [markdown]
# #### Добавление столбцов

# %% [markdown]
# ##### `Длительность ожидания ответа`, `Причина завершения`, `Виртуальный номер`

# %%
# Смотрим несовпадающие столбцы Primavera_new_df vs Primavera_df
for column in Primavera_new_df.columns.tolist():
  if column not in Primavera_df.columns.tolist():
    print(f"Primavera_new_df['{column}'], тип данных: {Primavera_new_df[column].dtypes}")

# %%
# Смотрим несовпадающие столбцы Primavera_df vs Primavera_new_df
for column in Primavera_df.columns.tolist():
  if column not in Primavera_new_df.columns.tolist():
    print(f"Primavera_df['{column}'], тип данных: {Primavera_df[column].dtypes}")
# Out:
# Primavera_df['Длительность ожидания ответа'], тип данных: object
# Primavera_df['Причина завершения'], тип данных: object
# Primavera_df['Виртуальный номер'], тип данных: int64
# Primavera_df['Файл записи звонка'], тип данных: object

# %%
# Добавляем столбец 'Длительность ожидания ответа' в Primavera_new_df
Primavera_new_df['Длительность ожидания ответа'] = '00:00:00'

# %%
# Добавляем столбец 'Длительность обработки' в Primavera_new_df
Primavera_new_df['Причина завершения'] = 'нет'

# %%
# Добавляем столбец 'Виртуальный номер' в Primavera_new_df
Primavera_new_df['Виртуальный номер'] = 0

# %% [markdown]
# ##### `Файл записи звонка`

# %%
# Смотрим несовпадающие столбцы Primavera_new_calls_df vs Primavera_new_df
for column in Primavera_new_calls_df.columns.tolist():
  if column not in Primavera_new_df.columns.tolist():
    print(f"Primavera_new_calls_df['{column}'], {Primavera_new_calls_df[column].shape[0]} строк, тип данных: {Primavera_new_calls_df[column].dtypes}")
print(f"Primavera_new_df, {Primavera_new_df.shape[0]} строк")
# Out:
# Primavera_new_calls_df['Файл записи звонка'], 767 строк, тип данных: object
# Primavera_new_df, 1523 строк

# %%
Primavera_new_calls_df['Файл записи звонка'].head()
# Out:
# 0    Новые записи звонков/Записи Primavera/2023-09-30_12-19-55.312627_from_79854305902_to_0253192_session_3263012391_talk.mp3
# 1    Новые записи звонков/Записи Primavera/2023-10-04_19-40-25.037187_from_74950210291_to_0253206_session_3276780397_talk.mp3
# 2    Новые записи звонков/Записи Primavera/2023-10-04_15-52-11.200324_from_79203810871_to_0253201_session_3276172302_talk.mp3
# 3    Новые записи звонков/Записи Primavera/2023-10-02_20-00-47.312686_from_74950210291_to_0150113_session_3271743567_talk.mp3
# 4    Новые записи звонков/Записи Primavera/2023-10-04_16-50-31.267655_from_79295237177_to_0111652_session_3269469074_talk.mp3
# Name: Файл записи звонка, dtype: object

# %%
# Добавляем столбец 'Файл записи звонка' в Primavera_new_df
Primavera_new_df = Primavera_new_df.merge(Primavera_new_calls_df[['Идентификатор сессии звонка','Файл записи звонка']], how='outer', on=['Идентификатор сессии звонка'])

# %%
# Смотрим долю непустых записей в столбце 'Файл записи звонка'
print(Primavera_new_df['Файл записи звонка'].count())
print(Primavera_new_df['Файл записи звонка'].shape[0])
# Out:
# 767
# 1523

# %%
# Запоняем пустоты в столбце 'Файл записи звонка' значением 'нет файла'
Primavera_new_df['Файл записи звонка'] = Primavera_new_df['Файл записи звонка'].fillna('нет файла')

# %%
# Смотрим долю непустых записей в столбце 'Файл записи звонка'
print(Primavera_new_df['Файл записи звонка'].count())
print(Primavera_new_df['Файл записи звонка'].shape[0])
# Out:
# 1523
# 1523

# %%
# Сортируем Primavera_new_df по столбцу 'Идентификатор сессии звонка'
Primavera_new_df = Primavera_new_df.sort_values('Идентификатор сессии звонка')

# %%
# Индексируем по порядку
Primavera_new_df.index = range(Primavera_new_df.shape[0])

# %%
# Нет файлов
Primavera_new_df['Файл записи звонка'][Primavera_new_df['Файл записи звонка'] == 'нет файла'].count()
# Out:
# 756

# %%
# Есть файлы
Primavera_new_df['Файл записи звонка'][Primavera_new_df['Файл записи звонка'] != 'нет файла'].count()
# Out:
# 767

# %% [markdown]
# ##### `Файл whisper-транскрибации записи звонка`, `Текст whisper-транскрибации записи звонка`

# %%
# Смотрим несовпадающие столбцы Primavera_new_transcriptions_df vs Primavera_new_df
for column in Primavera_new_transcriptions_df.columns.tolist():
  if column not in Primavera_new_df.columns.tolist():
    print(f"Primavera_new_transcriptions_df['{column}'], {Primavera_new_transcriptions_df[column].shape[0]} строк, тип данных: {Primavera_new_transcriptions_df[column].dtypes}")
print(f"Primavera_new_df, {Primavera_new_df.shape[0]} строк")
# Out:
# Primavera_new_transcriptions_df['Файл whisper-транскрибации записи звонка'], 767 строк, тип данных: object
# Primavera_new_transcriptions_df['Текст whisper-транскрибации записи звонка'], 767 строк, тип данных: object
# Primavera_new_df, 1523 строк

# %%
Primavera_new_transcriptions_df['Файл whisper-транскрибации записи звонка'].head()
# Out:
# 0    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_09-00-40.052431_from_74950210291_to_0253211_session_3200997782_talk_whisper_large.txt
# 1    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_09-25-57.450908_from_79264683596_to_0111639_session_3187995780_talk_whisper_large.txt
# 2    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_11-16-28.505654_from_79161163889_to_0111652_session_3195799881_talk_whisper_large.txt
# 3    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_11-42-21.432552_from_79377999852_to_0253201_session_3188347120_talk_whisper_large.txt
# 4    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Primavera/2023-09-01_12-05-26.624031_from_79199944228_to_0111652_session_3188422720_talk_whisper_large.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %%
Primavera_new_transcriptions_df['Текст whisper-транскрибации записи звонка'].head()
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Добрый день, оператор Яна, клубный город на реке Примавера. Как я могу к вам обращаться? Добрый день, Александр. Можете через 2 часа набрать? Да, покупка квартиры, да, интересует, Александр? Да, да, да. Все, хорошо, передам информацию. Ожидайте. Спасибо.
# 1    Клубный город на реке Примавера. Здравствуйте, Светлана. Да, здрасте. Есть квартиры? Да, да. Как обращаться к вам? Вячеслав. Вячеслав, вас менеджер проконсультирует минуту. Обращаем ваше внимание, что в целях контроля качества услуг разговор может быть записан. Обращаем ваше внимание. Примавера. Клубный город на реке. Меня Владимир зовут. Здравствуйте, Вячеслав. Всем могу быть полезен? Да, здрасте. Предъявление на вас, что квартиры до 20 миллионов, ну, как хотелось бы, до 15. Ну, либо однушка, либо двушка. Просите на двушку, наверное. Вячеслав, скажите, до 13 миллионов, вы сказали? Нет, до 17-ти. А, так. У нас просто двухкомнатные, где отдельная спальня и кухня. Они начинаются от 27 миллионов. Есть форматы Евро, двухкомнатные, где отдельная спальня и кухня-гостиная. Они начинаются от 19 миллионов 300 тысяч. Вам такие форматы подходят? Это самые дальние по сдаче, корпус. Да, совершенно верно. У нас сейчас в продаже две очереди, Россиния и Вивальди. Россия, ключи до декабря 2024 год...
# 2    Здравствуйте, это Татьяна. Здравствуйте, это Евгения. Город на реке, однокомнатный 25-й год, 19 370 000 рублей. Соединяем? Да. Ага. А для продаж соединяю с менеджером. Добрый день. Я хотела узнать, по ряду рассрочки какой у вас... Обращаем ваше внимание, что в целях контроля качества услуг разговор может быть записан. Прямовары, Клубная зона. Алло. Владимир зовут. Здравствуйте, Евгения. Чем могу быть полезен? Здравствуйте. Хотела поподробнее расспросить по отсрочке, рассрочке, то есть при покупке квартиры, такие условия. Евгения, а вас какой корпус интересует? Очередь. У нас есть две очереди. Первая на России называется, там ключи до декабря 24-го года пораньше завернуты. А вторая очередь называется в Вивальде, там срок получения ключей до декабря 25-го года, на год позднее. Вы готовы подождать? Ага. Подождать я готова, да. Ну какие у вас там условия? А что, разные условия для 24-го года? Да, конечно. А вы расскажите про то и про другое. В первую очередь у нас есть хорошая рассроч...
# 3                                           Кубный город на реке Примавера. Здравствуйте, Екатерина. Да, здравствуй, Екатерина. Скажите, пожалуйста, а где у вас офис находится? По поводу консультации приключена специалистка. Как вас представить можно? Михаил зовут. Соглени вас. Клубный город на реке Примавера. Меня зовут Екатерина. Михаил, здравствуйте. Чем могу быть вам? Правильно? Здравствуйте. А где у вас офис находится в Прадаже? Он находится по адресу Волоколамской шоссе, 71, корпус 1. Чуть в отдалении от объекта. Вы сейчас где-то недалеко? Да, мы где-то возле прям объекта. А, вам нужно пойти в другую сторону, либо там... В сторону Волоколамского шоссе. Да, абсолютно верно. Вы сейчас пешком или на автомобиле? Да, пешком. Я вам могу сбросить точку в Яндекс.Картах, в навигаторе, вы поймете где. И я вас буду застеливать. Есть номер живой, да? Можете сюда оставить. Сейчас, секунду, давайте я посмотрю определился ли. Так, 937, 799, да? Да, да. Все, сейчас отправлю вас. Все, спасибо, ждем.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Кловный город на реке Примавера. Здравствуйте, Анастасия. Девушка, здравствуйте. А у вас есть такой врач? Сейчас скажу. А ваш врач, это жилой комплекс. Ой, извините.
# Name: Текст whisper-транскрибации записи звонка, dtype: object

# %%
# Добавляем столбцы 'Файл whisper-транскрибации записи звонка' и 'Текст whisper-транскрибации записи звонка' в Primavera_new_df
Primavera_new_df = Primavera_new_df.merge(Primavera_new_transcriptions_df[['Идентификатор сессии звонка',
                                                                           'Файл whisper-транскрибации записи звонка',
                                                                           'Текст whisper-транскрибации записи звонка']],
                                          how='outer',
                                          on=['Идентификатор сессии звонка'])

# %%
# Смотрим долю непустых записей в столбце 'Файл whisper-транскрибации записи звонка'
print(Primavera_new_df['Файл whisper-транскрибации записи звонка'].count())
print(Primavera_new_df['Файл whisper-транскрибации записи звонка'].shape[0])
# Out:
# 767
# 1523

# %%
# Запоняем пустоты в столбце 'Файл whisper-транскрибации записи звонка' значением 'нет файла'
Primavera_new_df['Файл whisper-транскрибации записи звонка'] = Primavera_new_df['Файл whisper-транскрибации записи звонка'].fillna('нет файла')

# %%
# Смотрим долю непустых записей в столбце 'Файл whisper-транскрибации записи звонка'
print(Primavera_new_df['Файл whisper-транскрибации записи звонка'].count())
print(Primavera_new_df['Файл whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1523
# 1523

# %%
# Смотрим долю непустых записей в столбце 'Текст whisper-транскрибации записи звонка'
print(Primavera_new_df['Текст whisper-транскрибации записи звонка'].count())
print(Primavera_new_df['Текст whisper-транскрибации записи звонка'].shape[0])
# Out:
# 767
# 1523

# %%
# Запоняем пустоты в столбце 'Текст whisper-транскрибации записи звонка' значением 'нет текста'
Primavera_new_df['Текст whisper-транскрибации записи звонка'] = Primavera_new_df['Текст whisper-транскрибации записи звонка'].fillna('нет текста')

# %%
# Смотрим долю непустых записей в столбце 'Текст whisper-транскрибации записи звонка'
print(Primavera_new_df['Текст whisper-транскрибации записи звонка'].count())
print(Primavera_new_df['Текст whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1523
# 1523

# %%
# Сортируем Primavera_new_df по столбцу 'Идентификатор сессии звонка'
Primavera_new_df = Primavera_new_df.sort_values('Идентификатор сессии звонка')

# %%
# Индексируем по порядку
Primavera_new_df.index = range(Primavera_new_df.shape[0])

# %%
# Нет файлов
Primavera_new_df['Файл whisper-транскрибации записи звонка'][Primavera_new_df['Файл whisper-транскрибации записи звонка'] == 'нет файла'].count()
# Out:
# 756

# %%
# Есть файлы
Primavera_new_df['Файл whisper-транскрибации записи звонка'][Primavera_new_df['Файл whisper-транскрибации записи звонка'] != 'нет файла'].count()
# Out:
# 767

# %% [markdown]
# ##### `Класс`

# %%
# Добавляем столбец 'Класс' в Primavera_new_df
Primavera_new_df['Класс'] = 'Нецелевой'

# %%
# Теги целевых звонков
target_teg_list = []
pattern = '.*Целевой_М108.*|.*первичный целевой.*'
for teg in Primavera_new_df['Теги'].unique():
  if re.findall(pattern.lower(), teg.lower()):
    target_teg_list.append(teg)

# %%
# Целевые звонки
Primavera_new_df.loc[Primavera_new_df['Теги'].isin(target_teg_list), 'Класс'] = 'Целевой'

# %%
# Целевые звонки
Primavera_new_df['Класс'][Primavera_new_df['Класс'] == 'Целевой'].count()
# Out:
# 336

# %%
# Нецелевые звонки
Primavera_new_df['Класс'][Primavera_new_df['Класс'] != 'Целевой'].count()
# Out:
# 1187

# %%
# Нецелевые звонки
Primavera_new_df['Класс'][Primavera_new_df['Класс'] == 'Нецелевой'].count()
# Out:
# 1187

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Primavera_new_df в файл
with open(df_path + 'Primavera_new_df.pkl', 'wb') as f:
  pkl.dump(Primavera_new_df, f)

# %% [markdown]
# ### Paveletskaya_city

# %% [markdown]
# #### Добавление столбцов

# %% [markdown]
# ##### `Файл записи звонка`

# %%
# Смотрим несовпадающие столбцы Paveletskaya_city_new_df vs Paveletskaya_city_df
for column in Paveletskaya_city_new_df.columns.tolist():
  if column not in Paveletskaya_city_df.columns.tolist():
    print(f"Paveletskaya_city_new_df['{column}'], тип данных: {Paveletskaya_city_new_df[column].dtypes}")

# %%
# Смотрим несовпадающие столбцы Paveletskaya_city_df vs Paveletskaya_city_new_df
for column in Paveletskaya_city_df.columns.tolist():
  if column not in Paveletskaya_city_new_df.columns.tolist():
    print(f"Paveletskaya_city_df['{column}'], тип данных: {Paveletskaya_city_df[column].dtypes}")
# Out:
# Paveletskaya_city_df['Файл записи звонка'], тип данных: object

# %%
# Смотрим несовпадающие столбцы Paveletskaya_city_new_calls_df vs Paveletskaya_city_new_df
for column in Paveletskaya_city_new_calls_df.columns.tolist():
  if column not in Paveletskaya_city_new_df.columns.tolist():
    print(f"Paveletskaya_city_new_calls_df['{column}'], {Paveletskaya_city_new_calls_df[column].shape[0]} строк, тип данных: {Paveletskaya_city_new_calls_df[column].dtypes}")
print(f"Paveletskaya_city_new_df, {Paveletskaya_city_new_df.shape[0]} строк")
# Out:
# Paveletskaya_city_new_calls_df['Файл записи звонка'], 1413 строк, тип данных: object
# Paveletskaya_city_new_df, 1518 строк

# %%
Paveletskaya_city_new_calls_df['Файл записи звонка'].head()
# Out:
# 0     Новые записи звонков/Записи Павелецкая сити/2023-09-18_11-48-26.391636_from_74932482450_to_00288_session_3219964480_talk.mp3
# 1     Новые записи звонков/Записи Павелецкая сити/2023-09-18_12-54-18.603506_from_79160620083_to_00288_session_3220199190_talk.mp3
# 2    Новые записи звонков/Записи Павелецкая сити/2023-09-20_09-56-40.872148_from_905424768475_to_00288_session_3237457931_talk.mp3
# 3     Новые записи звонков/Записи Павелецкая сити/2023-09-19_13-53-47.892984_from_79037861965_to_00288_session_3222616640_talk.mp3
# 4     Новые записи звонков/Записи Павелецкая сити/2023-09-18_12-31-27.901544_from_79099465930_to_00288_session_3230778649_talk.mp3
# Name: Файл записи звонка, dtype: object

# %%
# Добавляем столбец 'Файл записи звонка' в Paveletskaya_city_new_df
Paveletskaya_city_new_df = Paveletskaya_city_new_df.merge(Paveletskaya_city_new_calls_df[['Идентификатор сессии звонка','Файл записи звонка']], how='outer', on=['Идентификатор сессии звонка'])

# %%
# Смотрим долю непустых записей в столбце 'Файл записи звонка'
print(Paveletskaya_city_new_df['Файл записи звонка'].count())
print(Paveletskaya_city_new_df['Файл записи звонка'].shape[0])
# Out:
# 1413
# 1518

# %%
# Запоняем пустоты в столбце 'Файл записи звонка' значением 'нет файла'
Paveletskaya_city_new_df['Файл записи звонка'] = Paveletskaya_city_new_df['Файл записи звонка'].fillna('нет файла')

# %%
# Смотрим долю непустых записей в столбце 'Файл записи звонка'
print(Paveletskaya_city_new_df['Файл записи звонка'].count())
print(Paveletskaya_city_new_df['Файл записи звонка'].shape[0])
# Out:
# 1518
# 1518

# %%
# Сортируем Paveletskaya_city_new_df по столбцу 'Идентификатор сессии звонка'
Paveletskaya_city_new_df = Paveletskaya_city_new_df.sort_values('Идентификатор сессии звонка')

# %%
# Индексируем по порядку
Paveletskaya_city_new_df.index = range(Paveletskaya_city_new_df.shape[0])

# %%
# Нет файлов
Paveletskaya_city_new_df['Файл записи звонка'][Paveletskaya_city_new_df['Файл записи звонка'] == 'нет файла'].count()
# Out:
# 105

# %%
# Есть файлы
Paveletskaya_city_new_df['Файл записи звонка'][Paveletskaya_city_new_df['Файл записи звонка'] != 'нет файла'].count()
# Out:
# 1413

# %% [markdown]
# ##### `Файл whisper-транскрибации записи звонка`, `Текст whisper-транскрибации записи звонка`

# %%
# Смотрим несовпадающие столбцы Paveletskaya_city_new_transcriptions_df vs Paveletskaya_city_new_df
for column in Paveletskaya_city_new_transcriptions_df.columns.tolist():
  if column not in Paveletskaya_city_new_df.columns.tolist():
    print(f"Paveletskaya_city_new_transcriptions_df['{column}'], {Paveletskaya_city_new_transcriptions_df[column].shape[0]} строк, тип данных: {Paveletskaya_city_new_transcriptions_df[column].dtypes}")
print(f"Paveletskaya_city_new_df, {Paveletskaya_city_new_df.shape[0]} строк")
# Out:
# Paveletskaya_city_new_transcriptions_df['Файл whisper-транскрибации записи звонка'], 1413 строк, тип данных: object
# Paveletskaya_city_new_transcriptions_df['Текст whisper-транскрибации записи звонка'], 1413 строк, тип данных: object
# Paveletskaya_city_new_df, 1518 строк

# %%
Paveletskaya_city_new_transcriptions_df['Файл whisper-транскрибации записи звонка'].head()
# Out:
# 0    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-08-31_20-02-47.458103_from_79169468891_to_00288_session_3195065861_talk.txt
# 1    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-09-01_08-51-34.418574_from_79139426842_to_00288_session_3195409751_talk.txt
# 2    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-09-01_10-53-19.201214_from_79257720080_to_00288_session_3188206290_talk.txt
# 3    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-09-01_11-24-52.929663_from_37378077136_to_00288_session_3188292205_talk.txt
# 4    Whisper-транскрибация новых записей звонков/Расшифровки_Записи Павелецкая сити/2023-09-01_11-33-04.092834_from_79858891114_to_00288_session_3195853356_talk.txt
# Name: Файл whisper-транскрибации записи звонка, dtype: object

# %%
Paveletskaya_city_new_transcriptions_df['Текст whisper-транскрибации записи звонка'].head()
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Здравствуйте, вы позвонили в компанию Эмергрупп. Пожалуйста дождитесь ответа нашего специалиста. Обращаем ваше внимание, что в целях улучшения качества обслуживания клиентов все разговоры записываются. Продолжая разговор, вы соглашаетесь на обработку ваших персональных данных. Вам звонок с Яндекс.Недвижимости. Для соединения с покупателем нажмите... Начинаем звонок покупателю.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Здравствуйте, вы позвонили в компанию Эммергрупп. Мы работаем ежедневно с 9 до 21 часа по московскому времени. Сейчас мы не можем ответить на ваш звонок. Пожалуйста, оставьте свои контактные данные, и мы вам перезвоним. Сообщите, пожалуйста, контактный номер телефона с указанием кода города и ваше имя. Начинайте говорить после звукового сигнала. 8-913-942-6842, Алина.
# 2    Здравствуйте! Вы позвонили в компанию Эмергрупп. Пожалуйста, дождитесь ответа нашего специалиста. Обращаем ваше внимание, что в целях улучшения качества обслуживания клиентов все разговоры записываются. Продолжая разговор, вы соглашаетесь на обработку ваших персональных данных. В компании Эмергрупп, меня зовут Ирина. Здравствуйте! Ирина, здравствуйте! Меня вот интересует ЖК по билетской сети. Покупка жировой недвижимости в данном комплексе? Переуступка. Можно ли у вас оформить переуступку по этому объекту? То есть, вы продаете, я правильно поняла вас? Да, да, да. Помните, с каким менеджером контактировали на объекте? Она уже не работает. Нет, именно агентство. Первое агентство, БЭСТ, Метриум. Не знаю. Не помните? Можно фамилию, имя, число, подговоры? Я посмотрю, с кем вы работали, с каким агентством. Ботя Рова, Людмила. Минуту. Людмила Борисовна? Да, да. У вас компания БЭСТ. БЭСТ, я вас сейчас соединю, минуту. По окончании разговора, пожалуйста, оцените качество отслуживания. Людм...
# 3                                                                Здравствуйте! Вы позвонили в компанию Эмэр Групп. Пожалуйста дождитесь ответа нашего специалиста. Обращаем ваше внимание, что в целях улучшения качества обслуживания клиентов все разговоры записываются. Продолжая разговор, вы соглашаетесь на обработку ваших персональных данных. Компания Наркология. Меня зовут Арина. Здравствуйте! Девушка, здравствуйте! Скажите, пожалуйста, я звоню вам с Молдавии. Это у вас наркологический центр, да? Нет, это строительная компания. Вы позвонили. А почему в этот номер пишется, как больница-наркологист? Я вам не смогу подсказать. Возможно, уже номер не принадлежит. А какой номер вы набирали? Подскажите, пожалуйста. Плюс семьсот сорок девять, пятьсот два, сто семьдесят семь, двадцать пять. Нет, что-то вообще соединение. Вы в Москву позвонили. В Москву? Я в Черпухов. Нет, нет, нет, нет, у нас вообще таких номеров нет. Какое-то соединение некорректное пошло. Ага, спасибо, до свидания. До свидания.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Здравствуйте! Вы позвонили в компанию ЭМР-Групп. Пожалуйста, дождитесь ответа нашего специалиста. Обращаем ваше внимание, что в целях улучшения качества обслуживания клиентов все разговоры записываются. Продолжая разговор, вы соглашаетесь на обработку ваших персональных данных.
# Name: Текст whisper-транскрибации записи звонка, dtype: object

# %%
# Добавляем столбцы 'Файл whisper-транскрибации записи звонка' и 'Текст whisper-транскрибации записи звонка' в Paveletskaya_city_new_df
Paveletskaya_city_new_df = Paveletskaya_city_new_df.merge(Paveletskaya_city_new_transcriptions_df[['Идентификатор сессии звонка',
                                                                                                   'Файл whisper-транскрибации записи звонка',
                                                                                                   'Текст whisper-транскрибации записи звонка']],
                                                          how='outer',
                                                          on=['Идентификатор сессии звонка'])

# %%
# Смотрим долю непустых записей в столбце 'Файл whisper-транскрибации записи звонка'
print(Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'].count())
print(Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1413
# 1518

# %%
# Запоняем пустоты в столбце 'Файл whisper-транскрибации записи звонка' значением 'нет файла'
Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'] = Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'].fillna('нет файла')

# %%
# Смотрим долю непустых записей в столбце 'Файл whisper-транскрибации записи звонка'
print(Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'].count())
print(Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1518
# 1518

# %%
# Смотрим долю непустых записей в столбце 'Текст whisper-транскрибации записи звонка'
print(Paveletskaya_city_new_df['Текст whisper-транскрибации записи звонка'].count())
print(Paveletskaya_city_new_df['Текст whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1413
# 1518

# %%
# Запоняем пустоты в столбце 'Текст whisper-транскрибации записи звонка' значением 'нет текста'
Paveletskaya_city_new_df['Текст whisper-транскрибации записи звонка'] = Paveletskaya_city_new_df['Текст whisper-транскрибации записи звонка'].fillna('нет текста')

# %%
# Смотрим долю непустых записей в столбце 'Текст whisper-транскрибации записи звонка'
print(Paveletskaya_city_new_df['Текст whisper-транскрибации записи звонка'].count())
print(Paveletskaya_city_new_df['Текст whisper-транскрибации записи звонка'].shape[0])
# Out:
# 1518
# 1518

# %%
# Сортируем Paveletskaya_city_new_df по столбцу 'Идентификатор сессии звонка'
Paveletskaya_city_new_df = Paveletskaya_city_new_df.sort_values('Идентификатор сессии звонка')

# %%
# Индексируем по порядку
Paveletskaya_city_new_df.index = range(Paveletskaya_city_new_df.shape[0])

# %%
# Нет файлов
Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'][Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'] == 'нет файла'].count()
# Out:
# 105

# %%
# Есть файлы
Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'][Paveletskaya_city_new_df['Файл whisper-транскрибации записи звонка'] != 'нет файла'].count()
# Out:
# 1413

# %% [markdown]
# ##### `Класс`

# %%
# Добавляем столбец 'Класс' в Paveletskaya_city_new_df
Paveletskaya_city_new_df['Класс'] = 'Нецелевой'

# %%
# Теги целевых звонков
target_teg_list = []
pattern = '.*Целевой_М108.*|.*первичный целевой.*'
for teg in Paveletskaya_city_new_df['Теги'].unique():
  if re.findall(pattern.lower(), teg.lower()):
    target_teg_list.append(teg)

# %%
# Целевые звонки
Paveletskaya_city_new_df.loc[Paveletskaya_city_new_df['Теги'].isin(target_teg_list), 'Класс'] = 'Целевой'

# %%
# Целевые звонки
Paveletskaya_city_new_df['Класс'][Paveletskaya_city_new_df['Класс'] == 'Целевой'].count()
# Out:
# 486

# %%
# Нецелевые звонки
Paveletskaya_city_new_df['Класс'][Paveletskaya_city_new_df['Класс'] != 'Целевой'].count()
# Out:
# 1032

# %%
# Нецелевые звонки
Paveletskaya_city_new_df['Класс'][Paveletskaya_city_new_df['Класс'] == 'Нецелевой'].count()
# Out:
# 1032

# %% [markdown]
# #### Сохранение датафрейма

# %%
# Сохраняем Paveletskaya_city_new_df в файл
with open(df_path + 'Paveletskaya_city_new_df.pkl', 'wb') as f:
  pkl.dump(Paveletskaya_city_new_df, f)

# %% [markdown]
# ### Соединение датафреймов

# %%
# Смотрим несовпадающие столбцы Headliner_new_df vs Primavera_new_df
for column in Headliner_new_df.columns.tolist():
  if column not in Primavera_new_df.columns.tolist():
    print(f"Headliner_new_df['{column}'], тип данных: {Headliner_new_df[column].dtypes}")

# %%
# Смотрим несовпадающие столбцы Headliner_new_df vs Paveletskaya_city_new_df
for column in Headliner_new_df.columns.tolist():
  if column not in Paveletskaya_city_new_df.columns.tolist():
    print(f"Headliner_new_df['{column}'], тип данных: {Headliner_new_df[column].dtypes}")

# %%
# Смотрим несовпадающие столбцы Primavera_new_df vs Headliner_new_df
for column in Primavera_new_df.columns.tolist():
  if column not in Headliner_new_df.columns.tolist():
    print(f"Primavera_new_df['{column}'], тип данных: {Primavera_new_df[column].dtypes}")

# %%
# Смотрим несовпадающие столбцы Primavera_new_df vs Paveletskaya_city_new_df
for column in Primavera_new_df.columns.tolist():
  if column not in Paveletskaya_city_new_df.columns.tolist():
    print(f"Primavera_new_df['{column}'], тип данных: {Primavera_new_df[column].dtypes}")

# %%
# Смотрим несовпадающие столбцы Paveletskaya_city_new_df vs Headliner_new_df
for column in Paveletskaya_city_new_df.columns.tolist():
  if column not in Headliner_new_df.columns.tolist():
    print(f"Paveletskaya_city_new_df['{column}'], тип данных: {Paveletskaya_city_new_df[column].dtypes}")

# %%
# Смотрим несовпадающие столбцы Paveletskaya_city_new_df vs Primavera_new_df
for column in Paveletskaya_city_new_df.columns.tolist():
  if column not in Primavera_new_df.columns.tolist():
    print(f"Paveletskaya_city_new_df['{column}'], тип данных: {Paveletskaya_city_new_df[column].dtypes}")

# %%
# Смотрим размеры датафреймов
print(Headliner_new_df.shape)
print(Primavera_new_df.shape)
print(Paveletskaya_city_new_df.shape)
# Out:
# (1542, 78)
# (1523, 78)
# (1518, 78)

# %%
# Соединяем датафреймы
all_new_df = pd.concat([Headliner_new_df, Primavera_new_df, Paveletskaya_city_new_df])
all_new_df.index = range(all_new_df.shape[0])

# %%
# Смотрим размер общего датафрейма
all_new_df.shape
# Out:
# (4583, 78)

# %%
# Сохраняем all_new_df в файл
with open(df_path + 'all_new_df.pkl', 'wb') as f:
  pkl.dump(all_new_df, f)
